# %%
# !pip install pfrl
# !pip install netron
# !pip install brevitas 
# !pip install onnxoptimizer
# !pip install onnx
# !pip install onnxruntime
# Out:
# Collecting pfrl
#   Downloading pfrl-0.4.0.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.6/112.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pfrl) (2.0.0)
# Requirement already satisfied: gym>=0.9.7 in /opt/conda/lib/python3.10/site-packages (from pfrl) (0.26.2)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/lib/python3.10/site-packages (from pfrl) (1.24.3)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from pfrl) (10.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from pfrl) (3.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (0.0.8)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.3.0->pfrl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.3.0->pfrl) (1.3.0)
# Building wheels for collected packages: pfrl
#   Building wheel for pfrl (setup.py) ... done
#   Created wheel for pfrl: filename=pfrl-0.4.0-py3-none-any.whl size=155461 sha256=0dcbec059867f68a4ff079b8f410209096f01a240d3804d4e2d2a9a1421257c8
#   Stored in directory: /root/.cache/pip/wheels/22/4a/0f/a87cd1ae925086eb3a1b8759f620fcf48e47939fb082946c3b
# Successfully built pfrl
# Installing collected packages: pfrl
# Successfully installed pfrl-0.4.0
# Cloning into 'Codebook_Learning_RL'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 77 (delta 5), reused 0 (delta 0), pack-reused 59
# Receiving objects: 100% (77/77), 14.41 MiB | 35.65 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Collecting netron
#   Obtaining dependency information for netron from https://files.pythonhosted.org/packages/32/87/50998a713c4f44df80aa2a0448ba6c5c9427cd04efecc20c1b6f26a6aad7/netron-7.3.4-py3-none-any.whl.metadata
#   Downloading netron-7.3.4-py3-none-any.whl.metadata (1.4 kB)
# Downloading netron-7.3.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: netron
# Successfully installed netron-7.3.4
# Collecting brevitas
#   Obtaining dependency information for brevitas from https://files.pythonhosted.org/packages/0a/3f/d88158fa70fc99031b11b77613eeac2dd0c45c1b45cb21bc1c26e4ed10c5/brevitas-0.10.0-py3-none-any.whl.metadata
#   Downloading brevitas-0.10.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting dependencies==2.0.1 (from brevitas)
#   Downloading dependencies-2.0.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from brevitas) (21.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from brevitas) (68.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from brevitas) (1.12)
# Requirement already satisfied: torch>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from brevitas) (2.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/lib/python3.10/site-packages (from brevitas) (4.5.0)
# Collecting unfoldNd (from brevitas)
#   Downloading unfoldNd-0.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.1->brevitas) (3.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.1->brevitas) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.1->brevitas) (3.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->brevitas) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->brevitas) (1.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from unfoldNd->brevitas) (1.24.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9.1->brevitas) (2.1.3)
# Downloading brevitas-0.10.0-py3-none-any.whl (600 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 600.8/600.8 kB 3.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: dependencies, unfoldNd, brevitas
# Successfully installed brevitas-0.10.0 dependencies-2.0.1 unfoldNd-0.2.0
# Collecting onnxoptimizer
#   Downloading onnxoptimizer-0.3.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (678 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 678.1/678.1 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: onnx in /opt/conda/lib/python3.10/site-packages (from onnxoptimizer) (1.15.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from onnx->onnxoptimizer) (1.24.3)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from onnx->onnxoptimizer) (3.20.3)
# Installing collected packages: onnxoptimizer
# Successfully installed onnxoptimizer-0.3.13
# Requirement already satisfied: onnx in /opt/conda/lib/python3.10/site-packages (1.15.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from onnx) (1.24.3)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from onnx) (3.20.3)
# Collecting onnxruntime
#   Obtaining dependency information for onnxruntime from https://files.pythonhosted.org/packages/7a/cf/6aa8c56fd63f53c2c485921e411269c7b501a2b4e634bd02f226ab2d5d8e/onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 843.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (1.24.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (21.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->onnxruntime) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 31.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.16.3

# %%
# from Codebook_Learning_RL import DDPG_classes

# %%
import pfrl
import os
import time
import torch
import numpy as np
import copy
import pickle
from torch import nn
from torch import distributions
from scipy.optimize import linear_sum_assignment
from DataPrep import dataPrep
from env_ddpg import envCB
from clustering import KMeans_only
from function_lib import bf_gain_cal, corr_mining
from DDPG_classes import OUNoise

#brevitas
import brevitas.nn as qnn
from torch import nn
from brevitas import config
from brevitas.quant import Int32Bias
config.IGNORE_MISSING_KEYS = True
config.JIT_ENABLED = True
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os
os.chdir('Codebook_Learning_RL')
print(os.getcwd())

# %%
class envCB_(envCB):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.gain_history = [0]
        self.EGC_history = []
        self.gain_history_test = []
    def compute_EGC(self):
        ch_r = torch.Tensor.cpu(self.ch.clone()).numpy()[:, :self.num_ant]
        ch_i = torch.Tensor.cpu(self.ch.clone()).numpy()[:, self.num_ant:]
        radius = np.sqrt(np.square(ch_r) + np.square(ch_i))
        gain_opt = np.mean(np.square(np.sum(radius, axis=1)))
        return gain_opt

# %%
options = {
        'gpu_idx': 0,
        'num_ant': 32,
        'num_bits': 4,
        'num_NNs': 4,  # codebook size
        'ch_sample_ratio': 0.5,
        'num_loop': 400,  # outer loop
        'target_update': 3,
        'path': './grid1101-1400.mat',
        'clustering_mode': 'random',
    }

train_opt = {
        'state': 0,
        'best_state': 0,
        'num_iter': 100,  # inner loop
        'tau': 1e-2,
        'overall_iter': 1,
        'replay_memory': [],
        'replay_memory_size': 8192,
        'minibatch_size': 1024,
        'gamma': 0,
        'gpu':0
    }
if not os.path.exists('beams/'):
    os.mkdir('beams/')

ch = dataPrep(options['path'])
ch = np.concatenate((ch[:, :options['num_ant']],
                     ch[:, int(ch.shape[1] / 2):int(ch.shape[1] / 2) + options['num_ant']]), axis=1)
with torch.cuda.device(options['gpu_idx']):
    u_classifier, sensing_beam = KMeans_only(ch, options['num_NNs'], n_bit=options['num_bits'], n_rand_beam=30)
    np.save('sensing_beam.npy', sensing_beam)
    sensing_beam = torch.from_numpy(sensing_beam).float().cuda()

    filename = 'kmeans_model.sav'
    pickle.dump(u_classifier, open(filename, 'wb'))

    # Quantization settings
    options['num_ph'] = 2 ** options['num_bits']
    options['multi_step'] = torch.from_numpy(
        np.linspace(int(-(options['num_ph'] - 2) / 2),
                    int(options['num_ph'] / 2),
                    num=options['num_ph'],
                    endpoint=True)).type(dtype=torch.float32).reshape(1, -1).cuda()
    options['pi'] = torch.tensor(np.pi).cuda()
    options['ph_table'] = (2 * options['pi']) / options['num_ph'] * options['multi_step']
    options['ph_table'].cuda()
    options['ph_table_rep'] = options['ph_table'].repeat(options['num_ant'], 1)
    actor_net_list = []
    critic_net_list = []
    actor_net_t_list = []
    critic_net_t_list = []
    ounoise_list = []
    env_list = []
    train_opt_list = []
    agent_list=[]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pfrl
from pfrl import experiments, explorers, replay_buffers, utils
from pfrl.agents.ddpg import DDPG
from pfrl.nn import BoundByTanh, ConcatObsAndAction
from pfrl.policies import DeterministicHead
from pfrl.explorers import Greedy

def create_agent_sac(state_size,action_size,train_options,gpu=0):
    def squashed_diagonal_gaussian_head(x):
        assert x.shape[-1] == action_size * 2
        mean, log_scale = torch.chunk(x, 2, dim=2)
        log_scale = torch.clamp(log_scale, -20.0, 2.0)
        var = torch.exp(log_scale * 2)
        base_distribution = distributions.Independent(
            distributions.Normal(loc=mean, scale=torch.sqrt(var)), 1
        )
        # cache_size=1 is required for numerical stability
        return distributions.transformed_distribution.TransformedDistribution(
            base_distribution, [distributions.transforms.TanhTransform(cache_size=1),
                                distributions.transforms.AffineTransform(0, torch.pi, event_dim=0, cache_size=1)]
        )

    #critic_networks
    q_func_1 = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    q_func_2 = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    
    #actor_network
    policy = nn.Sequential(
        qnn.QuantIdentity(bit_width=8, return_quant_tensor=True),
        qnn.QuantLinear(state_size, 16 * state_size, bias=True, weight_bit_width=8, bias_quant=Int32Bias),
        qnn.QuantReLU(bit_width=8, return_quant_tensor=True),
        qnn.QuantLinear(16 * state_size, 16 * action_size, bias=True, weight_bit_width=8, bias_quant=Int32Bias),
        qnn.QuantReLU(bit_width=8, return_quant_tensor=True),
        qnn.QuantLinear(16 * action_size, action_size*2, bias=True, weight_bit_width=8, bias_quant=Int32Bias),
        pfrl.nn.lmbda.Lambda(squashed_diagonal_gaussian_head),
    )

    opt_a = torch.optim.Adam(policy.parameters(), lr=1e-3, weight_decay=1e-3)
    opt_c_1 = torch.optim.Adam(q_func_1.parameters(), lr=1e-3, weight_decay=1e-2)
    opt_c_2 = torch.optim.Adam(q_func_2.parameters(), lr=1e-3, weight_decay=1e-2)
    
    rbuf = replay_buffers.ReplayBuffer(train_options['replay_memory_size'])
    
    agent = pfrl.agents.SoftActorCritic(
        policy,
        q_func_1,
        q_func_2,
        opt_a,
        opt_c_1,
        opt_c_2,
        rbuf,
        gamma=train_options['gamma'],
        update_interval=1,
        replay_start_size=train_options['minibatch_size'],
        gpu=gpu,
        soft_update_tau= train_opt['tau'],
        minibatch_size = train_options['minibatch_size'],
        entropy_target=-action_size,
        temperature_optimizer_lr=1e-3,
    )
    return agent

# %%
def train(
          env,
          options,
          train_options,
          agent,
          ounoise,
          beam_id):
    
#     action_pred_noisy = ounoise.get_action(action_pred,
#                                                t=train_options['overall_iter'])
    CB_Env = env   
    if train_options['overall_iter'] == 1:
        state = torch.zeros((1, options['num_ant'])).float().cuda()
        print('Initial State Activated.')
    else:
        state = train_options['state']
    
    
    #training_loop
    iteration = 0
    num_of_iter = train_options['num_iter']  
    while iteration < num_of_iter:

        
        action = agent.act(state)
#         print(type(agent.batch_last_action),agent.batch_last_action)
        action = torch.Tensor(action).to('cuda')
        reward_pred, bf_gain_pred, action_quant_pred, state_1_pred = CB_Env.get_reward(action)
        reward_pred = torch.from_numpy(reward_pred).float().cuda()
        
        action_pred_noisy = action
        mat_dist = torch.abs(action_pred_noisy.reshape(options['num_ant'], 1) - options['ph_table_rep'])
        action_quant = options['ph_table_rep'][range(options['num_ant']), torch.argmin(mat_dist, dim=1)].reshape(1, -1)
   
        state_1, reward, bf_gain, terminal = CB_Env.step(action_quant)
        reward = torch.from_numpy(reward).float().cuda()
        action = action_quant.reshape((1, -1)).float().cuda()
        
        
#         print(type(action_quant_pred.cpu().numpy()),action_quant_pred.cpu().numpy().shape)
#         print(type(action.cpu().numpy()),action.cpu().numpy().shape)
        agent.replay_buffer.append(
                    state=state,
                    action=action_quant_pred.cpu().numpy(),
                    reward=reward_pred,
                    next_state=state_1_pred,
                    next_action=None,
                    is_state_terminal=terminal,
                    env_id=0,
                )
#         print(agent.batch_last_action,agent.batch_last_action[0].shape)
        agent.batch_last_action = [action.cpu().numpy()] #because the critic is expecting quantizazed actions
        agent.observe(state_1, reward, terminal, False)

        
        iteration += 1
        train_options['overall_iter'] += 1
        state = state_1
        
        new_gain = torch.Tensor.cpu(CB_Env.achievement).detach().numpy().reshape((1, 1))
        max_previous_gain = max(CB_Env.gain_record)
        if new_gain > max_previous_gain:
            CB_Env.gain_history.append(float(new_gain))                   
        else:
            CB_Env.gain_history.append(float(max_previous_gain))
            
    train_options['state'] = state  # used for the next loop
    train_options['best_state'] = CB_Env.best_bf_vec  # used for clustering and assignment
    if (train_options['overall_iter']-1)%500==0:
#         print(
#             "Beam: %d, Iter: %d, Reward: %d, BF Gain: %.2f" % \
#             (beam_id, 
#              train_options['overall_iter'],
#              int(torch.Tensor.cpu(reward).numpy().squeeze()),
#              torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))
        print(
            "Beam: %d, Iter: %d, Reward pred: %d, Reward: %d, BF Gain pred: %.2f, BF Gain: %.2f" % \
            (beam_id, train_options['overall_iter'],
             int(torch.Tensor.cpu(reward_pred).numpy().squeeze()),
             int(torch.Tensor.cpu(reward).numpy().squeeze()),
             torch.Tensor.cpu(bf_gain_pred.detach()).numpy().squeeze(),
             torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))      
    
    return train_options

# %%
for beam_id in range(options['num_NNs']):
    ounoise_list.append(OUNoise((1, options['num_ant'])))
    env_list.append(envCB_(ch, options['num_ant'], options['num_bits'], beam_id, options))
    train_opt_list.append(copy.deepcopy(train_opt))
    agent = create_agent_sac(options['num_ant'],options['num_ant'],train_opt_list[beam_id],gpu=train_opt['gpu'])
    agent_list.append(agent)
    ounoise_list.append(OUNoise((1, options['num_ant'])))
# Out:
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094

# %%
with torch.cuda.device(options['gpu_idx']):
    for sample_id in range(options['num_loop']):

        # ---------- Sampling ---------- #
        n_sample = int(ch.shape[0] * options['ch_sample_ratio'])
        ch_sample_id = np.random.permutation(ch.shape[0])[0:n_sample]
        ch_sample = torch.from_numpy(ch[ch_sample_id, :]).float().cuda()

        # ---------- Clustering ---------- #
    #     start_time = time.time()

        bf_mat_sample = bf_gain_cal(sensing_beam, ch_sample)
        # print("Clustering -1 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()
        f_matrix = corr_mining(bf_mat_sample)
        f_matrix_np = torch.Tensor.cpu(f_matrix).numpy()
        # print("Clustering 0 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()
        labels = u_classifier.predict(np.transpose(f_matrix_np).astype(float))

        # print("Clustering 1 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()

        user_group = []  # order: clusters
        ch_group = []  # order: clusters
        for ii in range(options['num_NNs']):
            user_group.append(np.where(labels == ii)[0].tolist())
            ch_group.append(ch_sample[user_group[ii], :])

    #     print("Clustering 2 uses %s seconds." % (time.time() - start_time))

        # ---------- Assignment ---------- #
    #     start_time = time.time()

        # best_state matrix
        best_beam_mtx = torch.zeros((options['num_NNs'], 2 * options['num_ant'])).float().cuda()
        for pp in range(options['num_NNs']):
            best_beam_mtx[pp, :] = env_list[pp].best_bf_vec
        gain_mtx = bf_gain_cal(best_beam_mtx, ch_sample)  # (n_beam, n_user)
        for ii in range(options['num_NNs']):
            if ii == 0:
                cost_mtx = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
            else:
                sub = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
                cost_mtx = torch.cat((cost_mtx, sub), dim=1)
        cost_mtx = -torch.Tensor.cpu(cost_mtx).numpy()
        row_ind, col_ind = linear_sum_assignment(cost_mtx)
        assignment_record = dict(zip(row_ind.tolist(), col_ind.tolist()))  # key: network, value: cluster
        for ii in range(options['num_NNs']):
            env_list[ii].ch = ch_group[assignment_record[ii]]
            env_list[ii].EGC_history.append(env_list[ii].compute_EGC())
    #     print("Assignment uses %s seconds." % (time.time() - start_time))
    
        # Training Phase
        if (train_opt_list[beam_id]['overall_iter']-1)%500==0 or train_opt_list[beam_id]['overall_iter']==1:
            start_time = time.time()
#         if train_options['overall_iter']<40000:
        for beam_id in range(options['num_NNs']):
            train_opt_list[beam_id] = train(env_list[beam_id],options, train_opt_list[beam_id],agent_list[beam_id],ounoise_list[beam_id], beam_id)
        if (train_opt_list[beam_id]['overall_iter']-1)%500==0: 
            print("Training for 500 iteration for each Beam uses %s seconds." % (time.time() - start_time))
#         else:    
#             # Testing Phase
#             start_time = time.time()
#             for beam_id in range(options['num_NNs']):
#                 train_opt_list[beam_id] = test(env_list[beam_id],options, train_opt_list[beam_id],agent_list[beam_id], beam_id)
# Out:
# Initial State Activated.
# /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:1271: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at /usr/local/src/pytorch/c10/core/TensorImpl.h:1788.)
#   return super().rename(names)
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Beam: 0, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 2.13, BF Gain: 2.13
# Beam: 1, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 8.24, BF Gain: 8.24
# Beam: 2, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 4.70, BF Gain: 4.70
# Beam: 3, Iter: 501, Reward pred: -1, Reward: -1, BF Gain pred: 3.30, BF Gain: 3.30
# Training for 500 iteration for each Beam uses 31.619131565093994 seconds.
# /opt/conda/lib/python3.10/site-packages/pfrl/replay_buffer.py:180: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /usr/local/src/pytorch/torch/csrc/utils/tensor_new.cpp:245.)
#   "action": torch.as_tensor(
# Beam: 0, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 1.87, BF Gain: 1.87
# Beam: 1, Iter: 1001, Reward pred: 1, Reward: 1, BF Gain pred: 7.87, BF Gain: 7.87
# Beam: 2, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 6.17, BF Gain: 6.17
# Beam: 3, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 2.07, BF Gain: 2.07
# Training for 500 iteration for each Beam uses 225.897118806839 seconds.
# Beam: 0, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 6.08, BF Gain: 6.08
# Beam: 1, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 3.35, BF Gain: 3.35
# Beam: 2, Iter: 1501, Reward pred: 1, Reward: 1, BF Gain pred: 17.31, BF Gain: 17.31
# Beam: 3, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 2.91, BF Gain: 2.91
# Training for 500 iteration for each Beam uses 211.00506734848022 seconds.
# Beam: 0, Iter: 2001, Reward pred: -1, Reward: -1, BF Gain pred: 7.50, BF Gain: 7.50
# Beam: 1, Iter: 2001, Reward pred: -1, Reward: -1, BF Gain pred: 3.49, BF Gain: 3.49
# Beam: 2, Iter: 2001, Reward pred: -1, Reward: -1, BF Gain pred: 2.64, BF Gain: 2.64
# Beam: 3, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 3.73, BF Gain: 3.73
# Training for 500 iteration for each Beam uses 211.60437870025635 seconds.
# Beam: 0, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 11.28, BF Gain: 11.28
# Beam: 1, Iter: 2501, Reward pred: 1, Reward: 1, BF Gain pred: 18.07, BF Gain: 18.07
# Beam: 2, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 9.34, BF Gain: 9.34
# Beam: 3, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 1.90, BF Gain: 1.90
# Training for 500 iteration for each Beam uses 208.4491786956787 seconds.
# Beam: 0, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 27.06, BF Gain: 27.06
# Beam: 1, Iter: 3001, Reward pred: -1, Reward: -1, BF Gain pred: 8.85, BF Gain: 8.85
# Beam: 2, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 12.93, BF Gain: 12.93
# Beam: 3, Iter: 3001, Reward pred: -1, Reward: -1, BF Gain pred: 3.23, BF Gain: 3.23
# Training for 500 iteration for each Beam uses 207.5377595424652 seconds.
# Beam: 0, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 8.67, BF Gain: 8.67
# Beam: 1, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 6.05, BF Gain: 6.05
# Beam: 2, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 3.35, BF Gain: 3.35
# Beam: 3, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 2.67, BF Gain: 2.67
# Training for 500 iteration for each Beam uses 209.1373746395111 seconds.
# Beam: 0, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 13.84, BF Gain: 13.84
# Beam: 1, Iter: 4001, Reward pred: -1, Reward: -1, BF Gain pred: 2.71, BF Gain: 2.71
# Beam: 2, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 15.57, BF Gain: 15.57
# Beam: 3, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 5.09, BF Gain: 5.09
# Training for 500 iteration for each Beam uses 212.99691009521484 seconds.
# Beam: 0, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 1.45, BF Gain: 1.45
# Beam: 1, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 23.75, BF Gain: 23.75
# Beam: 2, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 47.66, BF Gain: 47.66
# Beam: 3, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 4.92, BF Gain: 4.92
# Training for 500 iteration for each Beam uses 211.01519060134888 seconds.
# Beam: 0, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 4.68, BF Gain: 4.68
# Beam: 1, Iter: 5001, Reward pred: 1, Reward: 1, BF Gain pred: 12.33, BF Gain: 12.33
# Beam: 2, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 8.39, BF Gain: 8.39
# Beam: 3, Iter: 5001, Reward pred: 1, Reward: 1, BF Gain pred: 2.91, BF Gain: 2.91
# Training for 500 iteration for each Beam uses 215.89026951789856 seconds.
# Beam: 0, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 16.51, BF Gain: 16.51
# Beam: 1, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 27.58, BF Gain: 27.58
# Beam: 2, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 34.82, BF Gain: 34.82
# Beam: 3, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 17.66, BF Gain: 17.66
# Training for 500 iteration for each Beam uses 216.73686623573303 seconds.
# Beam: 0, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 20.76, BF Gain: 20.76
# Beam: 1, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 15.45, BF Gain: 15.45
# Beam: 2, Iter: 6001, Reward pred: 1, Reward: 1, BF Gain pred: 43.18, BF Gain: 43.18
# Beam: 3, Iter: 6001, Reward pred: 1, Reward: 1, BF Gain pred: 29.01, BF Gain: 29.01
# Training for 500 iteration for each Beam uses 218.74713778495789 seconds.
# Beam: 0, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 55.46, BF Gain: 55.46
# Beam: 1, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 5.36, BF Gain: 5.36
# Beam: 2, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 8.76, BF Gain: 8.76
# Beam: 3, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 48.86, BF Gain: 48.86
# Training for 500 iteration for each Beam uses 217.1637737751007 seconds.
# Beam: 0, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 40.43, BF Gain: 40.43
# Beam: 1, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 6.66, BF Gain: 6.66
# Beam: 2, Iter: 7001, Reward pred: 1, Reward: 1, BF Gain pred: 34.67, BF Gain: 34.67
# Beam: 3, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 66.08, BF Gain: 66.08
# Training for 500 iteration for each Beam uses 211.31879878044128 seconds.
# Beam: 0, Iter: 7501, Reward pred: -1, Reward: -1, BF Gain pred: 16.92, BF Gain: 16.92
# Beam: 1, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 54.30, BF Gain: 54.30
# Beam: 2, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 85.06, BF Gain: 85.06
# Beam: 3, Iter: 7501, Reward pred: -1, Reward: -1, BF Gain pred: 74.61, BF Gain: 74.61
# Training for 500 iteration for each Beam uses 210.65565991401672 seconds.
# Beam: 0, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 44.98, BF Gain: 44.98
# Beam: 1, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 44.57, BF Gain: 44.57
# Beam: 2, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 59.41, BF Gain: 59.41
# Beam: 3, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 90.82, BF Gain: 90.82
# Training for 500 iteration for each Beam uses 211.2608711719513 seconds.
# Beam: 0, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 116.63, BF Gain: 116.63
# Beam: 1, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 79.46, BF Gain: 79.46
# Beam: 2, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 110.46, BF Gain: 110.46
# Beam: 3, Iter: 8501, Reward pred: 1, Reward: 1, BF Gain pred: 104.39, BF Gain: 104.39
# Training for 500 iteration for each Beam uses 210.87051916122437 seconds.
# Beam: 0, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 134.12, BF Gain: 134.12
# Beam: 1, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 120.27, BF Gain: 120.27
# Beam: 2, Iter: 9001, Reward pred: 1, Reward: 1, BF Gain pred: 147.75, BF Gain: 147.75
# Beam: 3, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 101.26, BF Gain: 101.26
# Training for 500 iteration for each Beam uses 211.77556681632996 seconds.
# Beam: 0, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 146.74, BF Gain: 146.74
# Beam: 1, Iter: 9501, Reward pred: 1, Reward: 1, BF Gain pred: 158.83, BF Gain: 158.83
# Beam: 2, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 193.71, BF Gain: 193.71
# Beam: 3, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 108.03, BF Gain: 108.03
# Training for 500 iteration for each Beam uses 211.260995388031 seconds.
# Beam: 0, Iter: 10001, Reward pred: 1, Reward: 1, BF Gain pred: 173.66, BF Gain: 173.66
# Beam: 1, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 160.83, BF Gain: 160.83
# Beam: 2, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 246.31, BF Gain: 246.31
# Beam: 3, Iter: 10001, Reward pred: 1, Reward: 1, BF Gain pred: 110.14, BF Gain: 110.14
# Training for 500 iteration for each Beam uses 211.32512092590332 seconds.
# Beam: 0, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 164.08, BF Gain: 164.08
# Beam: 1, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 184.39, BF Gain: 184.39
# Beam: 2, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 284.52, BF Gain: 284.52
# Beam: 3, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 108.64, BF Gain: 108.64
# Training for 500 iteration for each Beam uses 211.27886033058167 seconds.
# Beam: 0, Iter: 11001, Reward pred: 1, Reward: 1, BF Gain pred: 175.60, BF Gain: 175.60
# Beam: 1, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 182.28, BF Gain: 182.28
# Beam: 2, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 272.14, BF Gain: 272.14
# Beam: 3, Iter: 11001, Reward pred: 1, Reward: 1, BF Gain pred: 111.47, BF Gain: 111.47
# Training for 500 iteration for each Beam uses 210.69658255577087 seconds.
# Beam: 0, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 176.03, BF Gain: 176.03
# Beam: 1, Iter: 11501, Reward pred: 1, Reward: 1, BF Gain pred: 189.30, BF Gain: 189.30
# Beam: 2, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 283.34, BF Gain: 283.34
# Beam: 3, Iter: 11501, Reward pred: 1, Reward: 1, BF Gain pred: 111.16, BF Gain: 111.16
# Training for 500 iteration for each Beam uses 210.6831386089325 seconds.
# Beam: 0, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 178.26, BF Gain: 178.26
# Beam: 1, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 187.39, BF Gain: 187.39
# Beam: 2, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 286.46, BF Gain: 286.46
# Beam: 3, Iter: 12001, Reward pred: 1, Reward: 1, BF Gain pred: 112.08, BF Gain: 112.08
# Training for 500 iteration for each Beam uses 212.0029170513153 seconds.
# Beam: 0, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 180.02, BF Gain: 180.02
# Beam: 1, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 111.28, BF Gain: 111.28
# Beam: 2, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 281.92, BF Gain: 281.92
# Beam: 3, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 113.15, BF Gain: 113.15
# Training for 500 iteration for each Beam uses 211.1166706085205 seconds.
# Beam: 0, Iter: 13001, Reward pred: 1, Reward: 1, BF Gain pred: 183.32, BF Gain: 183.32
# Beam: 1, Iter: 13001, Reward pred: 1, Reward: 1, BF Gain pred: 179.59, BF Gain: 179.59
# Beam: 2, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 301.48, BF Gain: 301.48
# Beam: 3, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 110.86, BF Gain: 110.86
# Training for 500 iteration for each Beam uses 211.3050401210785 seconds.
# Beam: 0, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 183.78, BF Gain: 183.78
# Beam: 1, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 183.45, BF Gain: 183.45
# Beam: 2, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 51.48, BF Gain: 51.48
# Beam: 3, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 109.52, BF Gain: 109.52
# Training for 500 iteration for each Beam uses 211.42252159118652 seconds.
# Beam: 0, Iter: 14001, Reward pred: 1, Reward: 1, BF Gain pred: 187.23, BF Gain: 187.23
# Beam: 1, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 190.95, BF Gain: 190.95
# Beam: 2, Iter: 14001, Reward pred: 1, Reward: 1, BF Gain pred: 302.84, BF Gain: 302.84
# Beam: 3, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 113.42, BF Gain: 113.42
# Training for 500 iteration for each Beam uses 211.11091828346252 seconds.
# Beam: 0, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 181.08, BF Gain: 181.08
# Beam: 1, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 183.63, BF Gain: 183.63
# Beam: 2, Iter: 14501, Reward pred: 1, Reward: 1, BF Gain pred: 307.15, BF Gain: 307.15
# Beam: 3, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 109.57, BF Gain: 109.57
# Training for 500 iteration for each Beam uses 210.61207795143127 seconds.
# Beam: 0, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 34.60, BF Gain: 34.60
# Beam: 1, Iter: 15001, Reward pred: -1, Reward: -1, BF Gain pred: 186.55, BF Gain: 186.55
# Beam: 2, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 299.88, BF Gain: 299.88
# Beam: 3, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 108.72, BF Gain: 108.72
# Training for 500 iteration for each Beam uses 210.27570486068726 seconds.
# Beam: 0, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 178.77, BF Gain: 178.77
# Beam: 1, Iter: 15501, Reward pred: -1, Reward: -1, BF Gain pred: 190.35, BF Gain: 190.35
# Beam: 2, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 288.67, BF Gain: 288.67
# Beam: 3, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 112.57, BF Gain: 112.57
# Training for 500 iteration for each Beam uses 210.62050938606262 seconds.
# Beam: 0, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 181.60, BF Gain: 181.60
# Beam: 1, Iter: 16001, Reward pred: 1, Reward: 1, BF Gain pred: 192.11, BF Gain: 192.11
# Beam: 2, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 1.58, BF Gain: 1.58
# Beam: 3, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 110.17, BF Gain: 110.17
# Training for 500 iteration for each Beam uses 212.56780648231506 seconds.
# Beam: 0, Iter: 16501, Reward pred: 1, Reward: 1, BF Gain pred: 182.88, BF Gain: 182.88
# Beam: 1, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 188.46, BF Gain: 188.46
# Beam: 2, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 27.45, BF Gain: 27.45
# Beam: 3, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 112.06, BF Gain: 112.06
# Training for 500 iteration for each Beam uses 211.71539497375488 seconds.
# Beam: 0, Iter: 17001, Reward pred: -1, Reward: -1, BF Gain pred: 181.70, BF Gain: 181.70
# Beam: 1, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 192.73, BF Gain: 192.73
# Beam: 2, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 41.49, BF Gain: 41.49
# Beam: 3, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 111.81, BF Gain: 111.81
# Training for 500 iteration for each Beam uses 212.20883011817932 seconds.
# Beam: 0, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 179.99, BF Gain: 179.99
# Beam: 1, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 186.22, BF Gain: 186.22
# Beam: 2, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 69.06, BF Gain: 69.06
# Beam: 3, Iter: 17501, Reward pred: 1, Reward: 1, BF Gain pred: 112.54, BF Gain: 112.54
# Training for 500 iteration for each Beam uses 212.31406664848328 seconds.
# Beam: 0, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 184.05, BF Gain: 184.05
# Beam: 1, Iter: 18001, Reward pred: -1, Reward: -1, BF Gain pred: 186.61, BF Gain: 186.61
# Beam: 2, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 131.83, BF Gain: 131.83
# Beam: 3, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 113.63, BF Gain: 113.63
# Training for 500 iteration for each Beam uses 211.83136296272278 seconds.
# Beam: 0, Iter: 18501, Reward pred: 1, Reward: 1, BF Gain pred: 183.35, BF Gain: 183.35
# Beam: 1, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 184.29, BF Gain: 184.29
# Beam: 2, Iter: 18501, Reward pred: 1, Reward: 1, BF Gain pred: 70.38, BF Gain: 70.38
# Beam: 3, Iter: 18501, Reward pred: 1, Reward: 1, BF Gain pred: 109.53, BF Gain: 109.53
# Training for 500 iteration for each Beam uses 210.90474700927734 seconds.
# Beam: 0, Iter: 19001, Reward pred: 1, Reward: 1, BF Gain pred: 181.20, BF Gain: 181.20
# Beam: 1, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 184.09, BF Gain: 184.09
# Beam: 2, Iter: 19001, Reward pred: 1, Reward: 1, BF Gain pred: 116.84, BF Gain: 116.84
# Beam: 3, Iter: 19001, Reward pred: 1, Reward: 1, BF Gain pred: 112.26, BF Gain: 112.26
# Training for 500 iteration for each Beam uses 210.40760445594788 seconds.
# Beam: 0, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 179.82, BF Gain: 179.82
# Beam: 1, Iter: 19501, Reward pred: 1, Reward: 1, BF Gain pred: 196.67, BF Gain: 196.67
# Beam: 2, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 102.88, BF Gain: 102.88
# Beam: 3, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 111.98, BF Gain: 111.98
# Training for 500 iteration for each Beam uses 209.49784517288208 seconds.
# Beam: 0, Iter: 20001, Reward pred: 1, Reward: 1, BF Gain pred: 184.54, BF Gain: 184.54
# Beam: 1, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 183.11, BF Gain: 183.11
# Beam: 2, Iter: 20001, Reward pred: 1, Reward: 1, BF Gain pred: 152.73, BF Gain: 152.73
# Beam: 3, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 110.34, BF Gain: 110.34
# Training for 500 iteration for each Beam uses 210.92853832244873 seconds.
# Beam: 0, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 178.70, BF Gain: 178.70
# Beam: 1, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 188.98, BF Gain: 188.98
# Beam: 2, Iter: 20501, Reward pred: 1, Reward: 1, BF Gain pred: 163.14, BF Gain: 163.14
# Beam: 3, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 110.39, BF Gain: 110.39
# Training for 500 iteration for each Beam uses 211.95511054992676 seconds.
# Beam: 0, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 73.47, BF Gain: 73.47
# Beam: 1, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 190.54, BF Gain: 190.54
# Beam: 2, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 176.23, BF Gain: 176.23
# Beam: 3, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 114.87, BF Gain: 114.87
# Training for 500 iteration for each Beam uses 210.5435552597046 seconds.
# Beam: 0, Iter: 21501, Reward pred: 1, Reward: 1, BF Gain pred: 176.92, BF Gain: 176.92
# Beam: 1, Iter: 21501, Reward pred: 1, Reward: 1, BF Gain pred: 189.15, BF Gain: 189.15
# Beam: 2, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 200.18, BF Gain: 200.18
# Beam: 3, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 110.76, BF Gain: 110.76
# Training for 500 iteration for each Beam uses 211.01841855049133 seconds.
# Beam: 0, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 178.41, BF Gain: 178.41
# Beam: 1, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 189.29, BF Gain: 189.29
# Beam: 2, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 228.62, BF Gain: 228.62
# Beam: 3, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 112.03, BF Gain: 112.03
# Training for 500 iteration for each Beam uses 211.46008014678955 seconds.
# Beam: 0, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 181.99, BF Gain: 181.99
# Beam: 1, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 186.40, BF Gain: 186.40
# Beam: 2, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 223.58, BF Gain: 223.58
# Beam: 3, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 111.08, BF Gain: 111.08
# Training for 500 iteration for each Beam uses 212.84037232398987 seconds.
# Beam: 0, Iter: 23001, Reward pred: 1, Reward: 1, BF Gain pred: 182.53, BF Gain: 182.53
# Beam: 1, Iter: 23001, Reward pred: 1, Reward: 1, BF Gain pred: 189.89, BF Gain: 189.89
# Beam: 2, Iter: 23001, Reward pred: 1, Reward: 1, BF Gain pred: 238.12, BF Gain: 238.12
# Beam: 3, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 111.18, BF Gain: 111.18
# Training for 500 iteration for each Beam uses 212.36248469352722 seconds.
# Beam: 0, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 181.41, BF Gain: 181.41
# Beam: 1, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 187.37, BF Gain: 187.37
# Beam: 2, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 234.43, BF Gain: 234.43
# Beam: 3, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 111.65, BF Gain: 111.65
# Training for 500 iteration for each Beam uses 211.25964212417603 seconds.
# Beam: 0, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 185.31, BF Gain: 185.31
# Beam: 1, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 187.32, BF Gain: 187.32
# Beam: 2, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 238.54, BF Gain: 238.54
# Beam: 3, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 111.21, BF Gain: 111.21
# Training for 500 iteration for each Beam uses 212.17493534088135 seconds.
# Beam: 0, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 182.48, BF Gain: 182.48
# Beam: 1, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 189.52, BF Gain: 189.52
# Beam: 2, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 239.14, BF Gain: 239.14
# Beam: 3, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 108.61, BF Gain: 108.61
# Training for 500 iteration for each Beam uses 211.34315872192383 seconds.
# Beam: 0, Iter: 25001, Reward pred: 1, Reward: 1, BF Gain pred: 181.86, BF Gain: 181.86
# Beam: 1, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 191.36, BF Gain: 191.36
# Beam: 2, Iter: 25001, Reward pred: 1, Reward: 1, BF Gain pred: 237.39, BF Gain: 237.39
# Beam: 3, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 112.99, BF Gain: 112.99
# Training for 500 iteration for each Beam uses 211.7311978340149 seconds.
# Beam: 0, Iter: 25501, Reward pred: 1, Reward: 1, BF Gain pred: 37.33, BF Gain: 37.33
# Beam: 1, Iter: 25501, Reward pred: 1, Reward: 1, BF Gain pred: 189.41, BF Gain: 189.41
# Beam: 2, Iter: 25501, Reward pred: 1, Reward: 1, BF Gain pred: 232.08, BF Gain: 232.08
# Beam: 3, Iter: 25501, Reward pred: -1, Reward: -1, BF Gain pred: 111.25, BF Gain: 111.25
# Training for 500 iteration for each Beam uses 212.35381627082825 seconds.
# Beam: 0, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 177.05, BF Gain: 177.05
# Beam: 1, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 190.94, BF Gain: 190.94
# Beam: 2, Iter: 26001, Reward pred: 1, Reward: 1, BF Gain pred: 236.89, BF Gain: 236.89
# Beam: 3, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 111.76, BF Gain: 111.76
# Training for 500 iteration for each Beam uses 210.42655968666077 seconds.
# Beam: 0, Iter: 26501, Reward pred: 1, Reward: 1, BF Gain pred: 183.86, BF Gain: 183.86
# Beam: 1, Iter: 26501, Reward pred: 1, Reward: 1, BF Gain pred: 187.90, BF Gain: 187.90
# Beam: 2, Iter: 26501, Reward pred: 1, Reward: 1, BF Gain pred: 237.77, BF Gain: 237.77
# Beam: 3, Iter: 26501, Reward pred: 1, Reward: 1, BF Gain pred: 113.37, BF Gain: 113.37
# Training for 500 iteration for each Beam uses 210.96622371673584 seconds.
# Beam: 0, Iter: 27001, Reward pred: 1, Reward: 1, BF Gain pred: 184.73, BF Gain: 184.73
# Beam: 1, Iter: 27001, Reward pred: -1, Reward: -1, BF Gain pred: 186.90, BF Gain: 186.90
# Beam: 2, Iter: 27001, Reward pred: 1, Reward: 1, BF Gain pred: 236.55, BF Gain: 236.55
# Beam: 3, Iter: 27001, Reward pred: 1, Reward: 1, BF Gain pred: 112.89, BF Gain: 112.89
# Training for 500 iteration for each Beam uses 210.91116976737976 seconds.
# Beam: 0, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 74.53, BF Gain: 74.53
# Beam: 1, Iter: 27501, Reward pred: -1, Reward: -1, BF Gain pred: 192.27, BF Gain: 192.27
# Beam: 2, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 235.73, BF Gain: 235.73
# Beam: 3, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 112.14, BF Gain: 112.14
# Training for 500 iteration for each Beam uses 214.19269585609436 seconds.
# Beam: 0, Iter: 28001, Reward pred: 1, Reward: 1, BF Gain pred: 179.57, BF Gain: 179.57
# Beam: 1, Iter: 28001, Reward pred: 1, Reward: 1, BF Gain pred: 194.10, BF Gain: 194.10
# Beam: 2, Iter: 28001, Reward pred: 1, Reward: 1, BF Gain pred: 233.76, BF Gain: 233.76
# Beam: 3, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 109.52, BF Gain: 109.52
# Training for 500 iteration for each Beam uses 214.84467720985413 seconds.
# Beam: 0, Iter: 28501, Reward pred: -1, Reward: -1, BF Gain pred: 184.37, BF Gain: 184.37
# Beam: 1, Iter: 28501, Reward pred: 1, Reward: 1, BF Gain pred: 185.00, BF Gain: 185.00
# Beam: 2, Iter: 28501, Reward pred: 1, Reward: 1, BF Gain pred: 231.70, BF Gain: 231.70
# Beam: 3, Iter: 28501, Reward pred: 1, Reward: 1, BF Gain pred: 112.43, BF Gain: 112.43
# Training for 500 iteration for each Beam uses 213.36619210243225 seconds.
# Beam: 0, Iter: 29001, Reward pred: 1, Reward: 1, BF Gain pred: 185.03, BF Gain: 185.03
# Beam: 1, Iter: 29001, Reward pred: 1, Reward: 1, BF Gain pred: 190.39, BF Gain: 190.39
# Beam: 2, Iter: 29001, Reward pred: 1, Reward: 1, BF Gain pred: 232.35, BF Gain: 232.35
# Beam: 3, Iter: 29001, Reward pred: 1, Reward: 1, BF Gain pred: 113.94, BF Gain: 113.94
# Training for 500 iteration for each Beam uses 211.82552289962769 seconds.
# Beam: 0, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 181.43, BF Gain: 181.43
# Beam: 1, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 190.58, BF Gain: 190.58
# Beam: 2, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 235.14, BF Gain: 235.14
# Beam: 3, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 113.55, BF Gain: 113.55
# Training for 500 iteration for each Beam uses 213.94324707984924 seconds.
# Beam: 0, Iter: 30001, Reward pred: 1, Reward: 1, BF Gain pred: 171.82, BF Gain: 171.82
# Beam: 1, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 191.53, BF Gain: 191.53
# Beam: 2, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 231.61, BF Gain: 231.61
# Beam: 3, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 113.53, BF Gain: 113.53
# Training for 500 iteration for each Beam uses 212.52743887901306 seconds.
# Beam: 0, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 181.54, BF Gain: 181.54
# Beam: 1, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 184.63, BF Gain: 184.63
# Beam: 2, Iter: 30501, Reward pred: 1, Reward: 1, BF Gain pred: 239.20, BF Gain: 239.20
# Beam: 3, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 111.90, BF Gain: 111.90
# Training for 500 iteration for each Beam uses 212.48779487609863 seconds.
# Beam: 0, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 184.54, BF Gain: 184.54
# Beam: 1, Iter: 31001, Reward pred: 1, Reward: 1, BF Gain pred: 188.67, BF Gain: 188.67
# Beam: 2, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 237.52, BF Gain: 237.52
# Beam: 3, Iter: 31001, Reward pred: 1, Reward: 1, BF Gain pred: 112.84, BF Gain: 112.84
# Training for 500 iteration for each Beam uses 211.48967933654785 seconds.
# Beam: 0, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 184.20, BF Gain: 184.20
# Beam: 1, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 188.55, BF Gain: 188.55
# Beam: 2, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 231.80, BF Gain: 231.80
# Beam: 3, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 114.17, BF Gain: 114.17
# Training for 500 iteration for each Beam uses 212.1158344745636 seconds.
# Beam: 0, Iter: 32001, Reward pred: 1, Reward: 1, BF Gain pred: 187.24, BF Gain: 187.24
# Beam: 1, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 194.40, BF Gain: 194.40
# Beam: 2, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 239.79, BF Gain: 239.79
# Beam: 3, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 113.27, BF Gain: 113.27
# Training for 500 iteration for each Beam uses 213.27209568023682 seconds.
# Beam: 0, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 184.66, BF Gain: 184.66
# Beam: 1, Iter: 32501, Reward pred: -1, Reward: -1, BF Gain pred: 189.88, BF Gain: 189.88
# Beam: 2, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 235.36, BF Gain: 235.36
# Beam: 3, Iter: 32501, Reward pred: -1, Reward: -1, BF Gain pred: 110.53, BF Gain: 110.53
# Training for 500 iteration for each Beam uses 211.88119053840637 seconds.
# Beam: 0, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 178.65, BF Gain: 178.65
# Beam: 1, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 193.93, BF Gain: 193.93
# Beam: 2, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 236.35, BF Gain: 236.35
# Beam: 3, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 114.01, BF Gain: 114.01
# Training for 500 iteration for each Beam uses 214.45905900001526 seconds.
# Beam: 0, Iter: 33501, Reward pred: 1, Reward: 1, BF Gain pred: 186.36, BF Gain: 186.36
# Beam: 1, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 194.87, BF Gain: 194.87
# Beam: 2, Iter: 33501, Reward pred: 1, Reward: 1, BF Gain pred: 240.11, BF Gain: 240.11
# Beam: 3, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 111.23, BF Gain: 111.23
# Training for 500 iteration for each Beam uses 212.4449646472931 seconds.
# Beam: 0, Iter: 34001, Reward pred: 1, Reward: 1, BF Gain pred: 182.87, BF Gain: 182.87
# Beam: 1, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 189.87, BF Gain: 189.87
# Beam: 2, Iter: 34001, Reward pred: 1, Reward: 1, BF Gain pred: 233.86, BF Gain: 233.86
# Beam: 3, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 111.95, BF Gain: 111.95
# Training for 500 iteration for each Beam uses 212.66915607452393 seconds.
# Beam: 0, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 180.27, BF Gain: 180.27
# Beam: 1, Iter: 34501, Reward pred: 1, Reward: 1, BF Gain pred: 197.35, BF Gain: 197.35
# Beam: 2, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 232.46, BF Gain: 232.46
# Beam: 3, Iter: 34501, Reward pred: 1, Reward: 1, BF Gain pred: 111.97, BF Gain: 111.97
# Training for 500 iteration for each Beam uses 211.9561891555786 seconds.
# Beam: 0, Iter: 35001, Reward pred: 1, Reward: 1, BF Gain pred: 182.98, BF Gain: 182.98
# Beam: 1, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 192.50, BF Gain: 192.50
# Beam: 2, Iter: 35001, Reward pred: 1, Reward: 1, BF Gain pred: 241.50, BF Gain: 241.50
# Beam: 3, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 111.58, BF Gain: 111.58
# Training for 500 iteration for each Beam uses 212.17301535606384 seconds.
# Beam: 0, Iter: 35501, Reward pred: 1, Reward: 1, BF Gain pred: 183.61, BF Gain: 183.61
# Beam: 1, Iter: 35501, Reward pred: 1, Reward: 1, BF Gain pred: 192.40, BF Gain: 192.40
# Beam: 2, Iter: 35501, Reward pred: 1, Reward: 1, BF Gain pred: 241.09, BF Gain: 241.09
# Beam: 3, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 109.00, BF Gain: 109.00
# Training for 500 iteration for each Beam uses 212.64063262939453 seconds.
# Beam: 0, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 180.67, BF Gain: 180.67
# Beam: 1, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 190.45, BF Gain: 190.45
# Beam: 2, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 233.77, BF Gain: 233.77
# Beam: 3, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 112.68, BF Gain: 112.68
# Training for 500 iteration for each Beam uses 211.23391819000244 seconds.
# Beam: 0, Iter: 36501, Reward pred: 1, Reward: 1, BF Gain pred: 181.38, BF Gain: 181.38
# Beam: 1, Iter: 36501, Reward pred: 1, Reward: 1, BF Gain pred: 187.23, BF Gain: 187.23
# Beam: 2, Iter: 36501, Reward pred: 1, Reward: 1, BF Gain pred: 231.86, BF Gain: 231.86
# Beam: 3, Iter: 36501, Reward pred: -1, Reward: -1, BF Gain pred: 111.75, BF Gain: 111.75
# Training for 500 iteration for each Beam uses 211.7393901348114 seconds.
# Beam: 0, Iter: 37001, Reward pred: -1, Reward: -1, BF Gain pred: 177.46, BF Gain: 177.46
# Beam: 1, Iter: 37001, Reward pred: -1, Reward: -1, BF Gain pred: 187.56, BF Gain: 187.56
# Beam: 2, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 234.94, BF Gain: 234.94
# Beam: 3, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 112.27, BF Gain: 112.27
# Training for 500 iteration for each Beam uses 211.32632112503052 seconds.
# Beam: 0, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 182.45, BF Gain: 182.45
# Beam: 1, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 196.41, BF Gain: 196.41
# Beam: 2, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 238.15, BF Gain: 238.15
# Beam: 3, Iter: 37501, Reward pred: 1, Reward: 1, BF Gain pred: 113.17, BF Gain: 113.17
# Training for 500 iteration for each Beam uses 210.73530650138855 seconds.
# Beam: 0, Iter: 38001, Reward pred: 1, Reward: 1, BF Gain pred: 185.16, BF Gain: 185.16
# Beam: 1, Iter: 38001, Reward pred: 1, Reward: 1, BF Gain pred: 188.47, BF Gain: 188.47
# Beam: 2, Iter: 38001, Reward pred: 1, Reward: 1, BF Gain pred: 239.77, BF Gain: 239.77
# Beam: 3, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 111.79, BF Gain: 111.79
# Training for 500 iteration for each Beam uses 215.14089465141296 seconds.
# Beam: 0, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 181.24, BF Gain: 181.24
# Beam: 1, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 193.18, BF Gain: 193.18
# Beam: 2, Iter: 38501, Reward pred: 1, Reward: 1, BF Gain pred: 228.83, BF Gain: 228.83
# Beam: 3, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 111.50, BF Gain: 111.50
# Training for 500 iteration for each Beam uses 211.19089603424072 seconds.
# Beam: 0, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 181.11, BF Gain: 181.11
# Beam: 1, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 188.57, BF Gain: 188.57
# Beam: 2, Iter: 39001, Reward pred: 1, Reward: 1, BF Gain pred: 236.46, BF Gain: 236.46
# Beam: 3, Iter: 39001, Reward pred: 1, Reward: 1, BF Gain pred: 113.60, BF Gain: 113.60
# Training for 500 iteration for each Beam uses 211.85668087005615 seconds.
# Beam: 0, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 116.94, BF Gain: 116.94
# Beam: 1, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 188.62, BF Gain: 188.62
# Beam: 2, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 230.01, BF Gain: 230.01
# Beam: 3, Iter: 39501, Reward pred: 1, Reward: 1, BF Gain pred: 113.81, BF Gain: 113.81
# Training for 500 iteration for each Beam uses 211.3415286540985 seconds.
# Beam: 0, Iter: 40001, Reward pred: 1, Reward: 1, BF Gain pred: 172.84, BF Gain: 172.84
# Beam: 1, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 186.91, BF Gain: 186.91
# Beam: 2, Iter: 40001, Reward pred: 1, Reward: 1, BF Gain pred: 231.43, BF Gain: 231.43
# Beam: 3, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 112.36, BF Gain: 112.36
# Training for 500 iteration for each Beam uses 209.4819221496582 seconds.

# %%
import numpy as np
import scipy.io as scio

num_ant = 32
num_beam = 4
results = np.empty((num_beam, 2*num_ant))

path = './beams/'

for beam_id in range(num_beam):
    fname = 'beams_' + str(beam_id) + '_max.txt'
    with open(path + fname, 'r') as f:
        lines = f.readlines()
        last_line = lines[-1]
        results[beam_id, :] = np.fromstring(last_line.replace("\n", ""), sep=',').reshape(1, -1)

results = (1 / np.sqrt(num_ant)) * (results[:, ::2] + 1j * results[:, 1::2])

scio.savemat('beam_codebook.mat', {'beams': results})

# %%
from matplotlib import pyplot as plt
colors = ['b','r','g','c']
plt.figure(figsize=(12, 8))
plt.title(f'Best beamforming gain')
plt.xlabel('Beam_framing_gain')   
for beam_id, color in enumerate(colors):
    gain_record = np.array(env_list[beam_id].gain_history[1:])/options['num_ant']
    np.save(f'beam_{beam_id}_gain_records',gain_record)
    plt.plot(gain_record, label=f'Beam_{beam_id}',color=color)
    EGC = env_list[beam_id].compute_EGC()/options['num_ant']
    
    n_iterations = options['num_loop']*train_opt['num_iter']
    plt.plot([EGC]*n_iterations,linestyle='dashed',color=color,label=f'EGC Beam_{beam_id}')
plt.legend(loc="lower right")  
plt.show()

# %%
def duplicate_n_times(lst, n):
    duplicated_list = []
    for item in lst:
        duplicated_list.extend([item] * n)
    return duplicated_list
accuracy = 0
for beam_id in range(4):
    egc = duplicate_n_times(env_list[beam_id].EGC_history,100)
    egc=np.array(egc)/options['num_ant']  
    gain_record = np.array(env_list[beam_id].gain_history[1:])/options['num_ant']
    perc = (gain_record)/egc
    accuracy +=perc[-1]
    perc = round(perc[-1]*100)
    print(f'beam_{beam_id} reached {perc}% of EGC upperbound')
print(f'Mean EGC reached for all users {round(accuracy*100/4)} %')
# Out:
# beam_0 reached 90% of EGC upperbound
# beam_1 reached 62% of EGC upperbound
# beam_2 reached 81% of EGC upperbound
# beam_3 reached 86% of EGC upperbound
# Mean EGC reached for all users 80 %
