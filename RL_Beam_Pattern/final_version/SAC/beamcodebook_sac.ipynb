# %%
# !git clone https://github.com/YuZhang-GitHub/Codebook_Learning_RL.git
# Out:
# Cloning into 'Codebook_Learning_RL'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 77 (delta 5), reused 0 (delta 0), pack-reused 59
# Receiving objects: 100% (77/77), 14.41 MiB | 31.34 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# !pip install pfrl
# Out:
# Collecting pfrl
#   Downloading pfrl-0.4.0.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.6/112.6 kB 1.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pfrl) (2.0.0)
# Requirement already satisfied: gym>=0.9.7 in /opt/conda/lib/python3.10/site-packages (from pfrl) (0.26.2)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/lib/python3.10/site-packages (from pfrl) (1.23.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from pfrl) (9.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from pfrl) (3.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (0.0.8)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.3.0->pfrl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.3.0->pfrl) (1.3.0)
# Building wheels for collected packages: pfrl
#   Building wheel for pfrl (setup.py) ... done
#   Created wheel for pfrl: filename=pfrl-0.4.0-py3-none-any.whl size=155465 sha256=cf60010cd823e83ec59891c2206022933a96424fa3df53ac3aed3c9e97a25994
#   Stored in directory: /root/.cache/pip/wheels/22/4a/0f/a87cd1ae925086eb3a1b8759f620fcf48e47939fb082946c3b
# Successfully built pfrl
# Installing collected packages: pfrl
# Successfully installed pfrl-0.4.0

# %%
# from Codebook_Learning_RL import DDPG_classes

# %%
import os
os.chdir('/kaggle/working/Codebook_Learning_RL')
print(os.getcwd())
# Out:
# /kaggle/working/Codebook_Learning_RL

# %%
import pfrl
import os
import time
import torch
import numpy as np
import copy
import pickle
from torch import nn
from torch import distributions
from scipy.optimize import linear_sum_assignment
from DataPrep import dataPrep
from env_ddpg import envCB
from clustering import KMeans_only
from function_lib import bf_gain_cal, corr_mining
from DDPG_classes import OUNoise
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class envCB_(envCB):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.gain_history = [0]
        self.EGC_history = []
    def compute_EGC(self):
        ch_r = torch.Tensor.cpu(self.ch.clone()).numpy()[:, :self.num_ant]
        ch_i = torch.Tensor.cpu(self.ch.clone()).numpy()[:, self.num_ant:]
        radius = np.sqrt(np.square(ch_r) + np.square(ch_i))
        gain_opt = np.mean(np.square(np.sum(radius, axis=1)))
        return gain_opt

# %%
options = {
        'gpu_idx': 0,
        'num_ant': 32,
        'num_bits': 4,
        'num_NNs': 4,  # codebook size
        'ch_sample_ratio': 0.5,
        'num_loop': 400,  # outer loop
        'target_update': 3,
        'path': './grid1101-1400.mat',
        'clustering_mode': 'random',
    }

train_opt = {
        'state': 0,
        'best_state': 0,
        'num_iter': 100,  # inner loop
        'tau': 1e-2,
        'overall_iter': 1,
        'replay_memory': [],
        'replay_memory_size': 8192,
        'minibatch_size': 1024,
        'gamma': 0,
        'gpu':0
    }
if not os.path.exists('beams/'):
    os.mkdir('beams/')

ch = dataPrep(options['path'])
ch = np.concatenate((ch[:, :options['num_ant']],
                     ch[:, int(ch.shape[1] / 2):int(ch.shape[1] / 2) + options['num_ant']]), axis=1)
with torch.cuda.device(options['gpu_idx']):
    u_classifier, sensing_beam = KMeans_only(ch, options['num_NNs'], n_bit=options['num_bits'], n_rand_beam=30)
    np.save('sensing_beam.npy', sensing_beam)
    sensing_beam = torch.from_numpy(sensing_beam).float().cuda()

    filename = 'kmeans_model.sav'
    pickle.dump(u_classifier, open(filename, 'wb'))

    # Quantization settings
    options['num_ph'] = 2 ** options['num_bits']
    options['multi_step'] = torch.from_numpy(
        np.linspace(int(-(options['num_ph'] - 2) / 2),
                    int(options['num_ph'] / 2),
                    num=options['num_ph'],
                    endpoint=True)).type(dtype=torch.float32).reshape(1, -1).cuda()
    options['pi'] = torch.tensor(np.pi).cuda()
    options['ph_table'] = (2 * options['pi']) / options['num_ph'] * options['multi_step']
    options['ph_table'].cuda()
    options['ph_table_rep'] = options['ph_table'].repeat(options['num_ant'], 1)
    actor_net_list = []
    critic_net_list = []
    actor_net_t_list = []
    critic_net_t_list = []
    ounoise_list = []
    env_list = []
    train_opt_list = []
    agent_list=[]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from pfrl.utils.batch_states import batch_states
def batch_experiences_(experiences, device, phi, gamma, batch_states=batch_states):
    """Takes a batch of k experiences each of which contains j

    consecutive transitions and vectorizes them, where j is between 1 and n.

    Args:
        experiences: list of experiences. Each experience is a list
            containing between 1 and n dicts containing
              - state (object): State
              - action (object): Action
              - reward (float): Reward
              - is_state_terminal (bool): True iff next state is terminal
              - next_state (object): Next state
        device : GPU or CPU the tensor should be placed on
        phi : Preprocessing function
        gamma: discount factor
        batch_states: function that converts a list to a batch
    Returns:
        dict of batched transitions
    """

    batch_exp = {
        "state": batch_states([elem[0]["state"] for elem in experiences], device, phi),
        "action": torch.as_tensor(
            np.array([elem[0]["action"] for elem in experiences]), device=device
        ),
        "reward": torch.as_tensor(
            [
                sum((gamma**i) * exp[i]["reward"] for i in range(len(exp)))
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "next_state": batch_states(
            [elem[-1]["next_state"] for elem in experiences], device, phi
        ),
        "is_state_terminal": torch.as_tensor(
            [
                any(transition["is_state_terminal"] for transition in exp)
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "discount": torch.as_tensor(
            [(gamma ** len(elem)) for elem in experiences],
            dtype=torch.float32,
            device=device,
        ),
    }
    if all(elem[-1]["next_action"] is not None for elem in experiences):
        batch_exp["next_action"] = torch.as_tensor(
            [elem[-1]["next_action"] for elem in experiences], device=device
        )
    return batch_exp

from pfrl.agents.ddpg import DDPG
class DDPG_(DDPG):
    def update(self, experiences, errors_out=None):
        """Update the model from experiences"""

        batch = batch_experiences_(experiences, self.device, self.phi, self.gamma)

        self.critic_optimizer.zero_grad()
        self.compute_critic_loss(batch).backward()
        self.critic_optimizer.step()

        self.actor_optimizer.zero_grad()
        self.compute_actor_loss(batch).backward()
        self.actor_optimizer.step()

        self.n_updates += 1

# %%
import pfrl
from pfrl import experiments, explorers, replay_buffers, utils
from pfrl.agents.ddpg import DDPG
from pfrl.nn import BoundByTanh, ConcatObsAndAction
from pfrl.policies import DeterministicHead
from pfrl.explorers import Greedy

def create_agent(state_size,action_size,train_options,gpu=0):
    
    #critic_network
    q_func = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    #actor_network
    policy = nn.Sequential(
        nn.Linear(state_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, action_size),
        BoundByTanh(low= -torch.tensor(np.pi).float(), high= torch.tensor(np.pi).float()),
        DeterministicHead(),
    )
    
    opt_a = torch.optim.Adam(policy.parameters(), lr=1e-3, weight_decay=1e-3)
    opt_c = torch.optim.Adam(q_func.parameters(), lr=1e-3, weight_decay=1e-2)
    rbuf = replay_buffers.ReplayBuffer(train_options['replay_memory_size'])
    
    explorer =  Greedy()
    
    agent = DDPG_(
        policy,
        q_func,
        opt_a,
        opt_c,
        rbuf,
        gamma=train_options['gamma'],
        explorer = explorer,
        replay_start_size=train_options['minibatch_size'],
        target_update_method="soft",
        target_update_interval=options['target_update'],
        update_interval=1,
        soft_update_tau= train_opt['tau'],
        n_times_update=1,
        gpu=gpu,
        minibatch_size=train_options['minibatch_size'],
    )
    
    return agent

# %%
def create_agent_sac(state_size,action_size,train_options,gpu=0):
    def squashed_diagonal_gaussian_head(x):
        assert x.shape[-1] == action_size * 2
        mean, log_scale = torch.chunk(x, 2, dim=2)
        log_scale = torch.clamp(log_scale, -20.0, 2.0)
        var = torch.exp(log_scale * 2)
        base_distribution = distributions.Independent(
            distributions.Normal(loc=mean, scale=torch.sqrt(var)), 1
        )
        # cache_size=1 is required for numerical stability
        return distributions.transformed_distribution.TransformedDistribution(
            base_distribution, [distributions.transforms.TanhTransform(cache_size=1),
                                distributions.transforms.AffineTransform(0, torch.pi, event_dim=0, cache_size=1)]
        )

    #critic_networks
    q_func_1 = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    q_func_2 = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    
    #actor_network
    policy = nn.Sequential(
        nn.Linear(state_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, action_size* 2),
        pfrl.nn.lmbda.Lambda(squashed_diagonal_gaussian_head),
    )


    opt_a = torch.optim.Adam(policy.parameters(), lr=1e-3, weight_decay=1e-3)
    opt_c_1 = torch.optim.Adam(q_func_1.parameters(), lr=1e-3, weight_decay=1e-2)
    opt_c_2 = torch.optim.Adam(q_func_2.parameters(), lr=1e-3, weight_decay=1e-2)
    
    rbuf = replay_buffers.ReplayBuffer(train_options['replay_memory_size'])
    
    agent = pfrl.agents.SoftActorCritic(
        policy,
        q_func_1,
        q_func_2,
        opt_a,
        opt_c_1,
        opt_c_2,
        rbuf,
        gamma=train_options['gamma'],
        update_interval=1,
        replay_start_size=train_options['minibatch_size'],
        gpu=gpu,
        soft_update_tau= train_opt['tau'],
        minibatch_size = train_options['minibatch_size'],
        entropy_target=-action_size,
        temperature_optimizer_lr=1e-3,
    )
    return agent

# %%
def train(
          env,
          options,
          train_options,
          agent,
          ounoise,
          beam_id):
    
#     action_pred_noisy = ounoise.get_action(action_pred,
#                                                t=train_options['overall_iter'])
    CB_Env = env   
    if train_options['overall_iter'] == 1:
        state = torch.zeros((1, options['num_ant'])).float().cuda()
        print('Initial State Activated.')
    else:
        state = train_options['state']
    
    
    #training_loop
    iteration = 0
    num_of_iter = train_options['num_iter']  
    while iteration < num_of_iter:

        
        action = agent.act(state)
#         print(type(agent.batch_last_action),agent.batch_last_action)
        action = torch.Tensor(action).to('cuda')
        reward_pred, bf_gain_pred, action_quant_pred, state_1_pred = CB_Env.get_reward(action)
        reward_pred = torch.from_numpy(reward_pred).float().cuda()
        
        action_pred_noisy = action
        mat_dist = torch.abs(action_pred_noisy.reshape(options['num_ant'], 1) - options['ph_table_rep'])
        action_quant = options['ph_table_rep'][range(options['num_ant']), torch.argmin(mat_dist, dim=1)].reshape(1, -1)
   
        state_1, reward, bf_gain, terminal = CB_Env.step(action_quant)
        reward = torch.from_numpy(reward).float().cuda()
        action = action_quant.reshape((1, -1)).float().cuda()
        
        
#         print(type(action_quant_pred.cpu().numpy()),action_quant_pred.cpu().numpy().shape)
#         print(type(action.cpu().numpy()),action.cpu().numpy().shape)
        agent.replay_buffer.append(
                    state=state,
                    action=action_quant_pred.cpu().numpy(),
                    reward=reward_pred,
                    next_state=state_1_pred,
                    next_action=None,
                    is_state_terminal=terminal,
                    env_id=0,
                )
#         print(agent.batch_last_action,agent.batch_last_action[0].shape)
        agent.batch_last_action = [action.cpu().numpy()] #because the critic is expecting quantizazed actions
        agent.observe(state_1, reward, terminal, False)

        
        iteration += 1
        train_options['overall_iter'] += 1
        state = state_1
        
        new_gain = torch.Tensor.cpu(CB_Env.achievement).detach().numpy().reshape((1, 1))
        max_previous_gain = max(CB_Env.gain_record)
        if new_gain > max_previous_gain:
            CB_Env.gain_history.append(float(new_gain))                   
        else:
            CB_Env.gain_history.append(float(max_previous_gain))
            
    train_options['state'] = state  # used for the next loop
    train_options['best_state'] = CB_Env.best_bf_vec  # used for clustering and assignment
    if (train_options['overall_iter']-1)%500==0:
#         print(
#             "Beam: %d, Iter: %d, Reward: %d, BF Gain: %.2f" % \
#             (beam_id, 
#              train_options['overall_iter'],
#              int(torch.Tensor.cpu(reward).numpy().squeeze()),
#              torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))
        print(
            "Beam: %d, Iter: %d, Reward pred: %d, Reward: %d, BF Gain pred: %.2f, BF Gain: %.2f" % \
            (beam_id, train_options['overall_iter'],
             int(torch.Tensor.cpu(reward_pred).numpy().squeeze()),
             int(torch.Tensor.cpu(reward).numpy().squeeze()),
             torch.Tensor.cpu(bf_gain_pred.detach()).numpy().squeeze(),
             torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))      
    
    return train_options

# %%
for beam_id in range(options['num_NNs']):
    ounoise_list.append(OUNoise((1, options['num_ant'])))
    env_list.append(envCB_(ch, options['num_ant'], options['num_bits'], beam_id, options))
    train_opt_list.append(copy.deepcopy(train_opt))
    agent = create_agent_sac(options['num_ant'],options['num_ant'],train_opt_list[beam_id],gpu=train_opt['gpu'])
    agent_list.append(agent)
    ounoise_list.append(OUNoise((1, options['num_ant'])))
# Out:
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094

# %%
with torch.cuda.device(options['gpu_idx']):
    for sample_id in range(options['num_loop']):

        # ---------- Sampling ---------- #
        n_sample = int(ch.shape[0] * options['ch_sample_ratio'])
        ch_sample_id = np.random.permutation(ch.shape[0])[0:n_sample]
        ch_sample = torch.from_numpy(ch[ch_sample_id, :]).float().cuda()

        # ---------- Clustering ---------- #
    #     start_time = time.time()

        bf_mat_sample = bf_gain_cal(sensing_beam, ch_sample)
        # print("Clustering -1 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()
        f_matrix = corr_mining(bf_mat_sample)
        f_matrix_np = torch.Tensor.cpu(f_matrix).numpy()
        # print("Clustering 0 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()
        labels = u_classifier.predict(np.transpose(f_matrix_np).astype(float))

        # print("Clustering 1 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()

        user_group = []  # order: clusters
        ch_group = []  # order: clusters
        for ii in range(options['num_NNs']):
            user_group.append(np.where(labels == ii)[0].tolist())
            ch_group.append(ch_sample[user_group[ii], :])

    #     print("Clustering 2 uses %s seconds." % (time.time() - start_time))

        # ---------- Assignment ---------- #
    #     start_time = time.time()

        # best_state matrix
        best_beam_mtx = torch.zeros((options['num_NNs'], 2 * options['num_ant'])).float().cuda()
        for pp in range(options['num_NNs']):
            best_beam_mtx[pp, :] = env_list[pp].best_bf_vec
        gain_mtx = bf_gain_cal(best_beam_mtx, ch_sample)  # (n_beam, n_user)
        for ii in range(options['num_NNs']):
            if ii == 0:
                cost_mtx = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
            else:
                sub = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
                cost_mtx = torch.cat((cost_mtx, sub), dim=1)
        cost_mtx = -torch.Tensor.cpu(cost_mtx).numpy()
        row_ind, col_ind = linear_sum_assignment(cost_mtx)
        assignment_record = dict(zip(row_ind.tolist(), col_ind.tolist()))  # key: network, value: cluster
        for ii in range(options['num_NNs']):
            env_list[ii].ch = ch_group[assignment_record[ii]]
            env_list[ii].EGC_history.append(env_list[ii].compute_EGC())
    #     print("Assignment uses %s seconds." % (time.time() - start_time))
        if (train_opt_list[beam_id]['overall_iter']-1)%500==0 or train_opt_list[beam_id]['overall_iter']==1:
            start_time = time.time()
        for beam_id in range(options['num_NNs']):
            train_opt_list[beam_id] = train(env_list[beam_id],options, train_opt_list[beam_id],agent_list[beam_id],ounoise_list[beam_id], beam_id)
        if (train_opt_list[beam_id]['overall_iter']-1)%500==0: 
            print("Training for 500 iteration for each Beam uses %s seconds." % (time.time() - start_time))
# Out:
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Beam: 0, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 5.88, BF Gain: 5.88
# Beam: 1, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 17.69, BF Gain: 17.69
# Beam: 2, Iter: 501, Reward pred: -1, Reward: -1, BF Gain pred: 10.20, BF Gain: 10.20
# Beam: 3, Iter: 501, Reward pred: -1, Reward: -1, BF Gain pred: 2.23, BF Gain: 2.23
# Training for 500 iteration for each Beam uses 11.999882459640503 seconds.
# /opt/conda/lib/python3.10/site-packages/pfrl/replay_buffer.py:180: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /usr/local/src/pytorch/torch/csrc/utils/tensor_new.cpp:245.)
#   "action": torch.as_tensor(
# Beam: 0, Iter: 1001, Reward pred: 1, Reward: 1, BF Gain pred: 8.38, BF Gain: 8.38
# Beam: 1, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 5.11, BF Gain: 5.11
# Beam: 2, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 4.83, BF Gain: 4.83
# Beam: 3, Iter: 1001, Reward pred: 1, Reward: 1, BF Gain pred: 11.45, BF Gain: 11.45
# Training for 500 iteration for each Beam uses 142.00617837905884 seconds.
# Beam: 0, Iter: 1501, Reward pred: 1, Reward: 1, BF Gain pred: 3.32, BF Gain: 3.32
# Beam: 1, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 11.67, BF Gain: 11.67
# Beam: 2, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 3.33, BF Gain: 3.33
# Beam: 3, Iter: 1501, Reward pred: 1, Reward: 1, BF Gain pred: 1.91, BF Gain: 1.91
# Training for 500 iteration for each Beam uses 145.1819109916687 seconds.
# Beam: 0, Iter: 2001, Reward pred: -1, Reward: -1, BF Gain pred: 5.38, BF Gain: 5.38
# Beam: 1, Iter: 2001, Reward pred: -1, Reward: -1, BF Gain pred: 9.07, BF Gain: 9.07
# Beam: 2, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 10.09, BF Gain: 10.09
# Beam: 3, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 10.52, BF Gain: 10.52
# Training for 500 iteration for each Beam uses 146.45984315872192 seconds.
# Beam: 0, Iter: 2501, Reward pred: 1, Reward: 1, BF Gain pred: 18.48, BF Gain: 18.48
# Beam: 1, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 2.96, BF Gain: 2.96
# Beam: 2, Iter: 2501, Reward pred: 1, Reward: 1, BF Gain pred: 19.94, BF Gain: 19.94
# Beam: 3, Iter: 2501, Reward pred: 1, Reward: 1, BF Gain pred: 2.76, BF Gain: 2.76
# Training for 500 iteration for each Beam uses 146.63104939460754 seconds.
# Beam: 0, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 5.85, BF Gain: 5.85
# Beam: 1, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 31.62, BF Gain: 31.62
# Beam: 2, Iter: 3001, Reward pred: -1, Reward: -1, BF Gain pred: 12.20, BF Gain: 12.20
# Beam: 3, Iter: 3001, Reward pred: -1, Reward: -1, BF Gain pred: 3.33, BF Gain: 3.33
# Training for 500 iteration for each Beam uses 149.16336631774902 seconds.
# Beam: 0, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 2.82, BF Gain: 2.82
# Beam: 1, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 10.18, BF Gain: 10.18
# Beam: 2, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 26.83, BF Gain: 26.83
# Beam: 3, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 1.01, BF Gain: 1.01
# Training for 500 iteration for each Beam uses 152.3556900024414 seconds.
# Beam: 0, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 22.29, BF Gain: 22.29
# Beam: 1, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 22.32, BF Gain: 22.32
# Beam: 2, Iter: 4001, Reward pred: -1, Reward: -1, BF Gain pred: 4.26, BF Gain: 4.26
# Beam: 3, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 11.68, BF Gain: 11.68
# Training for 500 iteration for each Beam uses 149.89286041259766 seconds.
# Beam: 0, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 13.05, BF Gain: 13.05
# Beam: 1, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 27.55, BF Gain: 27.55
# Beam: 2, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 7.07, BF Gain: 7.07
# Beam: 3, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 8.93, BF Gain: 8.93
# Training for 500 iteration for each Beam uses 151.42972111701965 seconds.
# Beam: 0, Iter: 5001, Reward pred: 1, Reward: 1, BF Gain pred: 35.94, BF Gain: 35.94
# Beam: 1, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 12.15, BF Gain: 12.15
# Beam: 2, Iter: 5001, Reward pred: 1, Reward: 1, BF Gain pred: 17.71, BF Gain: 17.71
# Beam: 3, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 3.27, BF Gain: 3.27
# Training for 500 iteration for each Beam uses 151.21591329574585 seconds.
# Beam: 0, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 15.81, BF Gain: 15.81
# Beam: 1, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 57.75, BF Gain: 57.75
# Beam: 2, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 56.38, BF Gain: 56.38
# Beam: 3, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 6.68, BF Gain: 6.68
# Training for 500 iteration for each Beam uses 150.08581447601318 seconds.
# Beam: 0, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 16.15, BF Gain: 16.15
# Beam: 1, Iter: 6001, Reward pred: 1, Reward: 1, BF Gain pred: 87.75, BF Gain: 87.75
# Beam: 2, Iter: 6001, Reward pred: 1, Reward: 1, BF Gain pred: 57.84, BF Gain: 57.84
# Beam: 3, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 34.85, BF Gain: 34.85
# Training for 500 iteration for each Beam uses 150.34010338783264 seconds.
# Beam: 0, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 94.94, BF Gain: 94.94
# Beam: 1, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 83.79, BF Gain: 83.79
# Beam: 2, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 134.57, BF Gain: 134.57
# Beam: 3, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 44.44, BF Gain: 44.44
# Training for 500 iteration for each Beam uses 149.70329546928406 seconds.
# Beam: 0, Iter: 7001, Reward pred: 1, Reward: 1, BF Gain pred: 105.93, BF Gain: 105.93
# Beam: 1, Iter: 7001, Reward pred: 1, Reward: 1, BF Gain pred: 144.35, BF Gain: 144.35
# Beam: 2, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 124.02, BF Gain: 124.02
# Beam: 3, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 62.21, BF Gain: 62.21
# Training for 500 iteration for each Beam uses 150.49530506134033 seconds.
# Beam: 0, Iter: 7501, Reward pred: -1, Reward: -1, BF Gain pred: 130.17, BF Gain: 130.17
# Beam: 1, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 180.67, BF Gain: 180.67
# Beam: 2, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 200.92, BF Gain: 200.92
# Beam: 3, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 87.49, BF Gain: 87.49
# Training for 500 iteration for each Beam uses 150.21798586845398 seconds.
# Beam: 0, Iter: 8001, Reward pred: 1, Reward: 1, BF Gain pred: 143.03, BF Gain: 143.03
# Beam: 1, Iter: 8001, Reward pred: 1, Reward: 1, BF Gain pred: 200.14, BF Gain: 200.14
# Beam: 2, Iter: 8001, Reward pred: 1, Reward: 1, BF Gain pred: 191.43, BF Gain: 191.43
# Beam: 3, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 99.96, BF Gain: 99.96
# Training for 500 iteration for each Beam uses 153.5995008945465 seconds.
# Beam: 0, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 147.93, BF Gain: 147.93
# Beam: 1, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 193.42, BF Gain: 193.42
# Beam: 2, Iter: 8501, Reward pred: 1, Reward: 1, BF Gain pred: 223.33, BF Gain: 223.33
# Beam: 3, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 103.53, BF Gain: 103.53
# Training for 500 iteration for each Beam uses 149.86534452438354 seconds.
# Beam: 0, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 153.87, BF Gain: 153.87
# Beam: 1, Iter: 9001, Reward pred: 1, Reward: 1, BF Gain pred: 226.97, BF Gain: 226.97
# Beam: 2, Iter: 9001, Reward pred: 1, Reward: 1, BF Gain pred: 228.76, BF Gain: 228.76
# Beam: 3, Iter: 9001, Reward pred: 1, Reward: 1, BF Gain pred: 109.57, BF Gain: 109.57
# Training for 500 iteration for each Beam uses 152.3929557800293 seconds.
# Beam: 0, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 156.97, BF Gain: 156.97
# Beam: 1, Iter: 9501, Reward pred: 1, Reward: 1, BF Gain pred: 229.98, BF Gain: 229.98
# Beam: 2, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 230.93, BF Gain: 230.93
# Beam: 3, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 109.69, BF Gain: 109.69
# Training for 500 iteration for each Beam uses 150.4337854385376 seconds.
# Beam: 0, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 159.32, BF Gain: 159.32
# Beam: 1, Iter: 10001, Reward pred: 1, Reward: 1, BF Gain pred: 233.94, BF Gain: 233.94
# Beam: 2, Iter: 10001, Reward pred: 1, Reward: 1, BF Gain pred: 236.45, BF Gain: 236.45
# Beam: 3, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 110.78, BF Gain: 110.78
# Training for 500 iteration for each Beam uses 149.4315915107727 seconds.
# Beam: 0, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 158.73, BF Gain: 158.73
# Beam: 1, Iter: 10501, Reward pred: 1, Reward: 1, BF Gain pred: 227.99, BF Gain: 227.99
# Beam: 2, Iter: 10501, Reward pred: 1, Reward: 1, BF Gain pred: 239.39, BF Gain: 239.39
# Beam: 3, Iter: 10501, Reward pred: 1, Reward: 1, BF Gain pred: 109.62, BF Gain: 109.62
# Training for 500 iteration for each Beam uses 149.724458694458 seconds.
# Beam: 0, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 164.84, BF Gain: 164.84
# Beam: 1, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 228.93, BF Gain: 228.93
# Beam: 2, Iter: 11001, Reward pred: 1, Reward: 1, BF Gain pred: 243.70, BF Gain: 243.70
# Beam: 3, Iter: 11001, Reward pred: 1, Reward: 1, BF Gain pred: 113.22, BF Gain: 113.22
# Training for 500 iteration for each Beam uses 149.57999181747437 seconds.
# Beam: 0, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 163.53, BF Gain: 163.53
# Beam: 1, Iter: 11501, Reward pred: 1, Reward: 1, BF Gain pred: 241.65, BF Gain: 241.65
# Beam: 2, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 238.93, BF Gain: 238.93
# Beam: 3, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 112.89, BF Gain: 112.89
# Training for 500 iteration for each Beam uses 149.72659873962402 seconds.
# Beam: 0, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 162.71, BF Gain: 162.71
# Beam: 1, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 243.74, BF Gain: 243.74
# Beam: 2, Iter: 12001, Reward pred: 1, Reward: 1, BF Gain pred: 242.59, BF Gain: 242.59
# Beam: 3, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 114.01, BF Gain: 114.01
# Training for 500 iteration for each Beam uses 149.21171069145203 seconds.
# Beam: 0, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 165.58, BF Gain: 165.58
# Beam: 1, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 241.77, BF Gain: 241.77
# Beam: 2, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 245.98, BF Gain: 245.98
# Beam: 3, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 113.62, BF Gain: 113.62
# Training for 500 iteration for each Beam uses 148.90984773635864 seconds.
# Beam: 0, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 163.14, BF Gain: 163.14
# Beam: 1, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 241.41, BF Gain: 241.41
# Beam: 2, Iter: 13001, Reward pred: 1, Reward: 1, BF Gain pred: 242.76, BF Gain: 242.76
# Beam: 3, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 112.49, BF Gain: 112.49
# Training for 500 iteration for each Beam uses 149.75324964523315 seconds.
# Beam: 0, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 162.03, BF Gain: 162.03
# Beam: 1, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 238.09, BF Gain: 238.09
# Beam: 2, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 245.02, BF Gain: 245.02
# Beam: 3, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 113.01, BF Gain: 113.01
# Training for 500 iteration for each Beam uses 153.49543952941895 seconds.
# Beam: 0, Iter: 14001, Reward pred: 1, Reward: 1, BF Gain pred: 159.54, BF Gain: 159.54
# Beam: 1, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 244.93, BF Gain: 244.93
# Beam: 2, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 234.36, BF Gain: 234.36
# Beam: 3, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 113.12, BF Gain: 113.12
# Training for 500 iteration for each Beam uses 152.317875623703 seconds.
# Beam: 0, Iter: 14501, Reward pred: 1, Reward: 1, BF Gain pred: 163.60, BF Gain: 163.60
# Beam: 1, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 235.58, BF Gain: 235.58
# Beam: 2, Iter: 14501, Reward pred: 1, Reward: 1, BF Gain pred: 234.49, BF Gain: 234.49
# Beam: 3, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 112.68, BF Gain: 112.68
# Training for 500 iteration for each Beam uses 154.91574716567993 seconds.
# Beam: 0, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 165.67, BF Gain: 165.67
# Beam: 1, Iter: 15001, Reward pred: -1, Reward: -1, BF Gain pred: 241.04, BF Gain: 241.04
# Beam: 2, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 243.65, BF Gain: 243.65
# Beam: 3, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 109.36, BF Gain: 109.36
# Training for 500 iteration for each Beam uses 150.44679641723633 seconds.
# Beam: 0, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 166.64, BF Gain: 166.64
# Beam: 1, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 249.07, BF Gain: 249.07
# Beam: 2, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 239.61, BF Gain: 239.61
# Beam: 3, Iter: 15501, Reward pred: -1, Reward: -1, BF Gain pred: 110.68, BF Gain: 110.68
# Training for 500 iteration for each Beam uses 149.89416575431824 seconds.
# Beam: 0, Iter: 16001, Reward pred: 1, Reward: 1, BF Gain pred: 163.57, BF Gain: 163.57
# Beam: 1, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 238.66, BF Gain: 238.66
# Beam: 2, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 243.06, BF Gain: 243.06
# Beam: 3, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 114.90, BF Gain: 114.90
# Training for 500 iteration for each Beam uses 149.97038555145264 seconds.
# Beam: 0, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 164.64, BF Gain: 164.64
# Beam: 1, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 245.04, BF Gain: 245.04
# Beam: 2, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 230.78, BF Gain: 230.78
# Beam: 3, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 112.42, BF Gain: 112.42
# Training for 500 iteration for each Beam uses 149.5785059928894 seconds.
# Beam: 0, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 168.87, BF Gain: 168.87
# Beam: 1, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 237.24, BF Gain: 237.24
# Beam: 2, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 239.80, BF Gain: 239.80
# Beam: 3, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 114.85, BF Gain: 114.85
# Training for 500 iteration for each Beam uses 149.52589917182922 seconds.
# Beam: 0, Iter: 17501, Reward pred: 1, Reward: 1, BF Gain pred: 165.50, BF Gain: 165.50
# Beam: 1, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 240.01, BF Gain: 240.01
# Beam: 2, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 237.53, BF Gain: 237.53
# Beam: 3, Iter: 17501, Reward pred: 1, Reward: 1, BF Gain pred: 114.24, BF Gain: 114.24
# Training for 500 iteration for each Beam uses 151.9915955066681 seconds.
# Beam: 0, Iter: 18001, Reward pred: -1, Reward: -1, BF Gain pred: 161.78, BF Gain: 161.78
# Beam: 1, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 240.64, BF Gain: 240.64
# Beam: 2, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 243.61, BF Gain: 243.61
# Beam: 3, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 113.43, BF Gain: 113.43
# Training for 500 iteration for each Beam uses 154.5838508605957 seconds.
# Beam: 0, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 162.12, BF Gain: 162.12
# Beam: 1, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 239.14, BF Gain: 239.14
# Beam: 2, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 240.55, BF Gain: 240.55
# Beam: 3, Iter: 18501, Reward pred: 1, Reward: 1, BF Gain pred: 114.16, BF Gain: 114.16
# Training for 500 iteration for each Beam uses 154.65737533569336 seconds.
# Beam: 0, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 159.67, BF Gain: 159.67
# Beam: 1, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 232.45, BF Gain: 232.45
# Beam: 2, Iter: 19001, Reward pred: 1, Reward: 1, BF Gain pred: 242.95, BF Gain: 242.95
# Beam: 3, Iter: 19001, Reward pred: 1, Reward: 1, BF Gain pred: 111.18, BF Gain: 111.18
# Training for 500 iteration for each Beam uses 154.3589470386505 seconds.
# Beam: 0, Iter: 19501, Reward pred: 1, Reward: 1, BF Gain pred: 166.20, BF Gain: 166.20
# Beam: 1, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 232.17, BF Gain: 232.17
# Beam: 2, Iter: 19501, Reward pred: 1, Reward: 1, BF Gain pred: 250.87, BF Gain: 250.87
# Beam: 3, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 110.46, BF Gain: 110.46
# Training for 500 iteration for each Beam uses 154.25860333442688 seconds.
# Beam: 0, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 161.17, BF Gain: 161.17
# Beam: 1, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 237.44, BF Gain: 237.44
# Beam: 2, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 241.82, BF Gain: 241.82
# Beam: 3, Iter: 20001, Reward pred: 1, Reward: 1, BF Gain pred: 113.01, BF Gain: 113.01
# Training for 500 iteration for each Beam uses 154.26808285713196 seconds.
# Beam: 0, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 163.92, BF Gain: 163.92
# Beam: 1, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 242.12, BF Gain: 242.12
# Beam: 2, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 238.08, BF Gain: 238.08
# Beam: 3, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 114.35, BF Gain: 114.35
# Training for 500 iteration for each Beam uses 154.57336449623108 seconds.
# Beam: 0, Iter: 21001, Reward pred: 1, Reward: 1, BF Gain pred: 167.94, BF Gain: 167.94
# Beam: 1, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 244.56, BF Gain: 244.56
# Beam: 2, Iter: 21001, Reward pred: 1, Reward: 1, BF Gain pred: 238.01, BF Gain: 238.01
# Beam: 3, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 115.56, BF Gain: 115.56
# Training for 500 iteration for each Beam uses 154.06032729148865 seconds.
# Beam: 0, Iter: 21501, Reward pred: 1, Reward: 1, BF Gain pred: 163.73, BF Gain: 163.73
# Beam: 1, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 232.99, BF Gain: 232.99
# Beam: 2, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 239.49, BF Gain: 239.49
# Beam: 3, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 112.73, BF Gain: 112.73
# Training for 500 iteration for each Beam uses 154.32773733139038 seconds.
# Beam: 0, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 166.23, BF Gain: 166.23
# Beam: 1, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 246.04, BF Gain: 246.04
# Beam: 2, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 244.52, BF Gain: 244.52
# Beam: 3, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 113.90, BF Gain: 113.90
# Training for 500 iteration for each Beam uses 155.1164858341217 seconds.
# Beam: 0, Iter: 22501, Reward pred: 1, Reward: 1, BF Gain pred: 165.19, BF Gain: 165.19
# Beam: 1, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 236.24, BF Gain: 236.24
# Beam: 2, Iter: 22501, Reward pred: 1, Reward: 1, BF Gain pred: 238.15, BF Gain: 238.15
# Beam: 3, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 113.15, BF Gain: 113.15
# Training for 500 iteration for each Beam uses 154.71632385253906 seconds.
# Beam: 0, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 163.28, BF Gain: 163.28
# Beam: 1, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 232.85, BF Gain: 232.85
# Beam: 2, Iter: 23001, Reward pred: 1, Reward: 1, BF Gain pred: 240.35, BF Gain: 240.35
# Beam: 3, Iter: 23001, Reward pred: 1, Reward: 1, BF Gain pred: 113.00, BF Gain: 113.00
# Training for 500 iteration for each Beam uses 154.60251879692078 seconds.
# Beam: 0, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 165.01, BF Gain: 165.01
# Beam: 1, Iter: 23501, Reward pred: 1, Reward: 1, BF Gain pred: 250.16, BF Gain: 250.16
# Beam: 2, Iter: 23501, Reward pred: 1, Reward: 1, BF Gain pred: 239.39, BF Gain: 239.39
# Beam: 3, Iter: 23501, Reward pred: 1, Reward: 1, BF Gain pred: 113.14, BF Gain: 113.14
# Training for 500 iteration for each Beam uses 155.0302608013153 seconds.
# Beam: 0, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 169.44, BF Gain: 169.44
# Beam: 1, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 241.71, BF Gain: 241.71
# Beam: 2, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 240.06, BF Gain: 240.06
# Beam: 3, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 73.80, BF Gain: 73.80
# Training for 500 iteration for each Beam uses 154.43077516555786 seconds.
# Beam: 0, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 164.42, BF Gain: 164.42
# Beam: 1, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 244.86, BF Gain: 244.86
# Beam: 2, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 239.76, BF Gain: 239.76
# Beam: 3, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 115.87, BF Gain: 115.87
# Training for 500 iteration for each Beam uses 154.60758757591248 seconds.
# Beam: 0, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 163.15, BF Gain: 163.15
# Beam: 1, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 236.78, BF Gain: 236.78
# Beam: 2, Iter: 25001, Reward pred: 1, Reward: 1, BF Gain pred: 238.30, BF Gain: 238.30
# Beam: 3, Iter: 25001, Reward pred: 1, Reward: 1, BF Gain pred: 112.70, BF Gain: 112.70
# Training for 500 iteration for each Beam uses 154.25409770011902 seconds.
# Beam: 0, Iter: 25501, Reward pred: 1, Reward: 1, BF Gain pred: 165.14, BF Gain: 165.14
# Beam: 1, Iter: 25501, Reward pred: -1, Reward: -1, BF Gain pred: 240.50, BF Gain: 240.50
# Beam: 2, Iter: 25501, Reward pred: 1, Reward: 1, BF Gain pred: 245.10, BF Gain: 245.10
# Beam: 3, Iter: 25501, Reward pred: 1, Reward: 1, BF Gain pred: 113.33, BF Gain: 113.33
# Training for 500 iteration for each Beam uses 154.09855151176453 seconds.
# Beam: 0, Iter: 26001, Reward pred: 1, Reward: 1, BF Gain pred: 165.16, BF Gain: 165.16
# Beam: 1, Iter: 26001, Reward pred: 1, Reward: 1, BF Gain pred: 239.70, BF Gain: 239.70
# Beam: 2, Iter: 26001, Reward pred: 1, Reward: 1, BF Gain pred: 244.76, BF Gain: 244.76
# Beam: 3, Iter: 26001, Reward pred: 1, Reward: 1, BF Gain pred: 114.40, BF Gain: 114.40
# Training for 500 iteration for each Beam uses 154.4221818447113 seconds.
# Beam: 0, Iter: 26501, Reward pred: 1, Reward: 1, BF Gain pred: 166.76, BF Gain: 166.76
# Beam: 1, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 238.19, BF Gain: 238.19
# Beam: 2, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 233.00, BF Gain: 233.00
# Beam: 3, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 114.62, BF Gain: 114.62
# Training for 500 iteration for each Beam uses 155.00281310081482 seconds.
# Beam: 0, Iter: 27001, Reward pred: -1, Reward: -1, BF Gain pred: 166.23, BF Gain: 166.23
# Beam: 1, Iter: 27001, Reward pred: -1, Reward: -1, BF Gain pred: 240.94, BF Gain: 240.94
# Beam: 2, Iter: 27001, Reward pred: 1, Reward: 1, BF Gain pred: 239.05, BF Gain: 239.05
# Beam: 3, Iter: 27001, Reward pred: -1, Reward: -1, BF Gain pred: 113.58, BF Gain: 113.58
# Training for 500 iteration for each Beam uses 154.53845763206482 seconds.
# Beam: 0, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 162.76, BF Gain: 162.76
# Beam: 1, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 239.86, BF Gain: 239.86
# Beam: 2, Iter: 27501, Reward pred: -1, Reward: -1, BF Gain pred: 237.04, BF Gain: 237.04
# Beam: 3, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 112.40, BF Gain: 112.40
# Training for 500 iteration for each Beam uses 154.4342896938324 seconds.
# Beam: 0, Iter: 28001, Reward pred: 1, Reward: 1, BF Gain pred: 163.56, BF Gain: 163.56
# Beam: 1, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 234.29, BF Gain: 234.29
# Beam: 2, Iter: 28001, Reward pred: 1, Reward: 1, BF Gain pred: 243.18, BF Gain: 243.18
# Beam: 3, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 114.99, BF Gain: 114.99
# Training for 500 iteration for each Beam uses 154.17507100105286 seconds.
# Beam: 0, Iter: 28501, Reward pred: 1, Reward: 1, BF Gain pred: 164.65, BF Gain: 164.65
# Beam: 1, Iter: 28501, Reward pred: -1, Reward: -1, BF Gain pred: 230.23, BF Gain: 230.23
# Beam: 2, Iter: 28501, Reward pred: 1, Reward: 1, BF Gain pred: 241.39, BF Gain: 241.39
# Beam: 3, Iter: 28501, Reward pred: -1, Reward: -1, BF Gain pred: 111.23, BF Gain: 111.23
# Training for 500 iteration for each Beam uses 154.82703757286072 seconds.
# Beam: 0, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 166.16, BF Gain: 166.16
# Beam: 1, Iter: 29001, Reward pred: 1, Reward: 1, BF Gain pred: 241.24, BF Gain: 241.24
# Beam: 2, Iter: 29001, Reward pred: 1, Reward: 1, BF Gain pred: 239.42, BF Gain: 239.42
# Beam: 3, Iter: 29001, Reward pred: 1, Reward: 1, BF Gain pred: 114.83, BF Gain: 114.83
# Training for 500 iteration for each Beam uses 154.47948598861694 seconds.
# Beam: 0, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 164.70, BF Gain: 164.70
# Beam: 1, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 249.97, BF Gain: 249.97
# Beam: 2, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 241.74, BF Gain: 241.74
# Beam: 3, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 111.11, BF Gain: 111.11
# Training for 500 iteration for each Beam uses 154.75952696800232 seconds.
# Beam: 0, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 167.04, BF Gain: 167.04
# Beam: 1, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 244.75, BF Gain: 244.75
# Beam: 2, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 236.23, BF Gain: 236.23
# Beam: 3, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 113.31, BF Gain: 113.31
# Training for 500 iteration for each Beam uses 154.07190322875977 seconds.
# Beam: 0, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 160.47, BF Gain: 160.47
# Beam: 1, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 232.45, BF Gain: 232.45
# Beam: 2, Iter: 30501, Reward pred: 1, Reward: 1, BF Gain pred: 239.99, BF Gain: 239.99
# Beam: 3, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 114.36, BF Gain: 114.36
# Training for 500 iteration for each Beam uses 154.4176905155182 seconds.
# Beam: 0, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 163.51, BF Gain: 163.51
# Beam: 1, Iter: 31001, Reward pred: 1, Reward: 1, BF Gain pred: 235.38, BF Gain: 235.38
# Beam: 2, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 237.05, BF Gain: 237.05
# Beam: 3, Iter: 31001, Reward pred: 1, Reward: 1, BF Gain pred: 114.43, BF Gain: 114.43
# Training for 500 iteration for each Beam uses 154.4613697528839 seconds.
# Beam: 0, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 164.13, BF Gain: 164.13
# Beam: 1, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 243.16, BF Gain: 243.16
# Beam: 2, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 241.64, BF Gain: 241.64
# Beam: 3, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 112.83, BF Gain: 112.83
# Training for 500 iteration for each Beam uses 154.64394855499268 seconds.
# Beam: 0, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 165.94, BF Gain: 165.94
# Beam: 1, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 237.94, BF Gain: 237.94
# Beam: 2, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 241.90, BF Gain: 241.90
# Beam: 3, Iter: 32001, Reward pred: 1, Reward: 1, BF Gain pred: 113.56, BF Gain: 113.56
# Training for 500 iteration for each Beam uses 154.66598629951477 seconds.
# Beam: 0, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 167.22, BF Gain: 167.22
# Beam: 1, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 243.90, BF Gain: 243.90
# Beam: 2, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 242.69, BF Gain: 242.69
# Beam: 3, Iter: 32501, Reward pred: -1, Reward: -1, BF Gain pred: 114.59, BF Gain: 114.59
# Training for 500 iteration for each Beam uses 154.694176197052 seconds.
# Beam: 0, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 167.31, BF Gain: 167.31
# Beam: 1, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 249.46, BF Gain: 249.46
# Beam: 2, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 240.50, BF Gain: 240.50
# Beam: 3, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 115.81, BF Gain: 115.81
# Training for 500 iteration for each Beam uses 154.9997627735138 seconds.
# Beam: 0, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 165.02, BF Gain: 165.02
# Beam: 1, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 241.59, BF Gain: 241.59
# Beam: 2, Iter: 33501, Reward pred: 1, Reward: 1, BF Gain pred: 245.82, BF Gain: 245.82
# Beam: 3, Iter: 33501, Reward pred: 1, Reward: 1, BF Gain pred: 113.72, BF Gain: 113.72
# Training for 500 iteration for each Beam uses 154.5848264694214 seconds.
# Beam: 0, Iter: 34001, Reward pred: 1, Reward: 1, BF Gain pred: 166.08, BF Gain: 166.08
# Beam: 1, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 242.28, BF Gain: 242.28
# Beam: 2, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 238.22, BF Gain: 238.22
# Beam: 3, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 113.09, BF Gain: 113.09
# Training for 500 iteration for each Beam uses 154.49230670928955 seconds.
# Beam: 0, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 162.43, BF Gain: 162.43
# Beam: 1, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 246.35, BF Gain: 246.35
# Beam: 2, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 240.61, BF Gain: 240.61
# Beam: 3, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 115.55, BF Gain: 115.55
# Training for 500 iteration for each Beam uses 150.67340183258057 seconds.
# Beam: 0, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 163.01, BF Gain: 163.01
# Beam: 1, Iter: 35001, Reward pred: 1, Reward: 1, BF Gain pred: 236.15, BF Gain: 236.15
# Beam: 2, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 238.17, BF Gain: 238.17
# Beam: 3, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 113.91, BF Gain: 113.91
# Training for 500 iteration for each Beam uses 156.83254098892212 seconds.
# Beam: 0, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 165.65, BF Gain: 165.65
# Beam: 1, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 239.39, BF Gain: 239.39
# Beam: 2, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 235.72, BF Gain: 235.72
# Beam: 3, Iter: 35501, Reward pred: 1, Reward: 1, BF Gain pred: 113.43, BF Gain: 113.43
# Training for 500 iteration for each Beam uses 153.62155961990356 seconds.
# Beam: 0, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 163.65, BF Gain: 163.65
# Beam: 1, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 231.95, BF Gain: 231.95
# Beam: 2, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 240.93, BF Gain: 240.93
# Beam: 3, Iter: 36001, Reward pred: 1, Reward: 1, BF Gain pred: 113.77, BF Gain: 113.77
# Training for 500 iteration for each Beam uses 153.90062499046326 seconds.
# Beam: 0, Iter: 36501, Reward pred: -1, Reward: -1, BF Gain pred: 163.90, BF Gain: 163.90
# Beam: 1, Iter: 36501, Reward pred: 1, Reward: 1, BF Gain pred: 231.40, BF Gain: 231.40
# Beam: 2, Iter: 36501, Reward pred: -1, Reward: -1, BF Gain pred: 242.63, BF Gain: 242.63
# Beam: 3, Iter: 36501, Reward pred: 1, Reward: 1, BF Gain pred: 117.77, BF Gain: 117.77
# Training for 500 iteration for each Beam uses 152.3212537765503 seconds.
# Beam: 0, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 166.59, BF Gain: 166.59
# Beam: 1, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 237.43, BF Gain: 237.43
# Beam: 2, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 240.70, BF Gain: 240.70
# Beam: 3, Iter: 37001, Reward pred: -1, Reward: -1, BF Gain pred: 112.98, BF Gain: 112.98
# Training for 500 iteration for each Beam uses 152.18253111839294 seconds.
# Beam: 0, Iter: 37501, Reward pred: 1, Reward: 1, BF Gain pred: 165.46, BF Gain: 165.46
# Beam: 1, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 246.86, BF Gain: 246.86
# Beam: 2, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 246.58, BF Gain: 246.58
# Beam: 3, Iter: 37501, Reward pred: 1, Reward: 1, BF Gain pred: 115.33, BF Gain: 115.33
# Training for 500 iteration for each Beam uses 152.19815754890442 seconds.
# Beam: 0, Iter: 38001, Reward pred: 1, Reward: 1, BF Gain pred: 166.02, BF Gain: 166.02
# Beam: 1, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 244.28, BF Gain: 244.28
# Beam: 2, Iter: 38001, Reward pred: 1, Reward: 1, BF Gain pred: 240.05, BF Gain: 240.05
# Beam: 3, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 111.29, BF Gain: 111.29
# Training for 500 iteration for each Beam uses 151.93339943885803 seconds.
# Beam: 0, Iter: 38501, Reward pred: 1, Reward: 1, BF Gain pred: 166.83, BF Gain: 166.83
# Beam: 1, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 235.29, BF Gain: 235.29
# Beam: 2, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 243.71, BF Gain: 243.71
# Beam: 3, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 113.71, BF Gain: 113.71
# Training for 500 iteration for each Beam uses 152.07514309883118 seconds.
# Beam: 0, Iter: 39001, Reward pred: 1, Reward: 1, BF Gain pred: 163.94, BF Gain: 163.94
# Beam: 1, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 241.27, BF Gain: 241.27
# Beam: 2, Iter: 39001, Reward pred: 1, Reward: 1, BF Gain pred: 240.31, BF Gain: 240.31
# Beam: 3, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 113.16, BF Gain: 113.16
# Training for 500 iteration for each Beam uses 152.51599645614624 seconds.
# Beam: 0, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 160.62, BF Gain: 160.62
# Beam: 1, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 243.15, BF Gain: 243.15
# Beam: 2, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 247.02, BF Gain: 247.02
# Beam: 3, Iter: 39501, Reward pred: 1, Reward: 1, BF Gain pred: 115.04, BF Gain: 115.04
# Training for 500 iteration for each Beam uses 152.23009490966797 seconds.
# Beam: 0, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 167.04, BF Gain: 167.04
# Beam: 1, Iter: 40001, Reward pred: 1, Reward: 1, BF Gain pred: 242.26, BF Gain: 242.26
# Beam: 2, Iter: 40001, Reward pred: 1, Reward: 1, BF Gain pred: 242.42, BF Gain: 242.42
# Beam: 3, Iter: 40001, Reward pred: 1, Reward: 1, BF Gain pred: 115.02, BF Gain: 115.02
# Training for 500 iteration for each Beam uses 151.24591898918152 seconds.

# %%
import numpy as np
import scipy.io as scio

num_ant = 32
num_beam = 4
results = np.empty((num_beam, 2*num_ant))

path = './beams/'

for beam_id in range(num_beam):
    fname = 'beams_' + str(beam_id) + '_max.txt'
    with open(path + fname, 'r') as f:
        lines = f.readlines()
        last_line = lines[-1]
        results[beam_id, :] = np.fromstring(last_line.replace("\n", ""), sep=',').reshape(1, -1)

results = (1 / np.sqrt(num_ant)) * (results[:, ::2] + 1j * results[:, 1::2])

scio.savemat('beam_codebook.mat', {'beams': results})

# %%
from matplotlib import pyplot as plt
colors = ['b','r','g','c']
plt.figure(figsize=(12, 8))
plt.title(f'Best beamforming gain')
plt.xlabel('Beam_framing_gain')   
for beam_id, color in enumerate(colors):
    gain_record = np.array(env_list[beam_id].gain_history[1:])/options['num_ant']
    np.save(f'beam_{beam_id}_gain_records',gain_record)
    plt.plot(gain_record, label=f'Beam_{beam_id}',color=color)
    EGC = env_list[beam_id].compute_EGC()/options['num_ant']
    
    n_iterations = options['num_loop']*train_opt['num_iter']
    plt.plot([EGC]*n_iterations,linestyle='dashed',color=color,label=f'EGC Beam_{beam_id}')
plt.legend(loc="lower right")  
plt.show()

# %%
def duplicate_n_times(lst, n):
    duplicated_list = []
    for item in lst:
        duplicated_list.extend([item] * n)
    return duplicated_list

plt.figure(figsize=(12, 8))
for beam_id, color in enumerate(colors):
    egc = duplicate_n_times(env_list[beam_id].EGC_history,100)
    egc=np.array(egc)/options['num_ant']
    plt.plot(egc, label=f'Beam_{beam_id}',color=color)
plt.legend(loc="lower right")  
plt.show()

# %%
plt.figure(figsize=(12, 8))
for beam_id, color in enumerate(colors):
    n_iterations = options['num_loop']*train_opt['num_iter']
    egc = duplicate_n_times(env_list[beam_id].EGC_history,100)
    egc=np.array(egc)/options['num_ant']   
    gain_record = np.array(env_list[beam_id].gain_history[1:])/options['num_ant']
    plt.plot(egc-gain_record, label=f'Beam_{beam_id}',color=color)
plt.legend(loc="lower right")  
plt.show()

# %%
accuracy = 0
for beam_id in range(4):
    egc = duplicate_n_times(env_list[beam_id].EGC_history,100)
    egc=np.array(egc)/options['num_ant']  
    gain_record = np.array(env_list[beam_id].gain_history[1:])/options['num_ant']
    perc = (gain_record)/egc
    accuracy +=perc[-1]
    perc = round(perc[-1]*100)
    print(f'beam_{beam_id} reached {perc}% of EGC upperbound')
print(f'Mean EGC reached for all users {round(accuracy*100/4)} %')
# Out:
# beam_0 reached 86% of EGC upperbound
# beam_1 reached 61% of EGC upperbound
# beam_2 reached 80% of EGC upperbound
# beam_3 reached 93% of EGC upperbound
# Mean EGC reached for all users 80 %
