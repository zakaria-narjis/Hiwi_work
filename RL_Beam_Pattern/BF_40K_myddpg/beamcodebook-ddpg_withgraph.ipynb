# %%
# !git clone https://github.com/YuZhang-GitHub/Codebook_Learning_RL.git
# Out:
# Cloning into 'Codebook_Learning_RL'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 77 (delta 5), reused 0 (delta 0), pack-reused 59
# Receiving objects: 100% (77/77), 14.41 MiB | 29.52 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# !pip install pfrl
# Out:
# Collecting pfrl
#   Downloading pfrl-0.4.0.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.6/112.6 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pfrl) (2.0.0)
# Requirement already satisfied: gym>=0.9.7 in /opt/conda/lib/python3.10/site-packages (from pfrl) (0.26.2)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/lib/python3.10/site-packages (from pfrl) (1.23.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from pfrl) (9.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from pfrl) (3.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (0.0.8)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.3.0->pfrl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.3.0->pfrl) (1.3.0)
# Building wheels for collected packages: pfrl
#   Building wheel for pfrl (setup.py) ... done
#   Created wheel for pfrl: filename=pfrl-0.4.0-py3-none-any.whl size=155465 sha256=238866a1c951053ff81bb05d0842d7bc95b9a9c28e14635bacfb6e1ef5cf79ef
#   Stored in directory: /root/.cache/pip/wheels/22/4a/0f/a87cd1ae925086eb3a1b8759f620fcf48e47939fb082946c3b
# Successfully built pfrl
# Installing collected packages: pfrl
# Successfully installed pfrl-0.4.0

# %%
# from Codebook_Learning_RL import DDPG_classes

# %%
import os
os.chdir('/kaggle/working/Codebook_Learning_RL')
print(os.getcwd())
# Out:
# /kaggle/working/Codebook_Learning_RL

# %%
import pfrl
import os
import time
import torch
import numpy as np
import copy
import pickle
from torch import nn
from scipy.optimize import linear_sum_assignment
from DataPrep import dataPrep
from env_ddpg import envCB
from clustering import KMeans_only
from function_lib import bf_gain_cal, corr_mining
from DDPG_classes import OUNoise
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class envCB_(envCB):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.gain_history = [0]

# %%
options = {
        'gpu_idx': 0,
        'num_ant': 32,
        'num_bits': 4,
        'num_NNs': 4,  # codebook size
        'ch_sample_ratio': 0.5,
        'num_loop': 400,  # outer loop
        'target_update': 3,
        'path': './grid1101-1400.mat',
        'clustering_mode': 'random',
    }

train_opt = {
        'state': 0,
        'best_state': 0,
        'num_iter': 100,  # inner loop
        'tau': 1e-2,
        'overall_iter': 1,
        'replay_memory': [],
        'replay_memory_size': 8192,
        'minibatch_size': 1024,
        'gamma': 0,
        'gpu':0
    }
if not os.path.exists('beams/'):
    os.mkdir('beams/')

ch = dataPrep(options['path'])
ch = np.concatenate((ch[:, :options['num_ant']],
                     ch[:, int(ch.shape[1] / 2):int(ch.shape[1] / 2) + options['num_ant']]), axis=1)
u_classifier, sensing_beam = KMeans_only(ch, options['num_NNs'], n_bit=options['num_bits'], n_rand_beam=30)
np.save('sensing_beam.npy', sensing_beam)
sensing_beam = torch.from_numpy(sensing_beam).float().cuda()

filename = 'kmeans_model.sav'
pickle.dump(u_classifier, open(filename, 'wb'))

# Quantization settings
options['num_ph'] = 2 ** options['num_bits']
options['multi_step'] = torch.from_numpy(
    np.linspace(int(-(options['num_ph'] - 2) / 2),
                int(options['num_ph'] / 2),
                num=options['num_ph'],
                endpoint=True)).type(dtype=torch.float32).reshape(1, -1).cuda()
options['pi'] = torch.tensor(np.pi).cuda()
options['ph_table'] = (2 * options['pi']) / options['num_ph'] * options['multi_step']
options['ph_table'].cuda()
options['ph_table_rep'] = options['ph_table'].repeat(options['num_ant'], 1)
actor_net_list = []
critic_net_list = []
actor_net_t_list = []
critic_net_t_list = []
ounoise_list = []
env_list = []
train_opt_list = []
agent_list=[]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from pfrl.utils.batch_states import batch_states
def batch_experiences_(experiences, device, phi, gamma, batch_states=batch_states):
    """Takes a batch of k experiences each of which contains j

    consecutive transitions and vectorizes them, where j is between 1 and n.

    Args:
        experiences: list of experiences. Each experience is a list
            containing between 1 and n dicts containing
              - state (object): State
              - action (object): Action
              - reward (float): Reward
              - is_state_terminal (bool): True iff next state is terminal
              - next_state (object): Next state
        device : GPU or CPU the tensor should be placed on
        phi : Preprocessing function
        gamma: discount factor
        batch_states: function that converts a list to a batch
    Returns:
        dict of batched transitions
    """

    batch_exp = {
        "state": batch_states([elem[0]["state"] for elem in experiences], device, phi),
        "action": torch.as_tensor(
            np.array([elem[0]["action"] for elem in experiences]), device=device
        ),
        "reward": torch.as_tensor(
            [
                sum((gamma**i) * exp[i]["reward"] for i in range(len(exp)))
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "next_state": batch_states(
            [elem[-1]["next_state"] for elem in experiences], device, phi
        ),
        "is_state_terminal": torch.as_tensor(
            [
                any(transition["is_state_terminal"] for transition in exp)
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "discount": torch.as_tensor(
            [(gamma ** len(elem)) for elem in experiences],
            dtype=torch.float32,
            device=device,
        ),
    }
    if all(elem[-1]["next_action"] is not None for elem in experiences):
        batch_exp["next_action"] = torch.as_tensor(
            [elem[-1]["next_action"] for elem in experiences], device=device
        )
    return batch_exp

from pfrl.agents.ddpg import DDPG
class DDPG_(DDPG):
    def update(self, experiences, errors_out=None):
        """Update the model from experiences"""

        batch = batch_experiences_(experiences, self.device, self.phi, self.gamma)

        self.critic_optimizer.zero_grad()
        self.compute_critic_loss(batch).backward()
        self.critic_optimizer.step()

        self.actor_optimizer.zero_grad()
        self.compute_actor_loss(batch).backward()
        self.actor_optimizer.step()

        self.n_updates += 1

# %%
import pfrl
from pfrl import experiments, explorers, replay_buffers, utils
from pfrl.agents.ddpg import DDPG
from pfrl.nn import BoundByTanh, ConcatObsAndAction
from pfrl.policies import DeterministicHead
from pfrl.explorers import Greedy

def create_agent(state_size,action_size,train_options,gpu=0):
    
    #critic_network
    q_func = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    #actor_network
    policy = nn.Sequential(
        nn.Linear(state_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, action_size),
        BoundByTanh(low= -torch.tensor(np.pi).float(), high= torch.tensor(np.pi).float()),
        DeterministicHead(),
    )
    
    opt_a = torch.optim.Adam(policy.parameters(), lr=1e-3, weight_decay=1e-3)
    opt_c = torch.optim.Adam(q_func.parameters(), lr=1e-3, weight_decay=1e-2)
    rbuf = replay_buffers.ReplayBuffer(train_options['replay_memory_size'])
    
    explorer =  Greedy()
    
    agent = DDPG_(
        policy,
        q_func,
        opt_a,
        opt_c,
        rbuf,
        gamma = train_options['gamma'],
        explorer = explorer,
        replay_start_size = train_options['minibatch_size'],
        target_update_method = "soft",
        target_update_interval = options['target_update'],
        update_interval = 1,
        soft_update_tau = train_opt['tau'],
        n_times_update = 1,
        gpu = gpu,
        minibatch_size = train_options['minibatch_size'],
    )
    
    return agent

# %%
def train(
          env,
          options,
          train_options,
          agent,
          ounoise,
          beam_id):
    
#     action_pred_noisy = ounoise.get_action(action_pred,
#                                                t=train_options['overall_iter'])
    CB_Env = env   
    if train_options['overall_iter'] == 1:
        state = torch.zeros((1, options['num_ant'])).float().cuda()
        print('Initial State Activated.')
    else:
        state = train_options['state']
    
    
    #training_loop
    iteration = 0
    num_of_iter = train_options['num_iter'] 
    start_time = time.time()
    while iteration < num_of_iter:

        
        action = agent.act(state)
#         print(type(agent.batch_last_action),agent.batch_last_action)
        reward_pred, bf_gain_pred, action_quant_pred, state_1_pred = CB_Env.get_reward(torch.Tensor(action).to('cuda'))
        reward_pred = torch.from_numpy(reward_pred).float().cuda()
        
        action_pred_noisy = ounoise.get_action(torch.Tensor(action).to('cuda'), t=train_options['overall_iter'])
        mat_dist = torch.abs(action_pred_noisy.reshape(options['num_ant'], 1) - options['ph_table_rep'])
        action_quant = options['ph_table_rep'][range(options['num_ant']), torch.argmin(mat_dist, dim=1)].reshape(1, -1)
   
        state_1, reward, bf_gain, terminal = CB_Env.step(action_quant)
        reward = torch.from_numpy(reward).float().cuda()
        action = action_quant.reshape((1, -1)).float().cuda()
        
        
#         print(type(action_quant_pred.cpu().numpy()),action_quant_pred.cpu().numpy().shape)
#         print(type(action.cpu().numpy()),action.cpu().numpy().shape)
        agent.replay_buffer.append(
                    state=state,
                    action=action_quant_pred.cpu().numpy(),
                    reward=reward_pred,
                    next_state=state_1_pred,
                    next_action=None,
                    is_state_terminal=terminal,
                    env_id=0,
                )
#         print(agent.batch_last_action,agent.batch_last_action[0].shape)
        agent.batch_last_action = [action.cpu().numpy()] #because the critic is expecting quantizazed actions
        agent.observe(state_1, reward, terminal, False)

        
        iteration += 1
        train_options['overall_iter'] += 1
        state = state_1
        
        new_gain = torch.Tensor.cpu(CB_Env.achievement).detach().numpy().reshape((1, 1))
        max_previous_gain = max(CB_Env.gain_history)
        if new_gain > max_previous_gain:
            CB_Env.gain_history.append(float(new_gain))                   
        else:
            CB_Env.gain_history.append(float(max_previous_gain))
            
    train_options['state'] = state  # used for the next loop
    train_options['best_state'] = CB_Env.best_bf_vec  # used for clustering and assignment
    if (train_options['overall_iter']-1)%500==0:
#         print(
#             "Beam: %d, Iter: %d, Reward: %d, BF Gain: %.2f" % \
#             (beam_id, 
#              train_options['overall_iter'],
#              int(torch.Tensor.cpu(reward).numpy().squeeze()),
#              torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))
        print(
            "Beam: %d, Iter: %d, Reward pred: %d, Reward: %d, BF Gain pred: %.2f, BF Gain: %.2f" % \
            (beam_id, train_options['overall_iter'],
             int(torch.Tensor.cpu(reward_pred).numpy().squeeze()),
             int(torch.Tensor.cpu(reward).numpy().squeeze()),
             torch.Tensor.cpu(bf_gain_pred.detach()).numpy().squeeze(),
             torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))      
    
    return train_options

# %%
for beam_id in range(options['num_NNs']):
    ounoise_list.append(OUNoise((1, options['num_ant'])))
    env_list.append(envCB_(ch, options['num_ant'], options['num_bits'], beam_id, options))
    train_opt_list.append(copy.deepcopy(train_opt))
    agent = create_agent(options['num_ant'],options['num_ant'],train_opt_list[beam_id],gpu=train_opt['gpu'])
    agent_list.append(agent)
    ounoise_list.append(OUNoise((1, options['num_ant'])))
# Out:
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094

# %%
for sample_id in range(options['num_loop']):

    # ---------- Sampling ---------- #
    n_sample = int(ch.shape[0] * options['ch_sample_ratio'])
    ch_sample_id = np.random.permutation(ch.shape[0])[0:n_sample]
    ch_sample = torch.from_numpy(ch[ch_sample_id, :]).float().cuda()

    # ---------- Clustering ---------- #
#     start_time = time.time()

    bf_mat_sample = bf_gain_cal(sensing_beam, ch_sample)
    # print("Clustering -1 uses %s seconds." % (time.time() - start_time))
    # start_time = time.time()
    f_matrix = corr_mining(bf_mat_sample)
    f_matrix_np = torch.Tensor.cpu(f_matrix).numpy()
    # print("Clustering 0 uses %s seconds." % (time.time() - start_time))
    # start_time = time.time()
    labels = u_classifier.predict(np.transpose(f_matrix_np).astype(float))

    # print("Clustering 1 uses %s seconds." % (time.time() - start_time))
    # start_time = time.time()

    user_group = []  # order: clusters
    ch_group = []  # order: clusters
    for ii in range(options['num_NNs']):
        user_group.append(np.where(labels == ii)[0].tolist())
        ch_group.append(ch_sample[user_group[ii], :])

#     print("Clustering 2 uses %s seconds." % (time.time() - start_time))

    # ---------- Assignment ---------- #
#     start_time = time.time()

    # best_state matrix
    best_beam_mtx = torch.zeros((options['num_NNs'], 2 * options['num_ant'])).float().cuda()
    for pp in range(options['num_NNs']):
        best_beam_mtx[pp, :] = env_list[pp].best_bf_vec
    gain_mtx = bf_gain_cal(best_beam_mtx, ch_sample)  # (n_beam, n_user)
    for ii in range(options['num_NNs']):
        if ii == 0:
            cost_mtx = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
        else:
            sub = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
            cost_mtx = torch.cat((cost_mtx, sub), dim=1)
    cost_mtx = -torch.Tensor.cpu(cost_mtx).numpy()
    row_ind, col_ind = linear_sum_assignment(cost_mtx)
    assignment_record = dict(zip(row_ind.tolist(), col_ind.tolist()))  # key: network, value: cluster
    for ii in range(options['num_NNs']):
        env_list[ii].ch = ch_group[assignment_record[ii]]

#     print("Assignment uses %s seconds." % (time.time() - start_time))
    if (train_opt_list[beam_id]['overall_iter']-1)%500==0 or train_opt_list[beam_id]['overall_iter']==1:
        start_time = time.time()
    for beam_id in range(options['num_NNs']):
        train_opt_list[beam_id] = train(env_list[beam_id],options, train_opt_list[beam_id],agent_list[beam_id],ounoise_list[beam_id], beam_id)
    if (train_opt_list[beam_id]['overall_iter']-1)%500==0: 
        print("Training for 500 iteration for each Beam uses %s seconds." % (time.time() - start_time))
# Out:
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Beam: 0, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 3.53, BF Gain: 7.95
# Beam: 1, Iter: 501, Reward pred: -1, Reward: 1, BF Gain pred: 0.98, BF Gain: 6.03
# Beam: 2, Iter: 501, Reward pred: -1, Reward: 1, BF Gain pred: 0.40, BF Gain: 3.33
# Beam: 3, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 3.04, BF Gain: 5.08
# Training for 500 iteration for each Beam uses 13.021162033081055 seconds.
# Beam: 0, Iter: 1001, Reward pred: -1, Reward: 1, BF Gain pred: 0.57, BF Gain: 6.21
# Beam: 1, Iter: 1001, Reward pred: 1, Reward: 1, BF Gain pred: 1.21, BF Gain: 7.48
# Beam: 2, Iter: 1001, Reward pred: -1, Reward: 1, BF Gain pred: 0.20, BF Gain: 6.32
# Beam: 3, Iter: 1001, Reward pred: 1, Reward: 1, BF Gain pred: 1.14, BF Gain: 3.12
# Training for 500 iteration for each Beam uses 111.19463872909546 seconds.
# Beam: 0, Iter: 1501, Reward pred: -1, Reward: 1, BF Gain pred: 1.04, BF Gain: 7.89
# Beam: 1, Iter: 1501, Reward pred: -1, Reward: 1, BF Gain pred: 0.57, BF Gain: 4.01
# Beam: 2, Iter: 1501, Reward pred: -1, Reward: 1, BF Gain pred: 0.14, BF Gain: 3.34
# Beam: 3, Iter: 1501, Reward pred: 1, Reward: 1, BF Gain pred: 0.77, BF Gain: 3.93
# Training for 500 iteration for each Beam uses 112.93425559997559 seconds.
# Beam: 0, Iter: 2001, Reward pred: -1, Reward: 1, BF Gain pred: 0.46, BF Gain: 7.72
# Beam: 1, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 3.68, BF Gain: 6.96
# Beam: 2, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 2.08, BF Gain: 1.40
# Beam: 3, Iter: 2001, Reward pred: -1, Reward: 1, BF Gain pred: 2.92, BF Gain: 8.95
# Training for 500 iteration for each Beam uses 115.00817155838013 seconds.
# Beam: 0, Iter: 2501, Reward pred: -1, Reward: 1, BF Gain pred: 0.45, BF Gain: 4.67
# Beam: 1, Iter: 2501, Reward pred: 1, Reward: 1, BF Gain pred: 2.98, BF Gain: 4.30
# Beam: 2, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 6.58, BF Gain: 4.93
# Beam: 3, Iter: 2501, Reward pred: 1, Reward: -1, BF Gain pred: 13.00, BF Gain: 3.06
# Training for 500 iteration for each Beam uses 115.18009305000305 seconds.
# Beam: 0, Iter: 3001, Reward pred: -1, Reward: 1, BF Gain pred: 6.82, BF Gain: 11.63
# Beam: 1, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 12.75, BF Gain: 6.68
# Beam: 2, Iter: 3001, Reward pred: -1, Reward: 1, BF Gain pred: 0.73, BF Gain: 3.55
# Beam: 3, Iter: 3001, Reward pred: 1, Reward: -1, BF Gain pred: 26.12, BF Gain: 6.60
# Training for 500 iteration for each Beam uses 114.61030101776123 seconds.
# Beam: 0, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 9.51, BF Gain: 9.58
# Beam: 1, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 2.90, BF Gain: 3.81
# Beam: 2, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 6.90, BF Gain: 2.48
# Beam: 3, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 12.20, BF Gain: 13.37
# Training for 500 iteration for each Beam uses 115.48195457458496 seconds.
# Beam: 0, Iter: 4001, Reward pred: -1, Reward: -1, BF Gain pred: 5.89, BF Gain: 6.81
# Beam: 1, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 4.08, BF Gain: 2.58
# Beam: 2, Iter: 4001, Reward pred: -1, Reward: 1, BF Gain pred: 0.64, BF Gain: 3.18
# Beam: 3, Iter: 4001, Reward pred: 1, Reward: -1, BF Gain pred: 8.57, BF Gain: 1.47
# Training for 500 iteration for each Beam uses 115.20938158035278 seconds.
# Beam: 0, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 10.55, BF Gain: 12.43
# Beam: 1, Iter: 4501, Reward pred: 1, Reward: -1, BF Gain pred: 20.36, BF Gain: 3.31
# Beam: 2, Iter: 4501, Reward pred: 1, Reward: -1, BF Gain pred: 14.85, BF Gain: 1.61
# Beam: 3, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 10.90, BF Gain: 2.43
# Training for 500 iteration for each Beam uses 114.47840285301208 seconds.
# Beam: 0, Iter: 5001, Reward pred: 1, Reward: -1, BF Gain pred: 32.22, BF Gain: 12.57
# Beam: 1, Iter: 5001, Reward pred: 1, Reward: 1, BF Gain pred: 9.80, BF Gain: 16.22
# Beam: 2, Iter: 5001, Reward pred: 1, Reward: -1, BF Gain pred: 5.40, BF Gain: 3.42
# Beam: 3, Iter: 5001, Reward pred: 1, Reward: -1, BF Gain pred: 43.09, BF Gain: 15.96
# Training for 500 iteration for each Beam uses 114.73623585700989 seconds.
# Beam: 0, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 29.01, BF Gain: 5.79
# Beam: 1, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 19.36, BF Gain: 7.44
# Beam: 2, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 2.28, BF Gain: 9.38
# Beam: 3, Iter: 5501, Reward pred: 1, Reward: -1, BF Gain pred: 42.04, BF Gain: 30.31
# Training for 500 iteration for each Beam uses 114.73934936523438 seconds.
# Beam: 0, Iter: 6001, Reward pred: 1, Reward: 1, BF Gain pred: 24.90, BF Gain: 8.55
# Beam: 1, Iter: 6001, Reward pred: 1, Reward: -1, BF Gain pred: 41.02, BF Gain: 5.38
# Beam: 2, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 0.94, BF Gain: 1.26
# Beam: 3, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 16.94, BF Gain: 21.60
# Training for 500 iteration for each Beam uses 114.3530867099762 seconds.
# Beam: 0, Iter: 6501, Reward pred: 1, Reward: -1, BF Gain pred: 7.26, BF Gain: 3.89
# Beam: 1, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 28.04, BF Gain: 12.01
# Beam: 2, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 20.67, BF Gain: 3.42
# Beam: 3, Iter: 6501, Reward pred: -1, Reward: 1, BF Gain pred: 11.91, BF Gain: 27.41
# Training for 500 iteration for each Beam uses 114.53706884384155 seconds.
# Beam: 0, Iter: 7001, Reward pred: 1, Reward: 1, BF Gain pred: 34.68, BF Gain: 26.00
# Beam: 1, Iter: 7001, Reward pred: 1, Reward: -1, BF Gain pred: 46.13, BF Gain: 26.96
# Beam: 2, Iter: 7001, Reward pred: -1, Reward: 1, BF Gain pred: 2.18, BF Gain: 3.48
# Beam: 3, Iter: 7001, Reward pred: 1, Reward: -1, BF Gain pred: 65.09, BF Gain: 20.41
# Training for 500 iteration for each Beam uses 114.5418689250946 seconds.
# Beam: 0, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 6.09, BF Gain: 6.44
# Beam: 1, Iter: 7501, Reward pred: -1, Reward: -1, BF Gain pred: 12.76, BF Gain: 5.68
# Beam: 2, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 10.78, BF Gain: 8.89
# Beam: 3, Iter: 7501, Reward pred: 1, Reward: -1, BF Gain pred: 70.78, BF Gain: 13.42
# Training for 500 iteration for each Beam uses 115.58898687362671 seconds.
# Beam: 0, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 24.55, BF Gain: 13.16
# Beam: 1, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 51.67, BF Gain: 11.38
# Beam: 2, Iter: 8001, Reward pred: 1, Reward: -1, BF Gain pred: 25.26, BF Gain: 7.92
# Beam: 3, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 57.24, BF Gain: 23.99
# Training for 500 iteration for each Beam uses 115.32731914520264 seconds.
# Beam: 0, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 44.58, BF Gain: 38.22
# Beam: 1, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 53.50, BF Gain: 15.74
# Beam: 2, Iter: 8501, Reward pred: 1, Reward: -1, BF Gain pred: 27.06, BF Gain: 16.69
# Beam: 3, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 96.38, BF Gain: 11.65
# Training for 500 iteration for each Beam uses 115.91369795799255 seconds.
# Beam: 0, Iter: 9001, Reward pred: 1, Reward: -1, BF Gain pred: 10.67, BF Gain: 4.85
# Beam: 1, Iter: 9001, Reward pred: 1, Reward: -1, BF Gain pred: 63.48, BF Gain: 30.18
# Beam: 2, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 48.38, BF Gain: 3.90
# Beam: 3, Iter: 9001, Reward pred: 1, Reward: -1, BF Gain pred: 99.46, BF Gain: 27.55
# Training for 500 iteration for each Beam uses 115.82641339302063 seconds.
# Beam: 0, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 18.69, BF Gain: 4.22
# Beam: 1, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 46.99, BF Gain: 12.55
# Beam: 2, Iter: 9501, Reward pred: 1, Reward: -1, BF Gain pred: 64.49, BF Gain: 28.38
# Beam: 3, Iter: 9501, Reward pred: 1, Reward: -1, BF Gain pred: 147.16, BF Gain: 63.17
# Training for 500 iteration for each Beam uses 115.87481164932251 seconds.
# Beam: 0, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 53.17, BF Gain: 17.16
# Beam: 1, Iter: 10001, Reward pred: 1, Reward: -1, BF Gain pred: 71.53, BF Gain: 7.87
# Beam: 2, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 57.21, BF Gain: 14.90
# Beam: 3, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 123.49, BF Gain: 45.79
# Training for 500 iteration for each Beam uses 115.68296647071838 seconds.
# Beam: 0, Iter: 10501, Reward pred: 1, Reward: -1, BF Gain pred: 25.85, BF Gain: 7.00
# Beam: 1, Iter: 10501, Reward pred: 1, Reward: -1, BF Gain pred: 88.85, BF Gain: 10.47
# Beam: 2, Iter: 10501, Reward pred: 1, Reward: -1, BF Gain pred: 50.35, BF Gain: 7.88
# Beam: 3, Iter: 10501, Reward pred: 1, Reward: -1, BF Gain pred: 157.99, BF Gain: 58.82
# Training for 500 iteration for each Beam uses 115.56441593170166 seconds.
# Beam: 0, Iter: 11001, Reward pred: 1, Reward: -1, BF Gain pred: 72.57, BF Gain: 26.25
# Beam: 1, Iter: 11001, Reward pred: 1, Reward: -1, BF Gain pred: 75.53, BF Gain: 15.99
# Beam: 2, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 40.34, BF Gain: 7.91
# Beam: 3, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 149.37, BF Gain: 29.96
# Training for 500 iteration for each Beam uses 116.01257658004761 seconds.
# Beam: 0, Iter: 11501, Reward pred: 1, Reward: -1, BF Gain pred: 61.52, BF Gain: 5.88
# Beam: 1, Iter: 11501, Reward pred: 1, Reward: -1, BF Gain pred: 126.00, BF Gain: 26.10
# Beam: 2, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 65.61, BF Gain: 7.49
# Beam: 3, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 114.50, BF Gain: 17.44
# Training for 500 iteration for each Beam uses 115.90096998214722 seconds.
# Beam: 0, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 64.57, BF Gain: 43.20
# Beam: 1, Iter: 12001, Reward pred: 1, Reward: -1, BF Gain pred: 76.98, BF Gain: 20.36
# Beam: 2, Iter: 12001, Reward pred: 1, Reward: -1, BF Gain pred: 71.97, BF Gain: 32.71
# Beam: 3, Iter: 12001, Reward pred: 1, Reward: -1, BF Gain pred: 226.86, BF Gain: 73.56
# Training for 500 iteration for each Beam uses 115.7845687866211 seconds.
# Beam: 0, Iter: 12501, Reward pred: 1, Reward: -1, BF Gain pred: 46.24, BF Gain: 16.17
# Beam: 1, Iter: 12501, Reward pred: 1, Reward: -1, BF Gain pred: 58.68, BF Gain: 8.34
# Beam: 2, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 46.70, BF Gain: 25.26
# Beam: 3, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 174.57, BF Gain: 42.83
# Training for 500 iteration for each Beam uses 116.06433343887329 seconds.
# Beam: 0, Iter: 13001, Reward pred: 1, Reward: -1, BF Gain pred: 50.63, BF Gain: 9.29
# Beam: 1, Iter: 13001, Reward pred: 1, Reward: -1, BF Gain pred: 106.55, BF Gain: 51.98
# Beam: 2, Iter: 13001, Reward pred: 1, Reward: -1, BF Gain pred: 70.15, BF Gain: 32.97
# Beam: 3, Iter: 13001, Reward pred: 1, Reward: -1, BF Gain pred: 181.89, BF Gain: 53.69
# Training for 500 iteration for each Beam uses 116.05485153198242 seconds.
# Beam: 0, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 100.85, BF Gain: 39.41
# Beam: 1, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 97.12, BF Gain: 38.82
# Beam: 2, Iter: 13501, Reward pred: 1, Reward: -1, BF Gain pred: 76.96, BF Gain: 15.97
# Beam: 3, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 162.59, BF Gain: 11.04
# Training for 500 iteration for each Beam uses 115.62529134750366 seconds.
# Beam: 0, Iter: 14001, Reward pred: 1, Reward: -1, BF Gain pred: 74.70, BF Gain: 33.20
# Beam: 1, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 99.83, BF Gain: 43.31
# Beam: 2, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 63.77, BF Gain: 30.97
# Beam: 3, Iter: 14001, Reward pred: 1, Reward: -1, BF Gain pred: 176.98, BF Gain: 43.22
# Training for 500 iteration for each Beam uses 115.33026194572449 seconds.
# Beam: 0, Iter: 14501, Reward pred: 1, Reward: -1, BF Gain pred: 138.54, BF Gain: 71.11
# Beam: 1, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 90.76, BF Gain: 15.30
# Beam: 2, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 64.27, BF Gain: 26.22
# Beam: 3, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 161.13, BF Gain: 50.34
# Training for 500 iteration for each Beam uses 115.84997773170471 seconds.
# Beam: 0, Iter: 15001, Reward pred: 1, Reward: -1, BF Gain pred: 112.11, BF Gain: 44.81
# Beam: 1, Iter: 15001, Reward pred: 1, Reward: -1, BF Gain pred: 115.21, BF Gain: 55.32
# Beam: 2, Iter: 15001, Reward pred: -1, Reward: -1, BF Gain pred: 72.65, BF Gain: 22.61
# Beam: 3, Iter: 15001, Reward pred: -1, Reward: -1, BF Gain pred: 164.65, BF Gain: 51.16
# Training for 500 iteration for each Beam uses 117.53319430351257 seconds.
# Beam: 0, Iter: 15501, Reward pred: 1, Reward: -1, BF Gain pred: 94.46, BF Gain: 55.41
# Beam: 1, Iter: 15501, Reward pred: 1, Reward: -1, BF Gain pred: 107.13, BF Gain: 10.32
# Beam: 2, Iter: 15501, Reward pred: -1, Reward: -1, BF Gain pred: 74.30, BF Gain: 25.39
# Beam: 3, Iter: 15501, Reward pred: 1, Reward: -1, BF Gain pred: 198.51, BF Gain: 31.92
# Training for 500 iteration for each Beam uses 116.73008990287781 seconds.
# Beam: 0, Iter: 16001, Reward pred: 1, Reward: -1, BF Gain pred: 114.91, BF Gain: 46.67
# Beam: 1, Iter: 16001, Reward pred: 1, Reward: -1, BF Gain pred: 88.03, BF Gain: 26.93
# Beam: 2, Iter: 16001, Reward pred: 1, Reward: -1, BF Gain pred: 86.82, BF Gain: 14.45
# Beam: 3, Iter: 16001, Reward pred: 1, Reward: -1, BF Gain pred: 224.39, BF Gain: 95.62
# Training for 500 iteration for each Beam uses 116.83361482620239 seconds.
# Beam: 0, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 137.52, BF Gain: 34.36
# Beam: 1, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 84.69, BF Gain: 41.92
# Beam: 2, Iter: 16501, Reward pred: 1, Reward: -1, BF Gain pred: 79.61, BF Gain: 20.27
# Beam: 3, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 205.18, BF Gain: 101.45
# Training for 500 iteration for each Beam uses 117.72010040283203 seconds.
# Beam: 0, Iter: 17001, Reward pred: -1, Reward: -1, BF Gain pred: 113.05, BF Gain: 62.30
# Beam: 1, Iter: 17001, Reward pred: -1, Reward: -1, BF Gain pred: 117.07, BF Gain: 42.22
# Beam: 2, Iter: 17001, Reward pred: 1, Reward: -1, BF Gain pred: 77.71, BF Gain: 22.23
# Beam: 3, Iter: 17001, Reward pred: 1, Reward: -1, BF Gain pred: 170.91, BF Gain: 81.94
# Training for 500 iteration for each Beam uses 118.28788304328918 seconds.
# Beam: 0, Iter: 17501, Reward pred: 1, Reward: -1, BF Gain pred: 118.55, BF Gain: 66.28
# Beam: 1, Iter: 17501, Reward pred: 1, Reward: -1, BF Gain pred: 123.88, BF Gain: 32.68
# Beam: 2, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 70.56, BF Gain: 26.35
# Beam: 3, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 196.82, BF Gain: 36.18
# Training for 500 iteration for each Beam uses 118.02761769294739 seconds.
# Beam: 0, Iter: 18001, Reward pred: 1, Reward: -1, BF Gain pred: 132.20, BF Gain: 27.53
# Beam: 1, Iter: 18001, Reward pred: -1, Reward: -1, BF Gain pred: 94.22, BF Gain: 30.49
# Beam: 2, Iter: 18001, Reward pred: 1, Reward: -1, BF Gain pred: 67.52, BF Gain: 39.39
# Beam: 3, Iter: 18001, Reward pred: -1, Reward: -1, BF Gain pred: 174.46, BF Gain: 119.38
# Training for 500 iteration for each Beam uses 118.20538783073425 seconds.
# Beam: 0, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 66.96, BF Gain: 31.46
# Beam: 1, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 109.10, BF Gain: 27.33
# Beam: 2, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 75.42, BF Gain: 22.85
# Beam: 3, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 230.51, BF Gain: 83.06
# Training for 500 iteration for each Beam uses 117.26111364364624 seconds.
# Beam: 0, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 114.56, BF Gain: 43.43
# Beam: 1, Iter: 19001, Reward pred: 1, Reward: -1, BF Gain pred: 100.15, BF Gain: 17.41
# Beam: 2, Iter: 19001, Reward pred: 1, Reward: -1, BF Gain pred: 94.60, BF Gain: 32.31
# Beam: 3, Iter: 19001, Reward pred: 1, Reward: -1, BF Gain pred: 236.74, BF Gain: 78.15
# Training for 500 iteration for each Beam uses 117.63768339157104 seconds.
# Beam: 0, Iter: 19501, Reward pred: 1, Reward: -1, BF Gain pred: 101.33, BF Gain: 36.42
# Beam: 1, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 85.62, BF Gain: 4.76
# Beam: 2, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 51.29, BF Gain: 24.21
# Beam: 3, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 229.84, BF Gain: 50.63
# Training for 500 iteration for each Beam uses 116.0756459236145 seconds.
# Beam: 0, Iter: 20001, Reward pred: 1, Reward: -1, BF Gain pred: 130.13, BF Gain: 60.68
# Beam: 1, Iter: 20001, Reward pred: 1, Reward: -1, BF Gain pred: 107.95, BF Gain: 25.17
# Beam: 2, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 76.46, BF Gain: 38.53
# Beam: 3, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 223.97, BF Gain: 35.02
# Training for 500 iteration for each Beam uses 114.88879299163818 seconds.
# Beam: 0, Iter: 20501, Reward pred: 1, Reward: -1, BF Gain pred: 135.13, BF Gain: 66.31
# Beam: 1, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 132.82, BF Gain: 47.04
# Beam: 2, Iter: 20501, Reward pred: 1, Reward: -1, BF Gain pred: 85.00, BF Gain: 45.24
# Beam: 3, Iter: 20501, Reward pred: 1, Reward: -1, BF Gain pred: 215.85, BF Gain: 58.66
# Training for 500 iteration for each Beam uses 114.89143323898315 seconds.
# Beam: 0, Iter: 21001, Reward pred: 1, Reward: -1, BF Gain pred: 136.38, BF Gain: 48.37
# Beam: 1, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 99.66, BF Gain: 21.02
# Beam: 2, Iter: 21001, Reward pred: 1, Reward: -1, BF Gain pred: 77.35, BF Gain: 10.48
# Beam: 3, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 217.07, BF Gain: 38.37
# Training for 500 iteration for each Beam uses 114.53952050209045 seconds.
# Beam: 0, Iter: 21501, Reward pred: 1, Reward: -1, BF Gain pred: 122.06, BF Gain: 46.12
# Beam: 1, Iter: 21501, Reward pred: 1, Reward: -1, BF Gain pred: 123.00, BF Gain: 39.02
# Beam: 2, Iter: 21501, Reward pred: 1, Reward: -1, BF Gain pred: 80.58, BF Gain: 22.58
# Beam: 3, Iter: 21501, Reward pred: 1, Reward: -1, BF Gain pred: 226.54, BF Gain: 31.63
# Training for 500 iteration for each Beam uses 115.15247082710266 seconds.
# Beam: 0, Iter: 22001, Reward pred: -1, Reward: -1, BF Gain pred: 130.07, BF Gain: 52.51
# Beam: 1, Iter: 22001, Reward pred: 1, Reward: -1, BF Gain pred: 116.66, BF Gain: 56.85
# Beam: 2, Iter: 22001, Reward pred: 1, Reward: -1, BF Gain pred: 76.47, BF Gain: 18.77
# Beam: 3, Iter: 22001, Reward pred: -1, Reward: -1, BF Gain pred: 200.58, BF Gain: 43.18
# Training for 500 iteration for each Beam uses 115.25903391838074 seconds.
# Beam: 0, Iter: 22501, Reward pred: 1, Reward: -1, BF Gain pred: 124.00, BF Gain: 65.94
# Beam: 1, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 88.79, BF Gain: 43.48
# Beam: 2, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 84.70, BF Gain: 15.99
# Beam: 3, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 226.24, BF Gain: 91.50
# Training for 500 iteration for each Beam uses 114.71801233291626 seconds.
# Beam: 0, Iter: 23001, Reward pred: 1, Reward: -1, BF Gain pred: 113.94, BF Gain: 44.46
# Beam: 1, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 114.35, BF Gain: 44.39
# Beam: 2, Iter: 23001, Reward pred: 1, Reward: -1, BF Gain pred: 78.52, BF Gain: 23.46
# Beam: 3, Iter: 23001, Reward pred: 1, Reward: -1, BF Gain pred: 235.63, BF Gain: 119.17
# Training for 500 iteration for each Beam uses 115.18221497535706 seconds.
# Beam: 0, Iter: 23501, Reward pred: 1, Reward: -1, BF Gain pred: 122.36, BF Gain: 46.68
# Beam: 1, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 113.02, BF Gain: 42.33
# Beam: 2, Iter: 23501, Reward pred: 1, Reward: -1, BF Gain pred: 88.95, BF Gain: 46.31
# Beam: 3, Iter: 23501, Reward pred: 1, Reward: -1, BF Gain pred: 203.41, BF Gain: 44.16
# Training for 500 iteration for each Beam uses 115.63462209701538 seconds.
# Beam: 0, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 103.97, BF Gain: 68.68
# Beam: 1, Iter: 24001, Reward pred: 1, Reward: -1, BF Gain pred: 112.82, BF Gain: 37.05
# Beam: 2, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 72.32, BF Gain: 15.33
# Beam: 3, Iter: 24001, Reward pred: 1, Reward: -1, BF Gain pred: 226.69, BF Gain: 70.17
# Training for 500 iteration for each Beam uses 115.92553067207336 seconds.
# Beam: 0, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 143.33, BF Gain: 68.51
# Beam: 1, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 129.90, BF Gain: 61.85
# Beam: 2, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 59.64, BF Gain: 18.46
# Beam: 3, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 231.35, BF Gain: 49.12
# Training for 500 iteration for each Beam uses 117.43060636520386 seconds.
# Beam: 0, Iter: 25001, Reward pred: 1, Reward: -1, BF Gain pred: 156.05, BF Gain: 53.19
# Beam: 1, Iter: 25001, Reward pred: 1, Reward: -1, BF Gain pred: 120.08, BF Gain: 51.79
# Beam: 2, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 92.32, BF Gain: 21.33
# Beam: 3, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 209.92, BF Gain: 79.65
# Training for 500 iteration for each Beam uses 116.87836289405823 seconds.
# Beam: 0, Iter: 25501, Reward pred: 1, Reward: -1, BF Gain pred: 133.84, BF Gain: 37.93
# Beam: 1, Iter: 25501, Reward pred: -1, Reward: -1, BF Gain pred: 112.06, BF Gain: 40.02
# Beam: 2, Iter: 25501, Reward pred: 1, Reward: -1, BF Gain pred: 78.18, BF Gain: 47.91
# Beam: 3, Iter: 25501, Reward pred: -1, Reward: -1, BF Gain pred: 203.90, BF Gain: 62.93
# Training for 500 iteration for each Beam uses 116.99523997306824 seconds.
# Beam: 0, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 137.48, BF Gain: 51.12
# Beam: 1, Iter: 26001, Reward pred: 1, Reward: -1, BF Gain pred: 121.39, BF Gain: 39.00
# Beam: 2, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 69.37, BF Gain: 28.40
# Beam: 3, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 242.46, BF Gain: 97.90
# Training for 500 iteration for each Beam uses 115.66946506500244 seconds.
# Beam: 0, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 117.37, BF Gain: 39.73
# Beam: 1, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 98.82, BF Gain: 23.19
# Beam: 2, Iter: 26501, Reward pred: 1, Reward: -1, BF Gain pred: 95.94, BF Gain: 14.24
# Beam: 3, Iter: 26501, Reward pred: 1, Reward: -1, BF Gain pred: 243.14, BF Gain: 121.49
# Training for 500 iteration for each Beam uses 115.29591584205627 seconds.
# Beam: 0, Iter: 27001, Reward pred: 1, Reward: -1, BF Gain pred: 139.59, BF Gain: 46.91
# Beam: 1, Iter: 27001, Reward pred: -1, Reward: -1, BF Gain pred: 120.95, BF Gain: 30.16
# Beam: 2, Iter: 27001, Reward pred: 1, Reward: -1, BF Gain pred: 89.93, BF Gain: 27.40
# Beam: 3, Iter: 27001, Reward pred: 1, Reward: -1, BF Gain pred: 282.53, BF Gain: 144.51
# Training for 500 iteration for each Beam uses 116.01008152961731 seconds.
# Beam: 0, Iter: 27501, Reward pred: -1, Reward: -1, BF Gain pred: 99.01, BF Gain: 59.58
# Beam: 1, Iter: 27501, Reward pred: 1, Reward: -1, BF Gain pred: 113.96, BF Gain: 44.58
# Beam: 2, Iter: 27501, Reward pred: -1, Reward: -1, BF Gain pred: 87.31, BF Gain: 21.00
# Beam: 3, Iter: 27501, Reward pred: -1, Reward: -1, BF Gain pred: 268.30, BF Gain: 106.85
# Training for 500 iteration for each Beam uses 115.84566569328308 seconds.
# Beam: 0, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 130.30, BF Gain: 58.92
# Beam: 1, Iter: 28001, Reward pred: 1, Reward: -1, BF Gain pred: 124.93, BF Gain: 44.02
# Beam: 2, Iter: 28001, Reward pred: 1, Reward: -1, BF Gain pred: 89.30, BF Gain: 35.29
# Beam: 3, Iter: 28001, Reward pred: 1, Reward: -1, BF Gain pred: 245.10, BF Gain: 86.00
# Training for 500 iteration for each Beam uses 116.0046033859253 seconds.
# Beam: 0, Iter: 28501, Reward pred: 1, Reward: -1, BF Gain pred: 136.08, BF Gain: 60.86
# Beam: 1, Iter: 28501, Reward pred: 1, Reward: -1, BF Gain pred: 124.37, BF Gain: 31.96
# Beam: 2, Iter: 28501, Reward pred: -1, Reward: -1, BF Gain pred: 87.19, BF Gain: 13.95
# Beam: 3, Iter: 28501, Reward pred: 1, Reward: -1, BF Gain pred: 260.00, BF Gain: 114.10
# Training for 500 iteration for each Beam uses 115.91217637062073 seconds.
# Beam: 0, Iter: 29001, Reward pred: 1, Reward: -1, BF Gain pred: 134.04, BF Gain: 48.84
# Beam: 1, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 117.90, BF Gain: 48.06
# Beam: 2, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 87.64, BF Gain: 37.10
# Beam: 3, Iter: 29001, Reward pred: 1, Reward: -1, BF Gain pred: 261.30, BF Gain: 52.18
# Training for 500 iteration for each Beam uses 116.765798330307 seconds.
# Beam: 0, Iter: 29501, Reward pred: 1, Reward: -1, BF Gain pred: 156.63, BF Gain: 96.09
# Beam: 1, Iter: 29501, Reward pred: 1, Reward: -1, BF Gain pred: 122.33, BF Gain: 44.38
# Beam: 2, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 71.17, BF Gain: 10.81
# Beam: 3, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 241.45, BF Gain: 52.14
# Training for 500 iteration for each Beam uses 116.65433645248413 seconds.
# Beam: 0, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 139.69, BF Gain: 45.40
# Beam: 1, Iter: 30001, Reward pred: 1, Reward: -1, BF Gain pred: 140.92, BF Gain: 74.35
# Beam: 2, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 85.94, BF Gain: 41.50
# Beam: 3, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 271.37, BF Gain: 67.99
# Training for 500 iteration for each Beam uses 116.81640076637268 seconds.
# Beam: 0, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 144.21, BF Gain: 68.38
# Beam: 1, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 96.75, BF Gain: 30.55
# Beam: 2, Iter: 30501, Reward pred: 1, Reward: -1, BF Gain pred: 86.01, BF Gain: 56.04
# Beam: 3, Iter: 30501, Reward pred: 1, Reward: -1, BF Gain pred: 254.20, BF Gain: 97.29
# Training for 500 iteration for each Beam uses 117.5461175441742 seconds.
# Beam: 0, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 154.02, BF Gain: 44.22
# Beam: 1, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 106.36, BF Gain: 24.25
# Beam: 2, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 97.01, BF Gain: 52.42
# Beam: 3, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 237.39, BF Gain: 105.70
# Training for 500 iteration for each Beam uses 116.00838446617126 seconds.
# Beam: 0, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 156.75, BF Gain: 67.53
# Beam: 1, Iter: 31501, Reward pred: 1, Reward: -1, BF Gain pred: 131.65, BF Gain: 44.24
# Beam: 2, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 87.89, BF Gain: 38.10
# Beam: 3, Iter: 31501, Reward pred: 1, Reward: -1, BF Gain pred: 223.62, BF Gain: 62.83
# Training for 500 iteration for each Beam uses 116.39993143081665 seconds.
# Beam: 0, Iter: 32001, Reward pred: 1, Reward: -1, BF Gain pred: 145.01, BF Gain: 40.89
# Beam: 1, Iter: 32001, Reward pred: 1, Reward: -1, BF Gain pred: 120.48, BF Gain: 41.69
# Beam: 2, Iter: 32001, Reward pred: 1, Reward: -1, BF Gain pred: 99.11, BF Gain: 31.16
# Beam: 3, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 242.76, BF Gain: 73.26
# Training for 500 iteration for each Beam uses 116.46296072006226 seconds.
# Beam: 0, Iter: 32501, Reward pred: 1, Reward: -1, BF Gain pred: 159.10, BF Gain: 73.63
# Beam: 1, Iter: 32501, Reward pred: 1, Reward: -1, BF Gain pred: 100.07, BF Gain: 47.31
# Beam: 2, Iter: 32501, Reward pred: 1, Reward: -1, BF Gain pred: 85.51, BF Gain: 14.95
# Beam: 3, Iter: 32501, Reward pred: -1, Reward: -1, BF Gain pred: 207.83, BF Gain: 108.02
# Training for 500 iteration for each Beam uses 116.80136966705322 seconds.
# Beam: 0, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 147.04, BF Gain: 55.69
# Beam: 1, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 117.03, BF Gain: 24.78
# Beam: 2, Iter: 33001, Reward pred: 1, Reward: -1, BF Gain pred: 96.52, BF Gain: 30.00
# Beam: 3, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 242.51, BF Gain: 100.32
# Training for 500 iteration for each Beam uses 116.20049381256104 seconds.
# Beam: 0, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 107.78, BF Gain: 42.57
# Beam: 1, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 125.53, BF Gain: 87.26
# Beam: 2, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 96.21, BF Gain: 36.57
# Beam: 3, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 262.31, BF Gain: 97.31
# Training for 500 iteration for each Beam uses 116.51369738578796 seconds.
# Beam: 0, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 137.93, BF Gain: 48.83
# Beam: 1, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 139.67, BF Gain: 66.49
# Beam: 2, Iter: 34001, Reward pred: 1, Reward: -1, BF Gain pred: 100.19, BF Gain: 54.49
# Beam: 3, Iter: 34001, Reward pred: 1, Reward: -1, BF Gain pred: 275.38, BF Gain: 79.86
# Training for 500 iteration for each Beam uses 116.48040962219238 seconds.
# Beam: 0, Iter: 34501, Reward pred: 1, Reward: -1, BF Gain pred: 138.61, BF Gain: 40.08
# Beam: 1, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 123.53, BF Gain: 23.27
# Beam: 2, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 97.04, BF Gain: 50.41
# Beam: 3, Iter: 34501, Reward pred: 1, Reward: -1, BF Gain pred: 265.80, BF Gain: 83.17
# Training for 500 iteration for each Beam uses 117.87095308303833 seconds.
# Beam: 0, Iter: 35001, Reward pred: 1, Reward: -1, BF Gain pred: 141.13, BF Gain: 54.10
# Beam: 1, Iter: 35001, Reward pred: 1, Reward: -1, BF Gain pred: 125.40, BF Gain: 54.01
# Beam: 2, Iter: 35001, Reward pred: 1, Reward: -1, BF Gain pred: 101.12, BF Gain: 35.48
# Beam: 3, Iter: 35001, Reward pred: 1, Reward: -1, BF Gain pred: 255.75, BF Gain: 82.40
# Training for 500 iteration for each Beam uses 117.0669903755188 seconds.
# Beam: 0, Iter: 35501, Reward pred: 1, Reward: -1, BF Gain pred: 150.93, BF Gain: 86.63
# Beam: 1, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 97.98, BF Gain: 46.61
# Beam: 2, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 89.71, BF Gain: 29.62
# Beam: 3, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 243.97, BF Gain: 63.57
# Training for 500 iteration for each Beam uses 115.61106753349304 seconds.
# Beam: 0, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 134.17, BF Gain: 49.12
# Beam: 1, Iter: 36001, Reward pred: 1, Reward: -1, BF Gain pred: 126.16, BF Gain: 67.36
# Beam: 2, Iter: 36001, Reward pred: 1, Reward: -1, BF Gain pred: 101.83, BF Gain: 37.63
# Beam: 3, Iter: 36001, Reward pred: 1, Reward: -1, BF Gain pred: 279.56, BF Gain: 159.75
# Training for 500 iteration for each Beam uses 116.27759838104248 seconds.
# Beam: 0, Iter: 36501, Reward pred: 1, Reward: -1, BF Gain pred: 153.47, BF Gain: 35.10
# Beam: 1, Iter: 36501, Reward pred: 1, Reward: -1, BF Gain pred: 137.45, BF Gain: 51.71
# Beam: 2, Iter: 36501, Reward pred: 1, Reward: -1, BF Gain pred: 96.87, BF Gain: 59.96
# Beam: 3, Iter: 36501, Reward pred: -1, Reward: -1, BF Gain pred: 236.72, BF Gain: 105.03
# Training for 500 iteration for each Beam uses 116.27574133872986 seconds.
# Beam: 0, Iter: 37001, Reward pred: 1, Reward: -1, BF Gain pred: 153.04, BF Gain: 59.34
# Beam: 1, Iter: 37001, Reward pred: -1, Reward: -1, BF Gain pred: 112.38, BF Gain: 66.46
# Beam: 2, Iter: 37001, Reward pred: 1, Reward: -1, BF Gain pred: 96.73, BF Gain: 35.93
# Beam: 3, Iter: 37001, Reward pred: 1, Reward: -1, BF Gain pred: 239.90, BF Gain: 100.22
# Training for 500 iteration for each Beam uses 115.91499519348145 seconds.
# Beam: 0, Iter: 37501, Reward pred: 1, Reward: -1, BF Gain pred: 136.03, BF Gain: 51.17
# Beam: 1, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 125.66, BF Gain: 43.36
# Beam: 2, Iter: 37501, Reward pred: 1, Reward: -1, BF Gain pred: 101.14, BF Gain: 39.15
# Beam: 3, Iter: 37501, Reward pred: 1, Reward: -1, BF Gain pred: 272.48, BF Gain: 124.51
# Training for 500 iteration for each Beam uses 115.74139952659607 seconds.
# Beam: 0, Iter: 38001, Reward pred: 1, Reward: -1, BF Gain pred: 168.94, BF Gain: 70.37
# Beam: 1, Iter: 38001, Reward pred: 1, Reward: -1, BF Gain pred: 141.63, BF Gain: 63.90
# Beam: 2, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 97.55, BF Gain: 34.81
# Beam: 3, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 267.40, BF Gain: 145.18
# Training for 500 iteration for each Beam uses 115.98567771911621 seconds.
# Beam: 0, Iter: 38501, Reward pred: 1, Reward: -1, BF Gain pred: 148.27, BF Gain: 103.56
# Beam: 1, Iter: 38501, Reward pred: 1, Reward: -1, BF Gain pred: 127.00, BF Gain: 42.26
# Beam: 2, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 101.39, BF Gain: 37.05
# Beam: 3, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 245.13, BF Gain: 66.49
# Training for 500 iteration for each Beam uses 116.6266405582428 seconds.
# Beam: 0, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 151.52, BF Gain: 61.58
# Beam: 1, Iter: 39001, Reward pred: 1, Reward: -1, BF Gain pred: 135.26, BF Gain: 53.96
# Beam: 2, Iter: 39001, Reward pred: 1, Reward: -1, BF Gain pred: 95.66, BF Gain: 25.64
# Beam: 3, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 245.54, BF Gain: 52.17
# Training for 500 iteration for each Beam uses 116.92310166358948 seconds.
# Beam: 0, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 129.65, BF Gain: 44.12
# Beam: 1, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 124.37, BF Gain: 51.96
# Beam: 2, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 95.73, BF Gain: 37.77
# Beam: 3, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 234.54, BF Gain: 118.15
# Training for 500 iteration for each Beam uses 116.01436400413513 seconds.
# Beam: 0, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 142.95, BF Gain: 60.27
# Beam: 1, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 132.52, BF Gain: 59.26
# Beam: 2, Iter: 40001, Reward pred: 1, Reward: -1, BF Gain pred: 97.51, BF Gain: 51.64
# Beam: 3, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 263.45, BF Gain: 90.28
# Training for 500 iteration for each Beam uses 116.89069199562073 seconds.

# %%
import numpy as np
import scipy.io as scio

num_ant = 32
num_beam = 4
results = np.empty((num_beam, 2*num_ant))

path = './beams/'

for beam_id in range(num_beam):
    fname = 'beams_' + str(beam_id) + '_max.txt'
    with open(path + fname, 'r') as f:
        lines = f.readlines()
        last_line = lines[-1]
        results[beam_id, :] = np.fromstring(last_line.replace("\n", ""), sep=',').reshape(1, -1)

results = (1 / np.sqrt(num_ant)) * (results[:, ::2] + 1j * results[:, 1::2])

scio.savemat('beam_codebook.mat', {'beams': results})

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(12, 8))
plt.title(f'Best beamforming gain')
plt.xlabel('Beam_framing_gain')   
for beam_id in range(options['num_NNs']):
    gain_record=np.array(env_list[beam_id].gain_history[1:])
    np.save(f'beam_{beam_id}_gain_records',gain_record)
    plt.plot(gain_record, label=f'Beam_{beam_id}')
    plt.plot([])
plt.plot([231.17094]*40000,linestyle='dashed',color='black')
plt.legend(loc="lower right")  
plt.show()
