# %%
# !git clone https://github.com/YuZhang-GitHub/Codebook_Learning_RL.git
# Out:
# Cloning into 'Codebook_Learning_RL'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 77 (delta 5), reused 0 (delta 0), pack-reused 59
# Receiving objects: 100% (77/77), 14.41 MiB | 27.90 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# !pip install pfrl
# Out:
# Collecting pfrl
#   Downloading pfrl-0.4.0.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.6/112.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pfrl) (2.0.0)
# Requirement already satisfied: gym>=0.9.7 in /opt/conda/lib/python3.10/site-packages (from pfrl) (0.26.2)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/lib/python3.10/site-packages (from pfrl) (1.23.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from pfrl) (9.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from pfrl) (3.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (0.0.8)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.3.0->pfrl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.3.0->pfrl) (1.3.0)
# Building wheels for collected packages: pfrl
#   Building wheel for pfrl (setup.py) ... done
#   Created wheel for pfrl: filename=pfrl-0.4.0-py3-none-any.whl size=155465 sha256=447fa3fa742c5c80563a2f2e418dadcffd593c49c1870fee3854e0bf4c1c298b
#   Stored in directory: /root/.cache/pip/wheels/22/4a/0f/a87cd1ae925086eb3a1b8759f620fcf48e47939fb082946c3b
# Successfully built pfrl
# Installing collected packages: pfrl
# Successfully installed pfrl-0.4.0

# %%
# from Codebook_Learning_RL import DDPG_classes

# %%
import os
os.chdir('/kaggle/working/Codebook_Learning_RL')
print(os.getcwd())
# Out:
# /kaggle/working/Codebook_Learning_RL

# %%
import pfrl
import os
import time
import torch
import numpy as np
import copy
import pickle
from torch import nn
from scipy.optimize import linear_sum_assignment
from DataPrep import dataPrep
from env_ddpg import envCB
from clustering import KMeans_only
from function_lib import bf_gain_cal, corr_mining
from DDPG_classes import OUNoise
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
options = {
        'gpu_idx': 0,
        'num_ant': 32,
        'num_bits': 4,
        'num_NNs': 4,  # codebook size
        'ch_sample_ratio': 0.5,
        'num_loop': 400,  # outer loop
        'target_update': 3,
        'path': './grid1101-1400.mat',
        'clustering_mode': 'random',
    }

train_opt = {
        'state': 0,
        'best_state': 0,
        'num_iter': 100,  # inner loop
        'tau': 1e-2,
        'overall_iter': 1,
        'replay_memory': [],
        'replay_memory_size': 8192,
        'minibatch_size': 1024,
        'gamma': 0,
        'gpu':0
    }
if not os.path.exists('beams/'):
    os.mkdir('beams/')

ch = dataPrep(options['path'])
ch = np.concatenate((ch[:, :options['num_ant']],
                     ch[:, int(ch.shape[1] / 2):int(ch.shape[1] / 2) + options['num_ant']]), axis=1)
u_classifier, sensing_beam = KMeans_only(ch, options['num_NNs'], n_bit=options['num_bits'], n_rand_beam=30)
np.save('sensing_beam.npy', sensing_beam)
sensing_beam = torch.from_numpy(sensing_beam).float().cuda()

filename = 'kmeans_model.sav'
pickle.dump(u_classifier, open(filename, 'wb'))

# Quantization settings
options['num_ph'] = 2 ** options['num_bits']
options['multi_step'] = torch.from_numpy(
    np.linspace(int(-(options['num_ph'] - 2) / 2),
                int(options['num_ph'] / 2),
                num=options['num_ph'],
                endpoint=True)).type(dtype=torch.float32).reshape(1, -1).cuda()
options['pi'] = torch.tensor(np.pi).cuda()
options['ph_table'] = (2 * options['pi']) / options['num_ph'] * options['multi_step']
options['ph_table'].cuda()
options['ph_table_rep'] = options['ph_table'].repeat(options['num_ant'], 1)
actor_net_list = []
critic_net_list = []
actor_net_t_list = []
critic_net_t_list = []
ounoise_list = []
env_list = []
train_opt_list = []
agent_list=[]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from pfrl.utils.batch_states import batch_states
def batch_experiences_(experiences, device, phi, gamma, batch_states=batch_states):
    """Takes a batch of k experiences each of which contains j

    consecutive transitions and vectorizes them, where j is between 1 and n.

    Args:
        experiences: list of experiences. Each experience is a list
            containing between 1 and n dicts containing
              - state (object): State
              - action (object): Action
              - reward (float): Reward
              - is_state_terminal (bool): True iff next state is terminal
              - next_state (object): Next state
        device : GPU or CPU the tensor should be placed on
        phi : Preprocessing function
        gamma: discount factor
        batch_states: function that converts a list to a batch
    Returns:
        dict of batched transitions
    """

    batch_exp = {
        "state": batch_states([elem[0]["state"] for elem in experiences], device, phi),
        "action": torch.as_tensor(
            np.array([elem[0]["action"] for elem in experiences]), device=device
        ),
        "reward": torch.as_tensor(
            [
                sum((gamma**i) * exp[i]["reward"] for i in range(len(exp)))
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "next_state": batch_states(
            [elem[-1]["next_state"] for elem in experiences], device, phi
        ),
        "is_state_terminal": torch.as_tensor(
            [
                any(transition["is_state_terminal"] for transition in exp)
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "discount": torch.as_tensor(
            [(gamma ** len(elem)) for elem in experiences],
            dtype=torch.float32,
            device=device,
        ),
    }
    if all(elem[-1]["next_action"] is not None for elem in experiences):
        batch_exp["next_action"] = torch.as_tensor(
            [elem[-1]["next_action"] for elem in experiences], device=device
        )
    return batch_exp

from pfrl.agents.ddpg import DDPG
class DDPG_(DDPG):
    def update(self, experiences, errors_out=None):
        """Update the model from experiences"""

        batch = batch_experiences_(experiences, self.device, self.phi, self.gamma)

        self.critic_optimizer.zero_grad()
        self.compute_critic_loss(batch).backward()
        self.critic_optimizer.step()

        self.actor_optimizer.zero_grad()
        self.compute_actor_loss(batch).backward()
        self.actor_optimizer.step()

        self.n_updates += 1

# %%
import pfrl
from pfrl import experiments, explorers, replay_buffers, utils
from pfrl.agents.ddpg import DDPG
from pfrl.nn import BoundByTanh, ConcatObsAndAction
from pfrl.policies import DeterministicHead
from pfrl.explorers import Greedy

def create_agent(state_size,action_size,train_options,gpu=0):
    
    #critic_network
    q_func = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    #actor_network
    policy = nn.Sequential(
        nn.Linear(state_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, action_size),
        BoundByTanh(low= -torch.tensor(np.pi).float(), high= torch.tensor(np.pi).float()),
        DeterministicHead(),
    )
    
    opt_a = torch.optim.Adam(policy.parameters(), lr=1e-3, weight_decay=1e-3)
    opt_c = torch.optim.Adam(q_func.parameters(), lr=1e-3, weight_decay=1e-2)
    rbuf = replay_buffers.ReplayBuffer(train_options['replay_memory_size'])
    
    explorer =  Greedy()
    
    agent = DDPG_(
        policy,
        q_func,
        opt_a,
        opt_c,
        rbuf,
        gamma=train_options['gamma'],
        explorer = explorer,
        replay_start_size=train_options['minibatch_size'],
        target_update_method="soft",
        target_update_interval=options['target_update'],
        update_interval=1,
        soft_update_tau= train_opt['tau'],
        n_times_update=1,
        gpu=gpu,
        minibatch_size=train_options['minibatch_size'],
    )
    
    return agent

# %%
def train(
          env,
          options,
          train_options,
          agent,
          ounoise,
          beam_id):
    
#     action_pred_noisy = ounoise.get_action(action_pred,
#                                                t=train_options['overall_iter'])
    CB_Env = env   
    if train_options['overall_iter'] == 1:
        state = torch.zeros((1, options['num_ant'])).float().cuda()
        print('Initial State Activated.')
    else:
        state = train_options['state']
    
    
    #training_loop
    iteration = 0
    num_of_iter = train_options['num_iter']  
    while iteration < num_of_iter:

        
        action = agent.act(state)
#         print(type(agent.batch_last_action),agent.batch_last_action)
        reward_pred, bf_gain_pred, action_quant_pred, state_1_pred = CB_Env.get_reward(torch.Tensor(action).to('cuda'))
        reward_pred = torch.from_numpy(reward_pred).float().cuda()
        
        action_pred_noisy = ounoise.get_action(torch.Tensor(action).to('cuda'), t=train_options['overall_iter'])
        mat_dist = torch.abs(action_pred_noisy.reshape(options['num_ant'], 1) - options['ph_table_rep'])
        action_quant = options['ph_table_rep'][range(options['num_ant']), torch.argmin(mat_dist, dim=1)].reshape(1, -1)
   
        state_1, reward, bf_gain, terminal = CB_Env.step(action_quant)
        reward = torch.from_numpy(reward).float().cuda()
        action = action_quant.reshape((1, -1)).float().cuda()
        
        
#         print(type(action_quant_pred.cpu().numpy()),action_quant_pred.cpu().numpy().shape)
#         print(type(action.cpu().numpy()),action.cpu().numpy().shape)
        agent.replay_buffer.append(
                    state=state,
                    action=action_quant_pred.cpu().numpy(),
                    reward=reward_pred,
                    next_state=state_1_pred,
                    next_action=None,
                    is_state_terminal=terminal,
                    env_id=0,
                )
#         print(agent.batch_last_action,agent.batch_last_action[0].shape)
        agent.batch_last_action = [action.cpu().numpy()] #because the critic is expecting quantizazed actions
        agent.observe(state_1, reward, terminal, False)

        
        iteration += 1
        train_options['overall_iter'] += 1
        state = state_1

    train_options['state'] = state  # used for the next loop
    train_options['best_state'] = CB_Env.best_bf_vec  # used for clustering and assignment
    if (train_options['overall_iter']-1)%500==0:
#         print(
#             "Beam: %d, Iter: %d, Reward: %d, BF Gain: %.2f" % \
#             (beam_id, 
#              train_options['overall_iter'],
#              int(torch.Tensor.cpu(reward).numpy().squeeze()),
#              torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))
        print(
            "Beam: %d, Iter: %d, Reward pred: %d, Reward: %d, BF Gain pred: %.2f, BF Gain: %.2f" % \
            (beam_id, train_options['overall_iter'],
             int(torch.Tensor.cpu(reward_pred).numpy().squeeze()),
             int(torch.Tensor.cpu(reward).numpy().squeeze()),
             torch.Tensor.cpu(bf_gain_pred.detach()).numpy().squeeze(),
             torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))      
    
    return train_options

# %%
for beam_id in range(options['num_NNs']):
    ounoise_list.append(OUNoise((1, options['num_ant'])))
    env_list.append(envCB(ch, options['num_ant'], options['num_bits'], beam_id, options))
    train_opt_list.append(copy.deepcopy(train_opt))
    agent = create_agent(options['num_ant'],options['num_ant'],train_opt_list[beam_id],gpu=train_opt['gpu'])
    agent_list.append(agent)
    ounoise_list.append(OUNoise((1, options['num_ant'])))
# Out:
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094

# %%
for sample_id in range(options['num_loop']):

    # ---------- Sampling ---------- #
    n_sample = int(ch.shape[0] * options['ch_sample_ratio'])
    ch_sample_id = np.random.permutation(ch.shape[0])[0:n_sample]
    ch_sample = torch.from_numpy(ch[ch_sample_id, :]).float().cuda()

    # ---------- Clustering ---------- #
#     start_time = time.time()

    bf_mat_sample = bf_gain_cal(sensing_beam, ch_sample)
    # print("Clustering -1 uses %s seconds." % (time.time() - start_time))
    # start_time = time.time()
    f_matrix = corr_mining(bf_mat_sample)
    f_matrix_np = torch.Tensor.cpu(f_matrix).numpy()
    # print("Clustering 0 uses %s seconds." % (time.time() - start_time))
    # start_time = time.time()
    labels = u_classifier.predict(np.transpose(f_matrix_np).astype(float))

    # print("Clustering 1 uses %s seconds." % (time.time() - start_time))
    # start_time = time.time()

    user_group = []  # order: clusters
    ch_group = []  # order: clusters
    for ii in range(options['num_NNs']):
        user_group.append(np.where(labels == ii)[0].tolist())
        ch_group.append(ch_sample[user_group[ii], :])

#     print("Clustering 2 uses %s seconds." % (time.time() - start_time))

    # ---------- Assignment ---------- #
#     start_time = time.time()

    # best_state matrix
    best_beam_mtx = torch.zeros((options['num_NNs'], 2 * options['num_ant'])).float().cuda()
    for pp in range(options['num_NNs']):
        best_beam_mtx[pp, :] = env_list[pp].best_bf_vec
    gain_mtx = bf_gain_cal(best_beam_mtx, ch_sample)  # (n_beam, n_user)
    for ii in range(options['num_NNs']):
        if ii == 0:
            cost_mtx = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
        else:
            sub = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
            cost_mtx = torch.cat((cost_mtx, sub), dim=1)
    cost_mtx = -torch.Tensor.cpu(cost_mtx).numpy()
    row_ind, col_ind = linear_sum_assignment(cost_mtx)
    assignment_record = dict(zip(row_ind.tolist(), col_ind.tolist()))  # key: network, value: cluster
    for ii in range(options['num_NNs']):
        env_list[ii].ch = ch_group[assignment_record[ii]]

#     print("Assignment uses %s seconds." % (time.time() - start_time))
    if (train_opt_list[beam_id]['overall_iter']-1)%500==0 or train_opt_list[beam_id]['overall_iter']==1:
        start_time = time.time()
    for beam_id in range(options['num_NNs']):
        train_opt_list[beam_id] = train(env_list[beam_id],options, train_opt_list[beam_id],agent_list[beam_id],ounoise_list[beam_id], beam_id)
    if (train_opt_list[beam_id]['overall_iter']-1)%500==0: 
        print("Training for 500 iteration for each Beam uses %s seconds." % (time.time() - start_time))
# Out:
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Beam: 0, Iter: 501, Reward pred: -1, Reward: 1, BF Gain pred: 0.74, BF Gain: 14.46
# Beam: 1, Iter: 501, Reward pred: -1, Reward: 1, BF Gain pred: 6.13, BF Gain: 9.59
# Beam: 2, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 1.98, BF Gain: 21.18
# Beam: 3, Iter: 501, Reward pred: -1, Reward: 1, BF Gain pred: 1.49, BF Gain: 10.89
# Training for 500 iteration for each Beam (2000 iteration) uses 2.5970346927642822 seconds.
# Beam: 0, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 0.73, BF Gain: 0.79
# Beam: 1, Iter: 1001, Reward pred: -1, Reward: 1, BF Gain pred: 0.69, BF Gain: 1.91
# Beam: 2, Iter: 1001, Reward pred: -1, Reward: 1, BF Gain pred: 0.22, BF Gain: 2.74
# Beam: 3, Iter: 1001, Reward pred: -1, Reward: 1, BF Gain pred: 1.67, BF Gain: 2.52
# Training for 500 iteration for each Beam (2000 iteration) uses 18.466212511062622 seconds.
# Beam: 0, Iter: 1501, Reward pred: -1, Reward: 1, BF Gain pred: 1.19, BF Gain: 12.64
# Beam: 1, Iter: 1501, Reward pred: 1, Reward: 1, BF Gain pred: 1.18, BF Gain: 5.10
# Beam: 2, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 14.96, BF Gain: 14.66
# Beam: 3, Iter: 1501, Reward pred: -1, Reward: 1, BF Gain pred: 0.27, BF Gain: 1.00
# Training for 500 iteration for each Beam (2000 iteration) uses 18.554142951965332 seconds.
# Beam: 0, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 6.26, BF Gain: 10.71
# Beam: 1, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 4.09, BF Gain: 11.66
# Beam: 2, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 1.96, BF Gain: 5.50
# Beam: 3, Iter: 2001, Reward pred: -1, Reward: 1, BF Gain pred: 0.11, BF Gain: 3.32
# Training for 500 iteration for each Beam (2000 iteration) uses 18.56185221672058 seconds.
# Beam: 0, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 12.98, BF Gain: 6.08
# Beam: 1, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 3.97, BF Gain: 0.63
# Beam: 2, Iter: 2501, Reward pred: 1, Reward: -1, BF Gain pred: 5.74, BF Gain: 1.45
# Beam: 3, Iter: 2501, Reward pred: 1, Reward: 1, BF Gain pred: 8.30, BF Gain: 3.17
# Training for 500 iteration for each Beam (2000 iteration) uses 18.541121244430542 seconds.
# Beam: 0, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 12.30, BF Gain: 15.44
# Beam: 1, Iter: 3001, Reward pred: -1, Reward: -1, BF Gain pred: 16.90, BF Gain: 2.66
# Beam: 2, Iter: 3001, Reward pred: -1, Reward: 1, BF Gain pred: 4.55, BF Gain: 6.79
# Beam: 3, Iter: 3001, Reward pred: -1, Reward: -1, BF Gain pred: 13.42, BF Gain: 1.15
# Training for 500 iteration for each Beam (2000 iteration) uses 18.574551582336426 seconds.
# Beam: 0, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 13.24, BF Gain: 5.05
# Beam: 1, Iter: 3501, Reward pred: 1, Reward: -1, BF Gain pred: 18.33, BF Gain: 1.64
# Beam: 2, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 5.59, BF Gain: 6.82
# Beam: 3, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 10.78, BF Gain: 17.18
# Training for 500 iteration for each Beam (2000 iteration) uses 18.731362342834473 seconds.
# Beam: 0, Iter: 4001, Reward pred: 1, Reward: -1, BF Gain pred: 23.47, BF Gain: 6.94
# Beam: 1, Iter: 4001, Reward pred: 1, Reward: -1, BF Gain pred: 14.16, BF Gain: 3.52
# Beam: 2, Iter: 4001, Reward pred: 1, Reward: -1, BF Gain pred: 17.45, BF Gain: 3.63
# Beam: 3, Iter: 4001, Reward pred: -1, Reward: 1, BF Gain pred: 2.71, BF Gain: 5.06
# Training for 500 iteration for each Beam (2000 iteration) uses 18.986135959625244 seconds.
# Beam: 0, Iter: 4501, Reward pred: 1, Reward: -1, BF Gain pred: 21.68, BF Gain: 5.63
# Beam: 1, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 3.93, BF Gain: 1.27
# Beam: 2, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 6.40, BF Gain: 4.42
# Beam: 3, Iter: 4501, Reward pred: 1, Reward: -1, BF Gain pred: 16.32, BF Gain: 3.26
# Training for 500 iteration for each Beam (2000 iteration) uses 19.732962608337402 seconds.
# Beam: 0, Iter: 5001, Reward pred: 1, Reward: -1, BF Gain pred: 25.02, BF Gain: 2.97
# Beam: 1, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 16.17, BF Gain: 7.50
# Beam: 2, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 40.11, BF Gain: 16.89
# Beam: 3, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 2.05, BF Gain: 0.96
# Training for 500 iteration for each Beam (2000 iteration) uses 19.33447551727295 seconds.
# Beam: 0, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 15.24, BF Gain: 11.16
# Beam: 1, Iter: 5501, Reward pred: 1, Reward: -1, BF Gain pred: 34.87, BF Gain: 18.93
# Beam: 2, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 42.26, BF Gain: 23.95
# Beam: 3, Iter: 5501, Reward pred: 1, Reward: -1, BF Gain pred: 14.00, BF Gain: 2.57
# Training for 500 iteration for each Beam (2000 iteration) uses 19.285077333450317 seconds.
# Beam: 0, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 36.79, BF Gain: 13.73
# Beam: 1, Iter: 6001, Reward pred: 1, Reward: -1, BF Gain pred: 34.61, BF Gain: 12.89
# Beam: 2, Iter: 6001, Reward pred: 1, Reward: -1, BF Gain pred: 30.46, BF Gain: 18.58
# Beam: 3, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 5.54, BF Gain: 5.87
# Training for 500 iteration for each Beam (2000 iteration) uses 19.47796893119812 seconds.
# Beam: 0, Iter: 6501, Reward pred: 1, Reward: -1, BF Gain pred: 79.88, BF Gain: 18.82
# Beam: 1, Iter: 6501, Reward pred: 1, Reward: -1, BF Gain pred: 20.83, BF Gain: 13.57
# Beam: 2, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 21.67, BF Gain: 7.79
# Beam: 3, Iter: 6501, Reward pred: -1, Reward: -1, BF Gain pred: 23.31, BF Gain: 15.20
# Training for 500 iteration for each Beam (2000 iteration) uses 19.301450967788696 seconds.
# Beam: 0, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 29.70, BF Gain: 9.06
# Beam: 1, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 38.86, BF Gain: 22.58
# Beam: 2, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 50.36, BF Gain: 28.85
# Beam: 3, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 28.17, BF Gain: 21.59
# Training for 500 iteration for each Beam (2000 iteration) uses 19.34253978729248 seconds.
# Beam: 0, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 69.00, BF Gain: 13.25
# Beam: 1, Iter: 7501, Reward pred: 1, Reward: -1, BF Gain pred: 65.05, BF Gain: 11.84
# Beam: 2, Iter: 7501, Reward pred: 1, Reward: -1, BF Gain pred: 71.99, BF Gain: 11.74
# Beam: 3, Iter: 7501, Reward pred: 1, Reward: -1, BF Gain pred: 32.18, BF Gain: 26.10
# Training for 500 iteration for each Beam (2000 iteration) uses 19.54647994041443 seconds.
# Beam: 0, Iter: 8001, Reward pred: 1, Reward: -1, BF Gain pred: 126.35, BF Gain: 67.39
# Beam: 1, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 44.41, BF Gain: 22.48
# Beam: 2, Iter: 8001, Reward pred: 1, Reward: -1, BF Gain pred: 36.75, BF Gain: 21.13
# Beam: 3, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 29.98, BF Gain: 29.78
# Training for 500 iteration for each Beam (2000 iteration) uses 19.559447050094604 seconds.
# Beam: 0, Iter: 8501, Reward pred: 1, Reward: -1, BF Gain pred: 82.83, BF Gain: 51.89
# Beam: 1, Iter: 8501, Reward pred: 1, Reward: -1, BF Gain pred: 70.20, BF Gain: 2.67
# Beam: 2, Iter: 8501, Reward pred: 1, Reward: -1, BF Gain pred: 81.04, BF Gain: 29.33
# Beam: 3, Iter: 8501, Reward pred: -1, Reward: -1, BF Gain pred: 46.83, BF Gain: 8.37
# Training for 500 iteration for each Beam (2000 iteration) uses 19.378822088241577 seconds.
# Beam: 0, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 48.31, BF Gain: 20.34
# Beam: 1, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 87.39, BF Gain: 44.32
# Beam: 2, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 45.42, BF Gain: 10.87
# Beam: 3, Iter: 9001, Reward pred: 1, Reward: -1, BF Gain pred: 54.99, BF Gain: 6.17
# Training for 500 iteration for each Beam (2000 iteration) uses 18.941932678222656 seconds.
# Beam: 0, Iter: 9501, Reward pred: 1, Reward: -1, BF Gain pred: 121.74, BF Gain: 20.41
# Beam: 1, Iter: 9501, Reward pred: 1, Reward: -1, BF Gain pred: 50.54, BF Gain: 21.98
# Beam: 2, Iter: 9501, Reward pred: 1, Reward: -1, BF Gain pred: 73.88, BF Gain: 25.42
# Beam: 3, Iter: 9501, Reward pred: 1, Reward: -1, BF Gain pred: 72.97, BF Gain: 35.23
# Training for 500 iteration for each Beam (2000 iteration) uses 19.50243592262268 seconds.
# Beam: 0, Iter: 10001, Reward pred: 1, Reward: -1, BF Gain pred: 164.84, BF Gain: 43.18
# Beam: 1, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 61.58, BF Gain: 17.37
# Beam: 2, Iter: 10001, Reward pred: 1, Reward: -1, BF Gain pred: 95.98, BF Gain: 14.35
# Beam: 3, Iter: 10001, Reward pred: 1, Reward: -1, BF Gain pred: 79.42, BF Gain: 27.81
# Training for 500 iteration for each Beam (2000 iteration) uses 18.871827125549316 seconds.
# Beam: 0, Iter: 10501, Reward pred: 1, Reward: -1, BF Gain pred: 119.93, BF Gain: 30.13
# Beam: 1, Iter: 10501, Reward pred: 1, Reward: -1, BF Gain pred: 82.87, BF Gain: 42.28
# Beam: 2, Iter: 10501, Reward pred: 1, Reward: -1, BF Gain pred: 110.84, BF Gain: 29.88
# Beam: 3, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 44.62, BF Gain: 9.28
# Training for 500 iteration for each Beam (2000 iteration) uses 19.12936019897461 seconds.
# Beam: 0, Iter: 11001, Reward pred: 1, Reward: -1, BF Gain pred: 109.73, BF Gain: 2.23
# Beam: 1, Iter: 11001, Reward pred: 1, Reward: -1, BF Gain pred: 88.11, BF Gain: 29.05
# Beam: 2, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 114.66, BF Gain: 38.58
# Beam: 3, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 71.68, BF Gain: 27.79
# Training for 500 iteration for each Beam (2000 iteration) uses 18.95334529876709 seconds.
# Beam: 0, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 89.32, BF Gain: 13.62
# Beam: 1, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 80.66, BF Gain: 14.04
# Beam: 2, Iter: 11501, Reward pred: 1, Reward: -1, BF Gain pred: 137.89, BF Gain: 33.09
# Beam: 3, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 56.56, BF Gain: 23.45
# Training for 500 iteration for each Beam (2000 iteration) uses 19.71233320236206 seconds.
# Beam: 0, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 111.24, BF Gain: 33.33
# Beam: 1, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 91.66, BF Gain: 17.42
# Beam: 2, Iter: 12001, Reward pred: 1, Reward: -1, BF Gain pred: 121.14, BF Gain: 30.28
# Beam: 3, Iter: 12001, Reward pred: 1, Reward: -1, BF Gain pred: 88.26, BF Gain: 44.15
# Training for 500 iteration for each Beam (2000 iteration) uses 19.78136658668518 seconds.
# Beam: 0, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 84.11, BF Gain: 63.75
# Beam: 1, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 80.47, BF Gain: 17.16
# Beam: 2, Iter: 12501, Reward pred: 1, Reward: -1, BF Gain pred: 122.90, BF Gain: 55.43
# Beam: 3, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 81.18, BF Gain: 27.76
# Training for 500 iteration for each Beam (2000 iteration) uses 19.619167804718018 seconds.
# Beam: 0, Iter: 13001, Reward pred: 1, Reward: -1, BF Gain pred: 143.81, BF Gain: 49.41
# Beam: 1, Iter: 13001, Reward pred: 1, Reward: -1, BF Gain pred: 102.66, BF Gain: 12.74
# Beam: 2, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 107.01, BF Gain: 91.67
# Beam: 3, Iter: 13001, Reward pred: 1, Reward: -1, BF Gain pred: 62.61, BF Gain: 20.62
# Training for 500 iteration for each Beam (2000 iteration) uses 19.9336199760437 seconds.
# Beam: 0, Iter: 13501, Reward pred: 1, Reward: -1, BF Gain pred: 155.28, BF Gain: 52.57
# Beam: 1, Iter: 13501, Reward pred: 1, Reward: -1, BF Gain pred: 69.63, BF Gain: 18.03
# Beam: 2, Iter: 13501, Reward pred: 1, Reward: -1, BF Gain pred: 99.61, BF Gain: 39.80
# Beam: 3, Iter: 13501, Reward pred: -1, Reward: -1, BF Gain pred: 86.86, BF Gain: 23.10
# Training for 500 iteration for each Beam (2000 iteration) uses 19.867892742156982 seconds.
# Beam: 0, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 129.35, BF Gain: 43.54
# Beam: 1, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 106.31, BF Gain: 34.87
# Beam: 2, Iter: 14001, Reward pred: 1, Reward: -1, BF Gain pred: 129.83, BF Gain: 53.20
# Beam: 3, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 69.94, BF Gain: 28.15
# Training for 500 iteration for each Beam (2000 iteration) uses 19.6181800365448 seconds.
# Beam: 0, Iter: 14501, Reward pred: 1, Reward: -1, BF Gain pred: 166.95, BF Gain: 53.58
# Beam: 1, Iter: 14501, Reward pred: 1, Reward: -1, BF Gain pred: 107.57, BF Gain: 31.99
# Beam: 2, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 107.09, BF Gain: 18.48
# Beam: 3, Iter: 14501, Reward pred: 1, Reward: -1, BF Gain pred: 84.48, BF Gain: 18.32
# Training for 500 iteration for each Beam (2000 iteration) uses 19.160011768341064 seconds.
# Beam: 0, Iter: 15001, Reward pred: -1, Reward: -1, BF Gain pred: 102.83, BF Gain: 29.59
# Beam: 1, Iter: 15001, Reward pred: 1, Reward: -1, BF Gain pred: 99.98, BF Gain: 56.06
# Beam: 2, Iter: 15001, Reward pred: 1, Reward: -1, BF Gain pred: 118.29, BF Gain: 27.34
# Beam: 3, Iter: 15001, Reward pred: 1, Reward: -1, BF Gain pred: 85.57, BF Gain: 16.50
# Training for 500 iteration for each Beam (2000 iteration) uses 19.586777210235596 seconds.
# Beam: 0, Iter: 15501, Reward pred: 1, Reward: -1, BF Gain pred: 167.67, BF Gain: 29.87
# Beam: 1, Iter: 15501, Reward pred: 1, Reward: -1, BF Gain pred: 83.04, BF Gain: 16.99
# Beam: 2, Iter: 15501, Reward pred: 1, Reward: -1, BF Gain pred: 148.63, BF Gain: 37.93
# Beam: 3, Iter: 15501, Reward pred: 1, Reward: -1, BF Gain pred: 87.28, BF Gain: 38.31
# Training for 500 iteration for each Beam (2000 iteration) uses 19.712576150894165 seconds.
# Beam: 0, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 134.35, BF Gain: 79.08
# Beam: 1, Iter: 16001, Reward pred: 1, Reward: -1, BF Gain pred: 110.14, BF Gain: 11.84
# Beam: 2, Iter: 16001, Reward pred: 1, Reward: -1, BF Gain pred: 167.48, BF Gain: 56.12
# Beam: 3, Iter: 16001, Reward pred: 1, Reward: -1, BF Gain pred: 89.60, BF Gain: 16.86
# Training for 500 iteration for each Beam (2000 iteration) uses 20.034993886947632 seconds.
# Beam: 0, Iter: 16501, Reward pred: 1, Reward: -1, BF Gain pred: 172.89, BF Gain: 62.18
# Beam: 1, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 106.17, BF Gain: 25.84
# Beam: 2, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 126.54, BF Gain: 44.60
# Beam: 3, Iter: 16501, Reward pred: 1, Reward: -1, BF Gain pred: 90.87, BF Gain: 37.79
# Training for 500 iteration for each Beam (2000 iteration) uses 19.572320699691772 seconds.
# Beam: 0, Iter: 17001, Reward pred: 1, Reward: -1, BF Gain pred: 191.31, BF Gain: 122.48
# Beam: 1, Iter: 17001, Reward pred: -1, Reward: -1, BF Gain pred: 72.49, BF Gain: 25.93
# Beam: 2, Iter: 17001, Reward pred: -1, Reward: -1, BF Gain pred: 127.18, BF Gain: 48.84
# Beam: 3, Iter: 17001, Reward pred: 1, Reward: -1, BF Gain pred: 79.07, BF Gain: 8.45
# Training for 500 iteration for each Beam (2000 iteration) uses 19.590451955795288 seconds.
# Beam: 0, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 169.27, BF Gain: 27.65
# Beam: 1, Iter: 17501, Reward pred: 1, Reward: -1, BF Gain pred: 106.51, BF Gain: 12.28
# Beam: 2, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 119.85, BF Gain: 30.38
# Beam: 3, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 87.35, BF Gain: 28.11
# Training for 500 iteration for each Beam (2000 iteration) uses 19.777787923812866 seconds.
# Beam: 0, Iter: 18001, Reward pred: 1, Reward: -1, BF Gain pred: 184.61, BF Gain: 120.23
# Beam: 1, Iter: 18001, Reward pred: 1, Reward: -1, BF Gain pred: 130.37, BF Gain: 46.57
# Beam: 2, Iter: 18001, Reward pred: 1, Reward: -1, BF Gain pred: 163.35, BF Gain: 63.16
# Beam: 3, Iter: 18001, Reward pred: -1, Reward: -1, BF Gain pred: 79.85, BF Gain: 12.14
# Training for 500 iteration for each Beam (2000 iteration) uses 19.79288959503174 seconds.
# Beam: 0, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 156.05, BF Gain: 47.31
# Beam: 1, Iter: 18501, Reward pred: 1, Reward: -1, BF Gain pred: 115.70, BF Gain: 36.83
# Beam: 2, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 137.99, BF Gain: 36.85
# Beam: 3, Iter: 18501, Reward pred: 1, Reward: -1, BF Gain pred: 97.18, BF Gain: 21.92
# Training for 500 iteration for each Beam (2000 iteration) uses 19.112590312957764 seconds.
# Beam: 0, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 195.16, BF Gain: 99.94
# Beam: 1, Iter: 19001, Reward pred: 1, Reward: -1, BF Gain pred: 124.90, BF Gain: 25.31
# Beam: 2, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 155.21, BF Gain: 51.48
# Beam: 3, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 97.15, BF Gain: 44.50
# Training for 500 iteration for each Beam (2000 iteration) uses 19.800843954086304 seconds.
# Beam: 0, Iter: 19501, Reward pred: 1, Reward: -1, BF Gain pred: 174.33, BF Gain: 82.41
# Beam: 1, Iter: 19501, Reward pred: 1, Reward: -1, BF Gain pred: 117.30, BF Gain: 25.32
# Beam: 2, Iter: 19501, Reward pred: 1, Reward: -1, BF Gain pred: 138.31, BF Gain: 48.51
# Beam: 3, Iter: 19501, Reward pred: 1, Reward: -1, BF Gain pred: 91.55, BF Gain: 30.57
# Training for 500 iteration for each Beam (2000 iteration) uses 19.402791500091553 seconds.
# Beam: 0, Iter: 20001, Reward pred: 1, Reward: -1, BF Gain pred: 191.79, BF Gain: 38.23
# Beam: 1, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 112.77, BF Gain: 69.12
# Beam: 2, Iter: 20001, Reward pred: 1, Reward: -1, BF Gain pred: 171.66, BF Gain: 50.20
# Beam: 3, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 96.39, BF Gain: 28.26
# Training for 500 iteration for each Beam (2000 iteration) uses 19.58851647377014 seconds.
# Beam: 0, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 198.25, BF Gain: 78.02
# Beam: 1, Iter: 20501, Reward pred: 1, Reward: -1, BF Gain pred: 115.68, BF Gain: 19.54
# Beam: 2, Iter: 20501, Reward pred: 1, Reward: -1, BF Gain pred: 160.35, BF Gain: 79.10
# Beam: 3, Iter: 20501, Reward pred: 1, Reward: -1, BF Gain pred: 98.79, BF Gain: 39.51
# Training for 500 iteration for each Beam (2000 iteration) uses 19.634761333465576 seconds.
# Beam: 0, Iter: 21001, Reward pred: 1, Reward: -1, BF Gain pred: 161.86, BF Gain: 64.54
# Beam: 1, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 80.44, BF Gain: 41.99
# Beam: 2, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 138.64, BF Gain: 18.13
# Beam: 3, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 88.78, BF Gain: 31.97
# Training for 500 iteration for each Beam (2000 iteration) uses 19.576064586639404 seconds.
# Beam: 0, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 190.96, BF Gain: 115.53
# Beam: 1, Iter: 21501, Reward pred: 1, Reward: -1, BF Gain pred: 101.89, BF Gain: 28.73
# Beam: 2, Iter: 21501, Reward pred: 1, Reward: -1, BF Gain pred: 150.31, BF Gain: 40.21
# Beam: 3, Iter: 21501, Reward pred: 1, Reward: -1, BF Gain pred: 86.38, BF Gain: 36.72
# Training for 500 iteration for each Beam (2000 iteration) uses 19.653995990753174 seconds.
# Beam: 0, Iter: 22001, Reward pred: 1, Reward: -1, BF Gain pred: 182.57, BF Gain: 66.94
# Beam: 1, Iter: 22001, Reward pred: 1, Reward: -1, BF Gain pred: 113.22, BF Gain: 52.24
# Beam: 2, Iter: 22001, Reward pred: -1, Reward: -1, BF Gain pred: 115.92, BF Gain: 12.13
# Beam: 3, Iter: 22001, Reward pred: 1, Reward: -1, BF Gain pred: 100.34, BF Gain: 34.84
# Training for 500 iteration for each Beam (2000 iteration) uses 19.663100481033325 seconds.
# Beam: 0, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 179.59, BF Gain: 55.04
# Beam: 1, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 113.26, BF Gain: 44.08
# Beam: 2, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 159.09, BF Gain: 77.47
# Beam: 3, Iter: 22501, Reward pred: 1, Reward: -1, BF Gain pred: 99.40, BF Gain: 48.70
# Training for 500 iteration for each Beam (2000 iteration) uses 19.850266218185425 seconds.
# Beam: 0, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 152.24, BF Gain: 44.71
# Beam: 1, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 109.24, BF Gain: 19.61
# Beam: 2, Iter: 23001, Reward pred: 1, Reward: -1, BF Gain pred: 173.30, BF Gain: 41.30
# Beam: 3, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 84.10, BF Gain: 17.68
# Training for 500 iteration for each Beam (2000 iteration) uses 19.615605115890503 seconds.
# Beam: 0, Iter: 23501, Reward pred: 1, Reward: -1, BF Gain pred: 196.19, BF Gain: 71.27
# Beam: 1, Iter: 23501, Reward pred: 1, Reward: -1, BF Gain pred: 84.96, BF Gain: 4.28
# Beam: 2, Iter: 23501, Reward pred: 1, Reward: -1, BF Gain pred: 154.69, BF Gain: 54.59
# Beam: 3, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 78.19, BF Gain: 31.00
# Training for 500 iteration for each Beam (2000 iteration) uses 19.077252626419067 seconds.
# Beam: 0, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 165.96, BF Gain: 86.64
# Beam: 1, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 126.80, BF Gain: 43.07
# Beam: 2, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 129.07, BF Gain: 46.80
# Beam: 3, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 90.36, BF Gain: 37.19
# Training for 500 iteration for each Beam (2000 iteration) uses 19.217129707336426 seconds.
# Beam: 0, Iter: 24501, Reward pred: 1, Reward: -1, BF Gain pred: 191.15, BF Gain: 68.26
# Beam: 1, Iter: 24501, Reward pred: 1, Reward: -1, BF Gain pred: 131.33, BF Gain: 42.03
# Beam: 2, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 157.23, BF Gain: 88.04
# Beam: 3, Iter: 24501, Reward pred: 1, Reward: -1, BF Gain pred: 76.68, BF Gain: 38.48
# Training for 500 iteration for each Beam (2000 iteration) uses 19.622251510620117 seconds.
# Beam: 0, Iter: 25001, Reward pred: 1, Reward: -1, BF Gain pred: 159.96, BF Gain: 47.62
# Beam: 1, Iter: 25001, Reward pred: 1, Reward: -1, BF Gain pred: 129.86, BF Gain: 63.22
# Beam: 2, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 162.82, BF Gain: 73.42
# Beam: 3, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 85.79, BF Gain: 37.82
# Training for 500 iteration for each Beam (2000 iteration) uses 19.801026582717896 seconds.
# Beam: 0, Iter: 25501, Reward pred: 1, Reward: -1, BF Gain pred: 192.70, BF Gain: 119.48
# Beam: 1, Iter: 25501, Reward pred: 1, Reward: -1, BF Gain pred: 110.08, BF Gain: 39.39
# Beam: 2, Iter: 25501, Reward pred: 1, Reward: -1, BF Gain pred: 153.82, BF Gain: 25.90
# Beam: 3, Iter: 25501, Reward pred: 1, Reward: -1, BF Gain pred: 103.80, BF Gain: 34.18
# Training for 500 iteration for each Beam (2000 iteration) uses 19.72329878807068 seconds.
# Beam: 0, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 161.11, BF Gain: 76.81
# Beam: 1, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 111.29, BF Gain: 59.34
# Beam: 2, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 137.29, BF Gain: 33.22
# Beam: 3, Iter: 26001, Reward pred: 1, Reward: -1, BF Gain pred: 107.25, BF Gain: 44.26
# Training for 500 iteration for each Beam (2000 iteration) uses 20.06248378753662 seconds.
# Beam: 0, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 183.57, BF Gain: 62.33
# Beam: 1, Iter: 26501, Reward pred: 1, Reward: -1, BF Gain pred: 121.09, BF Gain: 25.13
# Beam: 2, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 159.21, BF Gain: 69.99
# Beam: 3, Iter: 26501, Reward pred: 1, Reward: -1, BF Gain pred: 93.37, BF Gain: 29.90
# Training for 500 iteration for each Beam (2000 iteration) uses 20.07570505142212 seconds.
# Beam: 0, Iter: 27001, Reward pred: 1, Reward: -1, BF Gain pred: 183.25, BF Gain: 46.44
# Beam: 1, Iter: 27001, Reward pred: 1, Reward: -1, BF Gain pred: 122.55, BF Gain: 35.36
# Beam: 2, Iter: 27001, Reward pred: 1, Reward: -1, BF Gain pred: 156.97, BF Gain: 46.30
# Beam: 3, Iter: 27001, Reward pred: -1, Reward: -1, BF Gain pred: 71.55, BF Gain: 25.74
# Training for 500 iteration for each Beam (2000 iteration) uses 19.647443771362305 seconds.
# Beam: 0, Iter: 27501, Reward pred: 1, Reward: -1, BF Gain pred: 159.31, BF Gain: 76.06
# Beam: 1, Iter: 27501, Reward pred: 1, Reward: -1, BF Gain pred: 133.34, BF Gain: 24.53
# Beam: 2, Iter: 27501, Reward pred: 1, Reward: -1, BF Gain pred: 155.19, BF Gain: 92.40
# Beam: 3, Iter: 27501, Reward pred: 1, Reward: -1, BF Gain pred: 76.91, BF Gain: 17.21
# Training for 500 iteration for each Beam (2000 iteration) uses 19.626444578170776 seconds.
# Beam: 0, Iter: 28001, Reward pred: 1, Reward: -1, BF Gain pred: 190.01, BF Gain: 78.92
# Beam: 1, Iter: 28001, Reward pred: 1, Reward: -1, BF Gain pred: 125.14, BF Gain: 53.60
# Beam: 2, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 130.18, BF Gain: 36.53
# Beam: 3, Iter: 28001, Reward pred: 1, Reward: -1, BF Gain pred: 101.25, BF Gain: 52.46
# Training for 500 iteration for each Beam (2000 iteration) uses 19.100005626678467 seconds.
# Beam: 0, Iter: 28501, Reward pred: 1, Reward: -1, BF Gain pred: 193.30, BF Gain: 66.12
# Beam: 1, Iter: 28501, Reward pred: 1, Reward: -1, BF Gain pred: 115.88, BF Gain: 44.40
# Beam: 2, Iter: 28501, Reward pred: 1, Reward: -1, BF Gain pred: 172.77, BF Gain: 90.41
# Beam: 3, Iter: 28501, Reward pred: 1, Reward: -1, BF Gain pred: 89.13, BF Gain: 25.47
# Training for 500 iteration for each Beam (2000 iteration) uses 19.690288066864014 seconds.
# Beam: 0, Iter: 29001, Reward pred: 1, Reward: -1, BF Gain pred: 203.25, BF Gain: 91.61
# Beam: 1, Iter: 29001, Reward pred: 1, Reward: -1, BF Gain pred: 110.05, BF Gain: 28.45
# Beam: 2, Iter: 29001, Reward pred: 1, Reward: -1, BF Gain pred: 169.75, BF Gain: 74.77
# Beam: 3, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 96.27, BF Gain: 31.61
# Training for 500 iteration for each Beam (2000 iteration) uses 19.470292568206787 seconds.
# Beam: 0, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 179.44, BF Gain: 80.57
# Beam: 1, Iter: 29501, Reward pred: 1, Reward: -1, BF Gain pred: 125.60, BF Gain: 52.14
# Beam: 2, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 140.85, BF Gain: 43.64
# Beam: 3, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 91.12, BF Gain: 18.49
# Training for 500 iteration for each Beam (2000 iteration) uses 20.40854287147522 seconds.
# Beam: 0, Iter: 30001, Reward pred: 1, Reward: -1, BF Gain pred: 201.44, BF Gain: 50.61
# Beam: 1, Iter: 30001, Reward pred: 1, Reward: -1, BF Gain pred: 113.04, BF Gain: 44.23
# Beam: 2, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 143.25, BF Gain: 32.55
# Beam: 3, Iter: 30001, Reward pred: 1, Reward: -1, BF Gain pred: 94.26, BF Gain: 31.30
# Training for 500 iteration for each Beam (2000 iteration) uses 19.71066975593567 seconds.
# Beam: 0, Iter: 30501, Reward pred: 1, Reward: -1, BF Gain pred: 210.39, BF Gain: 81.64
# Beam: 1, Iter: 30501, Reward pred: 1, Reward: -1, BF Gain pred: 115.60, BF Gain: 39.07
# Beam: 2, Iter: 30501, Reward pred: 1, Reward: -1, BF Gain pred: 172.69, BF Gain: 45.95
# Beam: 3, Iter: 30501, Reward pred: 1, Reward: -1, BF Gain pred: 95.39, BF Gain: 24.27
# Training for 500 iteration for each Beam (2000 iteration) uses 19.645490407943726 seconds.
# Beam: 0, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 188.14, BF Gain: 66.93
# Beam: 1, Iter: 31001, Reward pred: 1, Reward: -1, BF Gain pred: 123.04, BF Gain: 31.00
# Beam: 2, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 165.57, BF Gain: 83.88
# Beam: 3, Iter: 31001, Reward pred: 1, Reward: -1, BF Gain pred: 100.84, BF Gain: 32.60
# Training for 500 iteration for each Beam (2000 iteration) uses 19.496182918548584 seconds.
# Beam: 0, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 192.36, BF Gain: 42.34
# Beam: 1, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 119.97, BF Gain: 51.12
# Beam: 2, Iter: 31501, Reward pred: 1, Reward: -1, BF Gain pred: 173.27, BF Gain: 85.53
# Beam: 3, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 96.44, BF Gain: 43.28
# Training for 500 iteration for each Beam (2000 iteration) uses 19.32313871383667 seconds.
# Beam: 0, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 148.45, BF Gain: 85.32
# Beam: 1, Iter: 32001, Reward pred: 1, Reward: -1, BF Gain pred: 133.41, BF Gain: 57.85
# Beam: 2, Iter: 32001, Reward pred: 1, Reward: -1, BF Gain pred: 164.07, BF Gain: 55.75
# Beam: 3, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 101.07, BF Gain: 56.43
# Training for 500 iteration for each Beam (2000 iteration) uses 19.246503829956055 seconds.
# Beam: 0, Iter: 32501, Reward pred: -1, Reward: -1, BF Gain pred: 203.05, BF Gain: 70.98
# Beam: 1, Iter: 32501, Reward pred: -1, Reward: -1, BF Gain pred: 116.27, BF Gain: 30.24
# Beam: 2, Iter: 32501, Reward pred: 1, Reward: -1, BF Gain pred: 168.49, BF Gain: 52.22
# Beam: 3, Iter: 32501, Reward pred: 1, Reward: -1, BF Gain pred: 102.72, BF Gain: 44.65
# Training for 500 iteration for each Beam (2000 iteration) uses 19.263835668563843 seconds.
# Beam: 0, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 190.83, BF Gain: 94.36
# Beam: 1, Iter: 33001, Reward pred: 1, Reward: -1, BF Gain pred: 117.58, BF Gain: 29.19
# Beam: 2, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 163.44, BF Gain: 80.98
# Beam: 3, Iter: 33001, Reward pred: 1, Reward: -1, BF Gain pred: 79.42, BF Gain: 49.34
# Training for 500 iteration for each Beam (2000 iteration) uses 19.041670083999634 seconds.
# Beam: 0, Iter: 33501, Reward pred: 1, Reward: -1, BF Gain pred: 203.45, BF Gain: 66.94
# Beam: 1, Iter: 33501, Reward pred: 1, Reward: -1, BF Gain pred: 127.01, BF Gain: 47.22
# Beam: 2, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 131.88, BF Gain: 46.69
# Beam: 3, Iter: 33501, Reward pred: 1, Reward: -1, BF Gain pred: 101.83, BF Gain: 38.48
# Training for 500 iteration for each Beam (2000 iteration) uses 19.549248933792114 seconds.
# Beam: 0, Iter: 34001, Reward pred: 1, Reward: -1, BF Gain pred: 205.45, BF Gain: 79.16
# Beam: 1, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 125.85, BF Gain: 60.23
# Beam: 2, Iter: 34001, Reward pred: 1, Reward: -1, BF Gain pred: 168.75, BF Gain: 53.05
# Beam: 3, Iter: 34001, Reward pred: 1, Reward: -1, BF Gain pred: 98.65, BF Gain: 52.24
# Training for 500 iteration for each Beam (2000 iteration) uses 19.73187828063965 seconds.
# Beam: 0, Iter: 34501, Reward pred: 1, Reward: -1, BF Gain pred: 211.73, BF Gain: 98.07
# Beam: 1, Iter: 34501, Reward pred: 1, Reward: -1, BF Gain pred: 139.33, BF Gain: 69.18
# Beam: 2, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 160.16, BF Gain: 89.56
# Beam: 3, Iter: 34501, Reward pred: 1, Reward: -1, BF Gain pred: 105.97, BF Gain: 31.82
# Training for 500 iteration for each Beam (2000 iteration) uses 19.823415517807007 seconds.
# Beam: 0, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 174.19, BF Gain: 94.39
# Beam: 1, Iter: 35001, Reward pred: 1, Reward: -1, BF Gain pred: 104.07, BF Gain: 48.23
# Beam: 2, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 123.69, BF Gain: 49.22
# Beam: 3, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 100.05, BF Gain: 51.72
# Training for 500 iteration for each Beam (2000 iteration) uses 19.711524486541748 seconds.
# Beam: 0, Iter: 35501, Reward pred: 1, Reward: -1, BF Gain pred: 217.41, BF Gain: 68.45
# Beam: 1, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 117.15, BF Gain: 37.08
# Beam: 2, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 173.17, BF Gain: 80.99
# Beam: 3, Iter: 35501, Reward pred: 1, Reward: -1, BF Gain pred: 93.93, BF Gain: 35.90
# Training for 500 iteration for each Beam (2000 iteration) uses 19.711405515670776 seconds.
# Beam: 0, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 191.20, BF Gain: 112.53
# Beam: 1, Iter: 36001, Reward pred: 1, Reward: -1, BF Gain pred: 127.15, BF Gain: 74.41
# Beam: 2, Iter: 36001, Reward pred: 1, Reward: -1, BF Gain pred: 157.59, BF Gain: 41.85
# Beam: 3, Iter: 36001, Reward pred: 1, Reward: -1, BF Gain pred: 101.22, BF Gain: 37.48
# Training for 500 iteration for each Beam (2000 iteration) uses 19.739271640777588 seconds.
# Beam: 0, Iter: 36501, Reward pred: 1, Reward: -1, BF Gain pred: 193.52, BF Gain: 102.07
# Beam: 1, Iter: 36501, Reward pred: -1, Reward: -1, BF Gain pred: 120.39, BF Gain: 82.03
# Beam: 2, Iter: 36501, Reward pred: 1, Reward: -1, BF Gain pred: 175.62, BF Gain: 75.58
# Beam: 3, Iter: 36501, Reward pred: 1, Reward: -1, BF Gain pred: 104.90, BF Gain: 42.25
# Training for 500 iteration for each Beam (2000 iteration) uses 19.315748691558838 seconds.
# Beam: 0, Iter: 37001, Reward pred: -1, Reward: -1, BF Gain pred: 197.19, BF Gain: 90.91
# Beam: 1, Iter: 37001, Reward pred: 1, Reward: -1, BF Gain pred: 109.52, BF Gain: 42.09
# Beam: 2, Iter: 37001, Reward pred: 1, Reward: -1, BF Gain pred: 175.97, BF Gain: 45.55
# Beam: 3, Iter: 37001, Reward pred: -1, Reward: -1, BF Gain pred: 98.26, BF Gain: 46.22
# Training for 500 iteration for each Beam (2000 iteration) uses 19.074886322021484 seconds.
# Beam: 0, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 199.27, BF Gain: 74.10
# Beam: 1, Iter: 37501, Reward pred: 1, Reward: -1, BF Gain pred: 124.23, BF Gain: 44.78
# Beam: 2, Iter: 37501, Reward pred: 1, Reward: -1, BF Gain pred: 164.54, BF Gain: 63.57
# Beam: 3, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 101.16, BF Gain: 41.68
# Training for 500 iteration for each Beam (2000 iteration) uses 19.278685092926025 seconds.
# Beam: 0, Iter: 38001, Reward pred: 1, Reward: -1, BF Gain pred: 193.45, BF Gain: 115.46
# Beam: 1, Iter: 38001, Reward pred: 1, Reward: -1, BF Gain pred: 131.18, BF Gain: 58.14
# Beam: 2, Iter: 38001, Reward pred: 1, Reward: -1, BF Gain pred: 177.89, BF Gain: 83.37
# Beam: 3, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 73.63, BF Gain: 35.62
# Training for 500 iteration for each Beam (2000 iteration) uses 19.2970929145813 seconds.
# Beam: 0, Iter: 38501, Reward pred: 1, Reward: -1, BF Gain pred: 203.10, BF Gain: 125.40
# Beam: 1, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 119.37, BF Gain: 59.99
# Beam: 2, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 173.91, BF Gain: 96.71
# Beam: 3, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 101.38, BF Gain: 39.28
# Training for 500 iteration for each Beam (2000 iteration) uses 19.485010385513306 seconds.
# Beam: 0, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 206.09, BF Gain: 83.85
# Beam: 1, Iter: 39001, Reward pred: 1, Reward: -1, BF Gain pred: 128.69, BF Gain: 51.95
# Beam: 2, Iter: 39001, Reward pred: 1, Reward: -1, BF Gain pred: 180.74, BF Gain: 73.51
# Beam: 3, Iter: 39001, Reward pred: 1, Reward: -1, BF Gain pred: 94.12, BF Gain: 48.63
# Training for 500 iteration for each Beam (2000 iteration) uses 19.52909278869629 seconds.
# Beam: 0, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 176.83, BF Gain: 52.08
# Beam: 1, Iter: 39501, Reward pred: 1, Reward: -1, BF Gain pred: 119.84, BF Gain: 51.73
# Beam: 2, Iter: 39501, Reward pred: 1, Reward: -1, BF Gain pred: 182.54, BF Gain: 100.82
# Beam: 3, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 104.76, BF Gain: 57.10
# Training for 500 iteration for each Beam (2000 iteration) uses 19.593366861343384 seconds.
# Beam: 0, Iter: 40001, Reward pred: 1, Reward: -1, BF Gain pred: 196.69, BF Gain: 64.05
# Beam: 1, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 127.79, BF Gain: 70.49
# Beam: 2, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 177.15, BF Gain: 121.36
# Beam: 3, Iter: 40001, Reward pred: 1, Reward: -1, BF Gain pred: 100.81, BF Gain: 52.82
# Training for 500 iteration for each Beam (2000 iteration) uses 19.44944167137146 seconds.

# %%
import numpy as np
import scipy.io as scio

num_ant = 32
num_beam = 4
results = np.empty((num_beam, 2*num_ant))

path = './beams/'

for beam_id in range(num_beam):
    fname = 'beams_' + str(beam_id) + '_max.txt'
    with open(path + fname, 'r') as f:
        lines = f.readlines()
        last_line = lines[-1]
        results[beam_id, :] = np.fromstring(last_line.replace("\n", ""), sep=',').reshape(1, -1)

results = (1 / np.sqrt(num_ant)) * (results[:, ::2] + 1j * results[:, 1::2])

scio.savemat('beam_codebook.mat', {'beams': results})

# %%
np.concatenate(env_list[0].gain_record[1:]).flatten()
# Out:
# array([  0.26296154,   3.2169893 ,   5.8693147 ,   7.5164967 ,
#         10.507307  ,  25.558544  ,  26.124346  ,  38.738995  ,
#         40.99513   ,  43.359684  ,  44.625156  ,  47.51557   ,
#         54.51732   ,  56.320328  ,  61.108276  ,  67.52156   ,
#         73.4858    ,  83.96617   ,  94.781624  , 101.29149   ,
#        102.71874   , 122.880394  , 135.61642   , 139.71388   ,
#        144.554     , 150.95699   , 159.92236   , 162.57986   ,
#        172.83183   , 176.51715   , 176.95767   , 183.86588   ,
#        186.73668   , 195.50522   , 197.19229   , 198.94994   ,
#        202.75494   , 206.07744   , 206.35939   , 207.29887   ,
#        208.354     , 222.17683   , 222.64108   , 223.62915   ,
#        223.87695   , 225.63446   , 227.9424    , 235.08037   ,
#        237.59814   , 237.787     ], dtype=float32)

# %%
from matplotlib import pyplot as plt
plt.title(f'Best beamforming gain')
plt.xlabel('Beam_framing_gain')   
for beam_id in range(options['num_NNs']):
    gain_record=np.concatenate(env_list[beam_id].gain_record[1:]).flatten()
    plt.plot(gain_record, label=f'Beam_{beam_id}')
    plt.plot([])
plt.plot([231.17094]*50,linestyle='dashed',color='black')
plt.legend(loc="upper left")  
plt.show()
