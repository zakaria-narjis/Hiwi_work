# %%
# !git clone https://github.com/YuZhang-GitHub/Codebook_Learning_RL.git
# Out:
# fatal: destination path 'Codebook_Learning_RL' already exists and is not an empty directory.

# %%
# !pip install pfrl
# Out:
# Requirement already satisfied: pfrl in /opt/conda/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: torch>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from pfrl) (2.0.0)
# Requirement already satisfied: gym>=0.9.7 in /opt/conda/lib/python3.10/site-packages (from pfrl) (0.26.2)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/lib/python3.10/site-packages (from pfrl) (1.23.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from pfrl) (9.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from pfrl) (3.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from gym>=0.9.7->pfrl) (0.0.8)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.3.0->pfrl) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.3.0->pfrl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.3.0->pfrl) (1.3.0)

# %%
# from Codebook_Learning_RL import DDPG_classes

# %%
import os
os.chdir('/kaggle/working/Codebook_Learning_RL')
print(os.getcwd())
# Out:
# /kaggle/working/Codebook_Learning_RL

# %%
import pfrl
import os
import time
import torch
import numpy as np
import copy
import pickle
from torch import nn
from torch import distributions
from scipy.optimize import linear_sum_assignment
from DataPrep import dataPrep
from env_ddpg import envCB
from clustering import KMeans_only
from function_lib import bf_gain_cal, corr_mining
from DDPG_classes import OUNoise
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
options = {
        'gpu_idx': 0,
        'num_ant': 32,
        'num_bits': 4,
        'num_NNs': 4,  # codebook size
        'ch_sample_ratio': 0.5,
        'num_loop': 400,  # outer loop
        'target_update': 3,
        'path': './grid1101-1400.mat',
        'clustering_mode': 'random',
    }

train_opt = {
        'state': 0,
        'best_state': 0,
        'num_iter': 100,  # inner loop
        'tau': 1e-2,
        'overall_iter': 1,
        'replay_memory': [],
        'replay_memory_size': 8192,
        'minibatch_size': 1024,
        'gamma': 0,
        'gpu':0
    }
if not os.path.exists('beams/'):
    os.mkdir('beams/')

ch = dataPrep(options['path'])
ch = np.concatenate((ch[:, :options['num_ant']],
                     ch[:, int(ch.shape[1] / 2):int(ch.shape[1] / 2) + options['num_ant']]), axis=1)
with torch.cuda.device(options['gpu']):
    u_classifier, sensing_beam = KMeans_only(ch, options['num_NNs'], n_bit=options['num_bits'], n_rand_beam=30)
    np.save('sensing_beam.npy', sensing_beam)
    sensing_beam = torch.from_numpy(sensing_beam).float().cuda()

    filename = 'kmeans_model.sav'
    pickle.dump(u_classifier, open(filename, 'wb'))

    # Quantization settings
    options['num_ph'] = 2 ** options['num_bits']
    options['multi_step'] = torch.from_numpy(
        np.linspace(int(-(options['num_ph'] - 2) / 2),
                    int(options['num_ph'] / 2),
                    num=options['num_ph'],
                    endpoint=True)).type(dtype=torch.float32).reshape(1, -1).cuda()
    options['pi'] = torch.tensor(np.pi).cuda()
    options['ph_table'] = (2 * options['pi']) / options['num_ph'] * options['multi_step']
    options['ph_table'].cuda()
    options['ph_table_rep'] = options['ph_table'].repeat(options['num_ant'], 1)
    actor_net_list = []
    critic_net_list = []
    actor_net_t_list = []
    critic_net_t_list = []
    ounoise_list = []
    env_list = []
    train_opt_list = []
    agent_list=[]
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from pfrl.utils.batch_states import batch_states
def batch_experiences_(experiences, device, phi, gamma, batch_states=batch_states):
    """Takes a batch of k experiences each of which contains j

    consecutive transitions and vectorizes them, where j is between 1 and n.

    Args:
        experiences: list of experiences. Each experience is a list
            containing between 1 and n dicts containing
              - state (object): State
              - action (object): Action
              - reward (float): Reward
              - is_state_terminal (bool): True iff next state is terminal
              - next_state (object): Next state
        device : GPU or CPU the tensor should be placed on
        phi : Preprocessing function
        gamma: discount factor
        batch_states: function that converts a list to a batch
    Returns:
        dict of batched transitions
    """

    batch_exp = {
        "state": batch_states([elem[0]["state"] for elem in experiences], device, phi),
        "action": torch.as_tensor(
            np.array([elem[0]["action"] for elem in experiences]), device=device
        ),
        "reward": torch.as_tensor(
            [
                sum((gamma**i) * exp[i]["reward"] for i in range(len(exp)))
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "next_state": batch_states(
            [elem[-1]["next_state"] for elem in experiences], device, phi
        ),
        "is_state_terminal": torch.as_tensor(
            [
                any(transition["is_state_terminal"] for transition in exp)
                for exp in experiences
            ],
            dtype=torch.float32,
            device=device,
        ),
        "discount": torch.as_tensor(
            [(gamma ** len(elem)) for elem in experiences],
            dtype=torch.float32,
            device=device,
        ),
    }
    if all(elem[-1]["next_action"] is not None for elem in experiences):
        batch_exp["next_action"] = torch.as_tensor(
            [elem[-1]["next_action"] for elem in experiences], device=device
        )
    return batch_exp

from pfrl.agents.ddpg import DDPG
class DDPG_(DDPG):
    def update(self, experiences, errors_out=None):
        """Update the model from experiences"""

        batch = batch_experiences_(experiences, self.device, self.phi, self.gamma)

        self.critic_optimizer.zero_grad()
        self.compute_critic_loss(batch).backward()
        self.critic_optimizer.step()

        self.actor_optimizer.zero_grad()
        self.compute_actor_loss(batch).backward()
        self.actor_optimizer.step()

        self.n_updates += 1

# %%
import pfrl
from pfrl import experiments, explorers, replay_buffers, utils
from pfrl.agents.ddpg import DDPG
from pfrl.nn import BoundByTanh, ConcatObsAndAction
from pfrl.policies import DeterministicHead
from pfrl.explorers import Greedy

def create_agent(state_size,action_size,train_options,gpu=0):
    
    #critic_network
    q_func = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    #actor_network
    policy = nn.Sequential(
        nn.Linear(state_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, action_size),
        BoundByTanh(low= -torch.tensor(np.pi).float(), high= torch.tensor(np.pi).float()),
        DeterministicHead(),
    )
    
    opt_a = torch.optim.Adam(policy.parameters(), lr=1e-3, weight_decay=1e-3)
    opt_c = torch.optim.Adam(q_func.parameters(), lr=1e-3, weight_decay=1e-2)
    rbuf = replay_buffers.ReplayBuffer(train_options['replay_memory_size'])
    
    explorer =  Greedy()
    
    agent = DDPG_(
        policy,
        q_func,
        opt_a,
        opt_c,
        rbuf,
        gamma=train_options['gamma'],
        explorer = explorer,
        replay_start_size=train_options['minibatch_size'],
        target_update_method="soft",
        target_update_interval=options['target_update'],
        update_interval=1,
        soft_update_tau= train_opt['tau'],
        n_times_update=1,
        gpu=gpu,
        minibatch_size=train_options['minibatch_size'],
    )
    
    return agent

# %%
def create_agent_sac(state_size,action_size,train_options,gpu=0):
    def squashed_diagonal_gaussian_head(x):
        assert x.shape[-1] == action_size * 2
        mean, log_scale = torch.chunk(x, 2, dim=2)
        log_scale = torch.clamp(log_scale, -20.0, 2.0)
        var = torch.exp(log_scale * 2)
        base_distribution = distributions.Independent(
            distributions.Normal(loc=mean, scale=torch.sqrt(var)), 1
        )
        # cache_size=1 is required for numerical stability
        return distributions.transformed_distribution.TransformedDistribution(
            base_distribution, [distributions.transforms.TanhTransform(cache_size=1),
                                distributions.transforms.AffineTransform(0, torch.pi, event_dim=0, cache_size=1)]
        )

    #critic_networks
    q_func_1 = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    q_func_2 = nn.Sequential(
        ConcatObsAndAction(),
        nn.Linear(state_size + action_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, 1),
    )
    
    #actor_network
    policy = nn.Sequential(
        nn.Linear(state_size, 16*state_size),
        nn.ReLU(),
        nn.Linear(16*state_size, 16*action_size),
        nn.ReLU(),
        nn.Linear(16*action_size, action_size* 2),
        pfrl.nn.lmbda.Lambda(squashed_diagonal_gaussian_head),
    )


    opt_a = torch.optim.Adam(policy.parameters(), lr=1e-3, weight_decay=1e-3)
    opt_c_1 = torch.optim.Adam(q_func_1.parameters(), lr=1e-3, weight_decay=1e-2)
    opt_c_2 = torch.optim.Adam(q_func_2.parameters(), lr=1e-3, weight_decay=1e-2)
    
    rbuf = replay_buffers.ReplayBuffer(train_options['replay_memory_size'])
    
    agent = pfrl.agents.SoftActorCritic(
        policy,
        q_func_1,
        q_func_2,
        opt_a,
        opt_c_1,
        opt_c_2,
        rbuf,
        gamma=train_options['gamma'],
        update_interval=1,
        replay_start_size=train_options['minibatch_size'],
        gpu=gpu,
        soft_update_tau= train_opt['tau'],
        minibatch_size = train_options['minibatch_size'],
        entropy_target=-action_size,
        temperature_optimizer_lr=1e-3,
    )
    return agent

# %%
def train(
          env,
          options,
          train_options,
          agent,
          ounoise,
          beam_id):
    
#     action_pred_noisy = ounoise.get_action(action_pred,
#                                                t=train_options['overall_iter'])
    CB_Env = env   
    if train_options['overall_iter'] == 1:
        state = torch.zeros((1, options['num_ant'])).float().cuda()
        print('Initial State Activated.')
    else:
        state = train_options['state']
    
    
    #training_loop
    iteration = 0
    num_of_iter = train_options['num_iter']  
    while iteration < num_of_iter:

        
        action = agent.act(state)
#         print(type(agent.batch_last_action),agent.batch_last_action)
        reward_pred, bf_gain_pred, action_quant_pred, state_1_pred = CB_Env.get_reward(torch.Tensor(action).to('cuda'))
        reward_pred = torch.from_numpy(reward_pred).float().cuda()
        
        action_pred_noisy = torch.Tensor(action).to('cuda')
        mat_dist = torch.abs(action_pred_noisy.reshape(options['num_ant'], 1) - options['ph_table_rep'])
        action_quant = options['ph_table_rep'][range(options['num_ant']), torch.argmin(mat_dist, dim=1)].reshape(1, -1)
   
        state_1, reward, bf_gain, terminal = CB_Env.step(action_quant)
        reward = torch.from_numpy(reward).float().cuda()
        action = action_quant.reshape((1, -1)).float().cuda()
        
        
#         print(type(action_quant_pred.cpu().numpy()),action_quant_pred.cpu().numpy().shape)
#         print(type(action.cpu().numpy()),action.cpu().numpy().shape)
        agent.replay_buffer.append(
                    state=state,
                    action=action_quant_pred.cpu().numpy(),
                    reward=reward_pred,
                    next_state=state_1_pred,
                    next_action=None,
                    is_state_terminal=terminal,
                    env_id=0,
                )
#         print(agent.batch_last_action,agent.batch_last_action[0].shape)
        agent.batch_last_action = [action.cpu().numpy()] #because the critic is expecting quantizazed actions
        agent.observe(state_1, reward, terminal, False)

        
        iteration += 1
        train_options['overall_iter'] += 1
        state = state_1

    train_options['state'] = state  # used for the next loop
    train_options['best_state'] = CB_Env.best_bf_vec  # used for clustering and assignment
    if (train_options['overall_iter']-1)%500==0:
#         print(
#             "Beam: %d, Iter: %d, Reward: %d, BF Gain: %.2f" % \
#             (beam_id, 
#              train_options['overall_iter'],
#              int(torch.Tensor.cpu(reward).numpy().squeeze()),
#              torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))
        print(
            "Beam: %d, Iter: %d, Reward pred: %d, Reward: %d, BF Gain pred: %.2f, BF Gain: %.2f" % \
            (beam_id, train_options['overall_iter'],
             int(torch.Tensor.cpu(reward_pred).numpy().squeeze()),
             int(torch.Tensor.cpu(reward).numpy().squeeze()),
             torch.Tensor.cpu(bf_gain_pred.detach()).numpy().squeeze(),
             torch.Tensor.cpu(bf_gain.detach()).numpy().squeeze(),))      
    
    return train_options

# %%
for beam_id in range(options['num_NNs']):
    ounoise_list.append(OUNoise((1, options['num_ant'])))
    env_list.append(envCB(ch, options['num_ant'], options['num_bits'], beam_id, options))
    train_opt_list.append(copy.deepcopy(train_opt))
    agent = create_agent_sac(options['num_ant'],options['num_ant'],train_opt_list[beam_id],gpu=train_opt['gpu'])
    agent_list.append(agent)
    ounoise_list.append(OUNoise((1, options['num_ant'])))
# Out:
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094
# EGC bf gain:  231.17094

# %%
with torch.cuda.device(options['gpu']):
    for sample_id in range(options['num_loop']):

        # ---------- Sampling ---------- #
        n_sample = int(ch.shape[0] * options['ch_sample_ratio'])
        ch_sample_id = np.random.permutation(ch.shape[0])[0:n_sample]
        ch_sample = torch.from_numpy(ch[ch_sample_id, :]).float().cuda()

        # ---------- Clustering ---------- #
    #     start_time = time.time()

        bf_mat_sample = bf_gain_cal(sensing_beam, ch_sample)
        # print("Clustering -1 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()
        f_matrix = corr_mining(bf_mat_sample)
        f_matrix_np = torch.Tensor.cpu(f_matrix).numpy()
        # print("Clustering 0 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()
        labels = u_classifier.predict(np.transpose(f_matrix_np).astype(float))

        # print("Clustering 1 uses %s seconds." % (time.time() - start_time))
        # start_time = time.time()

        user_group = []  # order: clusters
        ch_group = []  # order: clusters
        for ii in range(options['num_NNs']):
            user_group.append(np.where(labels == ii)[0].tolist())
            ch_group.append(ch_sample[user_group[ii], :])

    #     print("Clustering 2 uses %s seconds." % (time.time() - start_time))

        # ---------- Assignment ---------- #
    #     start_time = time.time()

        # best_state matrix
        best_beam_mtx = torch.zeros((options['num_NNs'], 2 * options['num_ant'])).float().cuda()
        for pp in range(options['num_NNs']):
            best_beam_mtx[pp, :] = env_list[pp].best_bf_vec
        gain_mtx = bf_gain_cal(best_beam_mtx, ch_sample)  # (n_beam, n_user)
        for ii in range(options['num_NNs']):
            if ii == 0:
                cost_mtx = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
            else:
                sub = torch.mean(gain_mtx[:, user_group[ii]], dim=1).reshape(options['num_NNs'], -1)
                cost_mtx = torch.cat((cost_mtx, sub), dim=1)
        cost_mtx = -torch.Tensor.cpu(cost_mtx).numpy()
        row_ind, col_ind = linear_sum_assignment(cost_mtx)
        assignment_record = dict(zip(row_ind.tolist(), col_ind.tolist()))  # key: network, value: cluster
        for ii in range(options['num_NNs']):
            env_list[ii].ch = ch_group[assignment_record[ii]]

    #     print("Assignment uses %s seconds." % (time.time() - start_time))
        if (train_opt_list[beam_id]['overall_iter']-1)%500==0 or train_opt_list[beam_id]['overall_iter']==1:
            start_time = time.time()
        for beam_id in range(options['num_NNs']):
            train_opt_list[beam_id] = train(env_list[beam_id],options, train_opt_list[beam_id],agent_list[beam_id],ounoise_list[beam_id], beam_id)
        if (train_opt_list[beam_id]['overall_iter']-1)%500==0: 
            print("Training for 500 iteration for each Beam uses %s seconds." % (time.time() - start_time))
# Out:
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Initial State Activated.
# Beam: 0, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 5.99, BF Gain: 5.99
# Beam: 1, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 22.69, BF Gain: 22.69
# Beam: 2, Iter: 501, Reward pred: -1, Reward: -1, BF Gain pred: 4.61, BF Gain: 4.61
# Beam: 3, Iter: 501, Reward pred: 1, Reward: 1, BF Gain pred: 29.52, BF Gain: 29.52
# Training for 500 iteration for each Beam uses 11.635377168655396 seconds.
# /opt/conda/lib/python3.10/site-packages/pfrl/replay_buffer.py:180: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /usr/local/src/pytorch/torch/csrc/utils/tensor_new.cpp:245.)
#   "action": torch.as_tensor(
# Beam: 0, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 0.80, BF Gain: 0.80
# Beam: 1, Iter: 1001, Reward pred: 1, Reward: 1, BF Gain pred: 29.81, BF Gain: 29.81
# Beam: 2, Iter: 1001, Reward pred: 1, Reward: 1, BF Gain pred: 18.45, BF Gain: 18.45
# Beam: 3, Iter: 1001, Reward pred: -1, Reward: -1, BF Gain pred: 2.67, BF Gain: 2.67
# Training for 500 iteration for each Beam uses 140.24622321128845 seconds.
# Beam: 0, Iter: 1501, Reward pred: 1, Reward: 1, BF Gain pred: 4.04, BF Gain: 4.04
# Beam: 1, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 3.43, BF Gain: 3.43
# Beam: 2, Iter: 1501, Reward pred: -1, Reward: -1, BF Gain pred: 15.44, BF Gain: 15.44
# Beam: 3, Iter: 1501, Reward pred: 1, Reward: 1, BF Gain pred: 4.61, BF Gain: 4.61
# Training for 500 iteration for each Beam uses 142.92764616012573 seconds.
# Beam: 0, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 9.98, BF Gain: 9.98
# Beam: 1, Iter: 2001, Reward pred: 1, Reward: 1, BF Gain pred: 5.24, BF Gain: 5.24
# Beam: 2, Iter: 2001, Reward pred: -1, Reward: -1, BF Gain pred: 8.63, BF Gain: 8.63
# Beam: 3, Iter: 2001, Reward pred: -1, Reward: -1, BF Gain pred: 3.37, BF Gain: 3.37
# Training for 500 iteration for each Beam uses 143.45184779167175 seconds.
# Beam: 0, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 0.40, BF Gain: 0.40
# Beam: 1, Iter: 2501, Reward pred: 1, Reward: 1, BF Gain pred: 16.56, BF Gain: 16.56
# Beam: 2, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 11.48, BF Gain: 11.48
# Beam: 3, Iter: 2501, Reward pred: -1, Reward: -1, BF Gain pred: 3.10, BF Gain: 3.10
# Training for 500 iteration for each Beam uses 142.98720979690552 seconds.
# Beam: 0, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 11.93, BF Gain: 11.93
# Beam: 1, Iter: 3001, Reward pred: -1, Reward: -1, BF Gain pred: 5.08, BF Gain: 5.08
# Beam: 2, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 28.05, BF Gain: 28.05
# Beam: 3, Iter: 3001, Reward pred: 1, Reward: 1, BF Gain pred: 17.12, BF Gain: 17.12
# Training for 500 iteration for each Beam uses 144.47323036193848 seconds.
# Beam: 0, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 5.65, BF Gain: 5.65
# Beam: 1, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 4.46, BF Gain: 4.46
# Beam: 2, Iter: 3501, Reward pred: -1, Reward: -1, BF Gain pred: 2.30, BF Gain: 2.30
# Beam: 3, Iter: 3501, Reward pred: 1, Reward: 1, BF Gain pred: 7.17, BF Gain: 7.17
# Training for 500 iteration for each Beam uses 145.19047927856445 seconds.
# Beam: 0, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 6.52, BF Gain: 6.52
# Beam: 1, Iter: 4001, Reward pred: 1, Reward: 1, BF Gain pred: 21.64, BF Gain: 21.64
# Beam: 2, Iter: 4001, Reward pred: -1, Reward: -1, BF Gain pred: 10.61, BF Gain: 10.61
# Beam: 3, Iter: 4001, Reward pred: -1, Reward: -1, BF Gain pred: 1.75, BF Gain: 1.75
# Training for 500 iteration for each Beam uses 143.7403175830841 seconds.
# Beam: 0, Iter: 4501, Reward pred: 1, Reward: 1, BF Gain pred: 4.94, BF Gain: 4.94
# Beam: 1, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 2.06, BF Gain: 2.06
# Beam: 2, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 14.46, BF Gain: 14.46
# Beam: 3, Iter: 4501, Reward pred: -1, Reward: -1, BF Gain pred: 5.13, BF Gain: 5.13
# Training for 500 iteration for each Beam uses 146.62878394126892 seconds.
# Beam: 0, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 1.76, BF Gain: 1.76
# Beam: 1, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 2.65, BF Gain: 2.65
# Beam: 2, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 12.07, BF Gain: 12.07
# Beam: 3, Iter: 5001, Reward pred: -1, Reward: -1, BF Gain pred: 4.75, BF Gain: 4.75
# Training for 500 iteration for each Beam uses 148.009601354599 seconds.
# Beam: 0, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 20.46, BF Gain: 20.46
# Beam: 1, Iter: 5501, Reward pred: 1, Reward: 1, BF Gain pred: 27.58, BF Gain: 27.58
# Beam: 2, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 5.27, BF Gain: 5.27
# Beam: 3, Iter: 5501, Reward pred: -1, Reward: -1, BF Gain pred: 8.10, BF Gain: 8.10
# Training for 500 iteration for each Beam uses 146.10477805137634 seconds.
# Beam: 0, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 36.56, BF Gain: 36.56
# Beam: 1, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 16.18, BF Gain: 16.18
# Beam: 2, Iter: 6001, Reward pred: -1, Reward: -1, BF Gain pred: 11.18, BF Gain: 11.18
# Beam: 3, Iter: 6001, Reward pred: 1, Reward: 1, BF Gain pred: 8.48, BF Gain: 8.48
# Training for 500 iteration for each Beam uses 146.1464545726776 seconds.
# Beam: 0, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 48.31, BF Gain: 48.31
# Beam: 1, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 88.02, BF Gain: 88.02
# Beam: 2, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 53.20, BF Gain: 53.20
# Beam: 3, Iter: 6501, Reward pred: 1, Reward: 1, BF Gain pred: 20.92, BF Gain: 20.92
# Training for 500 iteration for each Beam uses 147.96779799461365 seconds.
# Beam: 0, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 57.74, BF Gain: 57.74
# Beam: 1, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 119.99, BF Gain: 119.99
# Beam: 2, Iter: 7001, Reward pred: 1, Reward: 1, BF Gain pred: 94.97, BF Gain: 94.97
# Beam: 3, Iter: 7001, Reward pred: -1, Reward: -1, BF Gain pred: 8.59, BF Gain: 8.59
# Training for 500 iteration for each Beam uses 147.56882095336914 seconds.
# Beam: 0, Iter: 7501, Reward pred: -1, Reward: -1, BF Gain pred: 86.94, BF Gain: 86.94
# Beam: 1, Iter: 7501, Reward pred: -1, Reward: -1, BF Gain pred: 161.53, BF Gain: 161.53
# Beam: 2, Iter: 7501, Reward pred: -1, Reward: -1, BF Gain pred: 124.33, BF Gain: 124.33
# Beam: 3, Iter: 7501, Reward pred: 1, Reward: 1, BF Gain pred: 10.72, BF Gain: 10.72
# Training for 500 iteration for each Beam uses 148.38911986351013 seconds.
# Beam: 0, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 83.84, BF Gain: 83.84
# Beam: 1, Iter: 8001, Reward pred: 1, Reward: 1, BF Gain pred: 204.34, BF Gain: 204.34
# Beam: 2, Iter: 8001, Reward pred: -1, Reward: -1, BF Gain pred: 162.79, BF Gain: 162.79
# Beam: 3, Iter: 8001, Reward pred: 1, Reward: 1, BF Gain pred: 72.90, BF Gain: 72.90
# Training for 500 iteration for each Beam uses 151.33245587348938 seconds.
# Beam: 0, Iter: 8501, Reward pred: 1, Reward: 1, BF Gain pred: 102.08, BF Gain: 102.08
# Beam: 1, Iter: 8501, Reward pred: 1, Reward: 1, BF Gain pred: 212.93, BF Gain: 212.93
# Beam: 2, Iter: 8501, Reward pred: 1, Reward: 1, BF Gain pred: 184.33, BF Gain: 184.33
# Beam: 3, Iter: 8501, Reward pred: 1, Reward: 1, BF Gain pred: 78.89, BF Gain: 78.89
# Training for 500 iteration for each Beam uses 153.47912096977234 seconds.
# Beam: 0, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 97.21, BF Gain: 97.21
# Beam: 1, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 221.73, BF Gain: 221.73
# Beam: 2, Iter: 9001, Reward pred: 1, Reward: 1, BF Gain pred: 202.52, BF Gain: 202.52
# Beam: 3, Iter: 9001, Reward pred: -1, Reward: -1, BF Gain pred: 102.85, BF Gain: 102.85
# Training for 500 iteration for each Beam uses 151.62178373336792 seconds.
# Beam: 0, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 106.30, BF Gain: 106.30
# Beam: 1, Iter: 9501, Reward pred: 1, Reward: 1, BF Gain pred: 241.75, BF Gain: 241.75
# Beam: 2, Iter: 9501, Reward pred: -1, Reward: -1, BF Gain pred: 196.42, BF Gain: 196.42
# Beam: 3, Iter: 9501, Reward pred: 1, Reward: 1, BF Gain pred: 132.19, BF Gain: 132.19
# Training for 500 iteration for each Beam uses 149.00890922546387 seconds.
# Beam: 0, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 106.39, BF Gain: 106.39
# Beam: 1, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 234.36, BF Gain: 234.36
# Beam: 2, Iter: 10001, Reward pred: -1, Reward: -1, BF Gain pred: 203.71, BF Gain: 203.71
# Beam: 3, Iter: 10001, Reward pred: 1, Reward: 1, BF Gain pred: 147.83, BF Gain: 147.83
# Training for 500 iteration for each Beam uses 147.15610432624817 seconds.
# Beam: 0, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 107.91, BF Gain: 107.91
# Beam: 1, Iter: 10501, Reward pred: 1, Reward: 1, BF Gain pred: 235.34, BF Gain: 235.34
# Beam: 2, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 202.90, BF Gain: 202.90
# Beam: 3, Iter: 10501, Reward pred: -1, Reward: -1, BF Gain pred: 151.26, BF Gain: 151.26
# Training for 500 iteration for each Beam uses 151.0399112701416 seconds.
# Beam: 0, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 105.55, BF Gain: 105.55
# Beam: 1, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 235.52, BF Gain: 235.52
# Beam: 2, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 203.26, BF Gain: 203.26
# Beam: 3, Iter: 11001, Reward pred: -1, Reward: -1, BF Gain pred: 152.28, BF Gain: 152.28
# Training for 500 iteration for each Beam uses 151.27952671051025 seconds.
# Beam: 0, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 105.83, BF Gain: 105.83
# Beam: 1, Iter: 11501, Reward pred: 1, Reward: 1, BF Gain pred: 238.48, BF Gain: 238.48
# Beam: 2, Iter: 11501, Reward pred: -1, Reward: -1, BF Gain pred: 208.11, BF Gain: 208.11
# Beam: 3, Iter: 11501, Reward pred: 1, Reward: 1, BF Gain pred: 153.38, BF Gain: 153.38
# Training for 500 iteration for each Beam uses 146.16409516334534 seconds.
# Beam: 0, Iter: 12001, Reward pred: 1, Reward: 1, BF Gain pred: 107.81, BF Gain: 107.81
# Beam: 1, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 234.28, BF Gain: 234.28
# Beam: 2, Iter: 12001, Reward pred: 1, Reward: 1, BF Gain pred: 205.68, BF Gain: 205.68
# Beam: 3, Iter: 12001, Reward pred: -1, Reward: -1, BF Gain pred: 153.52, BF Gain: 153.52
# Training for 500 iteration for each Beam uses 147.5515410900116 seconds.
# Beam: 0, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 109.60, BF Gain: 109.60
# Beam: 1, Iter: 12501, Reward pred: 1, Reward: 1, BF Gain pred: 239.07, BF Gain: 239.07
# Beam: 2, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 196.18, BF Gain: 196.18
# Beam: 3, Iter: 12501, Reward pred: -1, Reward: -1, BF Gain pred: 154.26, BF Gain: 154.26
# Training for 500 iteration for each Beam uses 148.89537072181702 seconds.
# Beam: 0, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 109.69, BF Gain: 109.69
# Beam: 1, Iter: 13001, Reward pred: 1, Reward: 1, BF Gain pred: 243.44, BF Gain: 243.44
# Beam: 2, Iter: 13001, Reward pred: 1, Reward: 1, BF Gain pred: 209.91, BF Gain: 209.91
# Beam: 3, Iter: 13001, Reward pred: -1, Reward: -1, BF Gain pred: 156.51, BF Gain: 156.51
# Training for 500 iteration for each Beam uses 146.41033554077148 seconds.
# Beam: 0, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 109.82, BF Gain: 109.82
# Beam: 1, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 232.98, BF Gain: 232.98
# Beam: 2, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 207.58, BF Gain: 207.58
# Beam: 3, Iter: 13501, Reward pred: 1, Reward: 1, BF Gain pred: 160.66, BF Gain: 160.66
# Training for 500 iteration for each Beam uses 145.86182570457458 seconds.
# Beam: 0, Iter: 14001, Reward pred: -1, Reward: -1, BF Gain pred: 107.60, BF Gain: 107.60
# Beam: 1, Iter: 14001, Reward pred: 1, Reward: 1, BF Gain pred: 244.68, BF Gain: 244.68
# Beam: 2, Iter: 14001, Reward pred: 1, Reward: 1, BF Gain pred: 211.09, BF Gain: 211.09
# Beam: 3, Iter: 14001, Reward pred: 1, Reward: 1, BF Gain pred: 162.26, BF Gain: 162.26
# Training for 500 iteration for each Beam uses 146.96994304656982 seconds.
# Beam: 0, Iter: 14501, Reward pred: 1, Reward: 1, BF Gain pred: 109.84, BF Gain: 109.84
# Beam: 1, Iter: 14501, Reward pred: -1, Reward: -1, BF Gain pred: 236.38, BF Gain: 236.38
# Beam: 2, Iter: 14501, Reward pred: 1, Reward: 1, BF Gain pred: 207.98, BF Gain: 207.98
# Beam: 3, Iter: 14501, Reward pred: 1, Reward: 1, BF Gain pred: 157.65, BF Gain: 157.65
# Training for 500 iteration for each Beam uses 150.09551763534546 seconds.
# Beam: 0, Iter: 15001, Reward pred: -1, Reward: -1, BF Gain pred: 106.94, BF Gain: 106.94
# Beam: 1, Iter: 15001, Reward pred: -1, Reward: -1, BF Gain pred: 233.97, BF Gain: 233.97
# Beam: 2, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 207.72, BF Gain: 207.72
# Beam: 3, Iter: 15001, Reward pred: 1, Reward: 1, BF Gain pred: 158.58, BF Gain: 158.58
# Training for 500 iteration for each Beam uses 149.03377413749695 seconds.
# Beam: 0, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 107.80, BF Gain: 107.80
# Beam: 1, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 240.52, BF Gain: 240.52
# Beam: 2, Iter: 15501, Reward pred: 1, Reward: 1, BF Gain pred: 209.19, BF Gain: 209.19
# Beam: 3, Iter: 15501, Reward pred: -1, Reward: -1, BF Gain pred: 157.82, BF Gain: 157.82
# Training for 500 iteration for each Beam uses 148.03472208976746 seconds.
# Beam: 0, Iter: 16001, Reward pred: 1, Reward: 1, BF Gain pred: 108.07, BF Gain: 108.07
# Beam: 1, Iter: 16001, Reward pred: 1, Reward: 1, BF Gain pred: 235.27, BF Gain: 235.27
# Beam: 2, Iter: 16001, Reward pred: -1, Reward: -1, BF Gain pred: 203.26, BF Gain: 203.26
# Beam: 3, Iter: 16001, Reward pred: 1, Reward: 1, BF Gain pred: 157.18, BF Gain: 157.18
# Training for 500 iteration for each Beam uses 154.8553068637848 seconds.
# Beam: 0, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 107.65, BF Gain: 107.65
# Beam: 1, Iter: 16501, Reward pred: 1, Reward: 1, BF Gain pred: 239.43, BF Gain: 239.43
# Beam: 2, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 207.65, BF Gain: 207.65
# Beam: 3, Iter: 16501, Reward pred: -1, Reward: -1, BF Gain pred: 143.75, BF Gain: 143.75
# Training for 500 iteration for each Beam uses 150.4811074733734 seconds.
# Beam: 0, Iter: 17001, Reward pred: -1, Reward: -1, BF Gain pred: 107.77, BF Gain: 107.77
# Beam: 1, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 237.06, BF Gain: 237.06
# Beam: 2, Iter: 17001, Reward pred: -1, Reward: -1, BF Gain pred: 206.79, BF Gain: 206.79
# Beam: 3, Iter: 17001, Reward pred: 1, Reward: 1, BF Gain pred: 158.89, BF Gain: 158.89
# Training for 500 iteration for each Beam uses 154.82059907913208 seconds.
# Beam: 0, Iter: 17501, Reward pred: 1, Reward: 1, BF Gain pred: 108.40, BF Gain: 108.40
# Beam: 1, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 237.82, BF Gain: 237.82
# Beam: 2, Iter: 17501, Reward pred: 1, Reward: 1, BF Gain pred: 212.01, BF Gain: 212.01
# Beam: 3, Iter: 17501, Reward pred: -1, Reward: -1, BF Gain pred: 155.97, BF Gain: 155.97
# Training for 500 iteration for each Beam uses 150.3000910282135 seconds.
# Beam: 0, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 108.73, BF Gain: 108.73
# Beam: 1, Iter: 18001, Reward pred: -1, Reward: -1, BF Gain pred: 244.32, BF Gain: 244.32
# Beam: 2, Iter: 18001, Reward pred: -1, Reward: -1, BF Gain pred: 200.26, BF Gain: 200.26
# Beam: 3, Iter: 18001, Reward pred: 1, Reward: 1, BF Gain pred: 157.56, BF Gain: 157.56
# Training for 500 iteration for each Beam uses 148.54724884033203 seconds.
# Beam: 0, Iter: 18501, Reward pred: 1, Reward: 1, BF Gain pred: 109.41, BF Gain: 109.41
# Beam: 1, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 233.42, BF Gain: 233.42
# Beam: 2, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 212.63, BF Gain: 212.63
# Beam: 3, Iter: 18501, Reward pred: -1, Reward: -1, BF Gain pred: 158.28, BF Gain: 158.28
# Training for 500 iteration for each Beam uses 150.5131230354309 seconds.
# Beam: 0, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 108.47, BF Gain: 108.47
# Beam: 1, Iter: 19001, Reward pred: 1, Reward: 1, BF Gain pred: 245.08, BF Gain: 245.08
# Beam: 2, Iter: 19001, Reward pred: 1, Reward: 1, BF Gain pred: 206.81, BF Gain: 206.81
# Beam: 3, Iter: 19001, Reward pred: -1, Reward: -1, BF Gain pred: 159.16, BF Gain: 159.16
# Training for 500 iteration for each Beam uses 149.61369800567627 seconds.
# Beam: 0, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 107.93, BF Gain: 107.93
# Beam: 1, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 243.68, BF Gain: 243.68
# Beam: 2, Iter: 19501, Reward pred: -1, Reward: -1, BF Gain pred: 207.55, BF Gain: 207.55
# Beam: 3, Iter: 19501, Reward pred: 1, Reward: 1, BF Gain pred: 160.40, BF Gain: 160.40
# Training for 500 iteration for each Beam uses 149.09183502197266 seconds.
# Beam: 0, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 108.13, BF Gain: 108.13
# Beam: 1, Iter: 20001, Reward pred: 1, Reward: 1, BF Gain pred: 240.24, BF Gain: 240.24
# Beam: 2, Iter: 20001, Reward pred: 1, Reward: 1, BF Gain pred: 206.61, BF Gain: 206.61
# Beam: 3, Iter: 20001, Reward pred: -1, Reward: -1, BF Gain pred: 158.76, BF Gain: 158.76
# Training for 500 iteration for each Beam uses 149.81045532226562 seconds.
# Beam: 0, Iter: 20501, Reward pred: -1, Reward: -1, BF Gain pred: 106.16, BF Gain: 106.16
# Beam: 1, Iter: 20501, Reward pred: 1, Reward: 1, BF Gain pred: 238.38, BF Gain: 238.38
# Beam: 2, Iter: 20501, Reward pred: 1, Reward: 1, BF Gain pred: 209.21, BF Gain: 209.21
# Beam: 3, Iter: 20501, Reward pred: 1, Reward: 1, BF Gain pred: 157.22, BF Gain: 157.22
# Training for 500 iteration for each Beam uses 149.52248406410217 seconds.
# Beam: 0, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 107.96, BF Gain: 107.96
# Beam: 1, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 232.99, BF Gain: 232.99
# Beam: 2, Iter: 21001, Reward pred: -1, Reward: -1, BF Gain pred: 206.86, BF Gain: 206.86
# Beam: 3, Iter: 21001, Reward pred: 1, Reward: 1, BF Gain pred: 157.80, BF Gain: 157.80
# Training for 500 iteration for each Beam uses 146.68253087997437 seconds.
# Beam: 0, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 106.53, BF Gain: 106.53
# Beam: 1, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 239.05, BF Gain: 239.05
# Beam: 2, Iter: 21501, Reward pred: 1, Reward: 1, BF Gain pred: 206.23, BF Gain: 206.23
# Beam: 3, Iter: 21501, Reward pred: -1, Reward: -1, BF Gain pred: 156.35, BF Gain: 156.35
# Training for 500 iteration for each Beam uses 149.0549337863922 seconds.
# Beam: 0, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 110.17, BF Gain: 110.17
# Beam: 1, Iter: 22001, Reward pred: -1, Reward: -1, BF Gain pred: 237.30, BF Gain: 237.30
# Beam: 2, Iter: 22001, Reward pred: 1, Reward: 1, BF Gain pred: 209.19, BF Gain: 209.19
# Beam: 3, Iter: 22001, Reward pred: -1, Reward: -1, BF Gain pred: 155.10, BF Gain: 155.10
# Training for 500 iteration for each Beam uses 148.85270071029663 seconds.
# Beam: 0, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 108.01, BF Gain: 108.01
# Beam: 1, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 234.35, BF Gain: 234.35
# Beam: 2, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 206.12, BF Gain: 206.12
# Beam: 3, Iter: 22501, Reward pred: -1, Reward: -1, BF Gain pred: 160.15, BF Gain: 160.15
# Training for 500 iteration for each Beam uses 148.855806350708 seconds.
# Beam: 0, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 109.07, BF Gain: 109.07
# Beam: 1, Iter: 23001, Reward pred: 1, Reward: 1, BF Gain pred: 243.80, BF Gain: 243.80
# Beam: 2, Iter: 23001, Reward pred: -1, Reward: -1, BF Gain pred: 204.84, BF Gain: 204.84
# Beam: 3, Iter: 23001, Reward pred: 1, Reward: 1, BF Gain pred: 158.28, BF Gain: 158.28
# Training for 500 iteration for each Beam uses 152.53631234169006 seconds.
# Beam: 0, Iter: 23501, Reward pred: 1, Reward: 1, BF Gain pred: 108.32, BF Gain: 108.32
# Beam: 1, Iter: 23501, Reward pred: 1, Reward: 1, BF Gain pred: 238.45, BF Gain: 238.45
# Beam: 2, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 203.96, BF Gain: 203.96
# Beam: 3, Iter: 23501, Reward pred: -1, Reward: -1, BF Gain pred: 159.35, BF Gain: 159.35
# Training for 500 iteration for each Beam uses 150.92884707450867 seconds.
# Beam: 0, Iter: 24001, Reward pred: -1, Reward: -1, BF Gain pred: 109.95, BF Gain: 109.95
# Beam: 1, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 242.71, BF Gain: 242.71
# Beam: 2, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 206.56, BF Gain: 206.56
# Beam: 3, Iter: 24001, Reward pred: 1, Reward: 1, BF Gain pred: 161.85, BF Gain: 161.85
# Training for 500 iteration for each Beam uses 148.4755208492279 seconds.
# Beam: 0, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 108.70, BF Gain: 108.70
# Beam: 1, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 240.34, BF Gain: 240.34
# Beam: 2, Iter: 24501, Reward pred: 1, Reward: 1, BF Gain pred: 208.26, BF Gain: 208.26
# Beam: 3, Iter: 24501, Reward pred: -1, Reward: -1, BF Gain pred: 156.92, BF Gain: 156.92
# Training for 500 iteration for each Beam uses 148.34346866607666 seconds.
# Beam: 0, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 109.82, BF Gain: 109.82
# Beam: 1, Iter: 25001, Reward pred: -1, Reward: -1, BF Gain pred: 243.68, BF Gain: 243.68
# Beam: 2, Iter: 25001, Reward pred: 1, Reward: 1, BF Gain pred: 209.45, BF Gain: 209.45
# Beam: 3, Iter: 25001, Reward pred: 1, Reward: 1, BF Gain pred: 157.99, BF Gain: 157.99
# Training for 500 iteration for each Beam uses 148.06322503089905 seconds.
# Beam: 0, Iter: 25501, Reward pred: -1, Reward: -1, BF Gain pred: 108.86, BF Gain: 108.86
# Beam: 1, Iter: 25501, Reward pred: -1, Reward: -1, BF Gain pred: 239.48, BF Gain: 239.48
# Beam: 2, Iter: 25501, Reward pred: -1, Reward: -1, BF Gain pred: 211.05, BF Gain: 211.05
# Beam: 3, Iter: 25501, Reward pred: 1, Reward: 1, BF Gain pred: 159.90, BF Gain: 159.90
# Training for 500 iteration for each Beam uses 148.98613142967224 seconds.
# Beam: 0, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 109.79, BF Gain: 109.79
# Beam: 1, Iter: 26001, Reward pred: -1, Reward: -1, BF Gain pred: 241.95, BF Gain: 241.95
# Beam: 2, Iter: 26001, Reward pred: 1, Reward: 1, BF Gain pred: 205.77, BF Gain: 205.77
# Beam: 3, Iter: 26001, Reward pred: 1, Reward: 1, BF Gain pred: 157.14, BF Gain: 157.14
# Training for 500 iteration for each Beam uses 150.42100310325623 seconds.
# Beam: 0, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 106.55, BF Gain: 106.55
# Beam: 1, Iter: 26501, Reward pred: 1, Reward: 1, BF Gain pred: 238.12, BF Gain: 238.12
# Beam: 2, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 202.01, BF Gain: 202.01
# Beam: 3, Iter: 26501, Reward pred: -1, Reward: -1, BF Gain pred: 160.67, BF Gain: 160.67
# Training for 500 iteration for each Beam uses 150.70939779281616 seconds.
# Beam: 0, Iter: 27001, Reward pred: 1, Reward: 1, BF Gain pred: 109.49, BF Gain: 109.49
# Beam: 1, Iter: 27001, Reward pred: 1, Reward: 1, BF Gain pred: 237.98, BF Gain: 237.98
# Beam: 2, Iter: 27001, Reward pred: 1, Reward: 1, BF Gain pred: 205.73, BF Gain: 205.73
# Beam: 3, Iter: 27001, Reward pred: -1, Reward: -1, BF Gain pred: 159.22, BF Gain: 159.22
# Training for 500 iteration for each Beam uses 151.67718720436096 seconds.
# Beam: 0, Iter: 27501, Reward pred: -1, Reward: -1, BF Gain pred: 110.18, BF Gain: 110.18
# Beam: 1, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 240.81, BF Gain: 240.81
# Beam: 2, Iter: 27501, Reward pred: -1, Reward: -1, BF Gain pred: 211.36, BF Gain: 211.36
# Beam: 3, Iter: 27501, Reward pred: 1, Reward: 1, BF Gain pred: 158.21, BF Gain: 158.21
# Training for 500 iteration for each Beam uses 151.12731170654297 seconds.
# Beam: 0, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 108.58, BF Gain: 108.58
# Beam: 1, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 240.67, BF Gain: 240.67
# Beam: 2, Iter: 28001, Reward pred: -1, Reward: -1, BF Gain pred: 208.69, BF Gain: 208.69
# Beam: 3, Iter: 28001, Reward pred: 1, Reward: 1, BF Gain pred: 157.40, BF Gain: 157.40
# Training for 500 iteration for each Beam uses 148.54624772071838 seconds.
# Beam: 0, Iter: 28501, Reward pred: -1, Reward: -1, BF Gain pred: 109.68, BF Gain: 109.68
# Beam: 1, Iter: 28501, Reward pred: -1, Reward: -1, BF Gain pred: 230.61, BF Gain: 230.61
# Beam: 2, Iter: 28501, Reward pred: 1, Reward: 1, BF Gain pred: 216.02, BF Gain: 216.02
# Beam: 3, Iter: 28501, Reward pred: 1, Reward: 1, BF Gain pred: 156.34, BF Gain: 156.34
# Training for 500 iteration for each Beam uses 147.38742327690125 seconds.
# Beam: 0, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 110.20, BF Gain: 110.20
# Beam: 1, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 232.89, BF Gain: 232.89
# Beam: 2, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 211.90, BF Gain: 211.90
# Beam: 3, Iter: 29001, Reward pred: -1, Reward: -1, BF Gain pred: 158.32, BF Gain: 158.32
# Training for 500 iteration for each Beam uses 150.6406900882721 seconds.
# Beam: 0, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 108.15, BF Gain: 108.15
# Beam: 1, Iter: 29501, Reward pred: -1, Reward: -1, BF Gain pred: 239.97, BF Gain: 239.97
# Beam: 2, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 210.43, BF Gain: 210.43
# Beam: 3, Iter: 29501, Reward pred: 1, Reward: 1, BF Gain pred: 158.41, BF Gain: 158.41
# Training for 500 iteration for each Beam uses 148.10047912597656 seconds.
# Beam: 0, Iter: 30001, Reward pred: 1, Reward: 1, BF Gain pred: 110.26, BF Gain: 110.26
# Beam: 1, Iter: 30001, Reward pred: 1, Reward: 1, BF Gain pred: 239.62, BF Gain: 239.62
# Beam: 2, Iter: 30001, Reward pred: 1, Reward: 1, BF Gain pred: 212.55, BF Gain: 212.55
# Beam: 3, Iter: 30001, Reward pred: -1, Reward: -1, BF Gain pred: 158.89, BF Gain: 158.89
# Training for 500 iteration for each Beam uses 147.1658308506012 seconds.
# Beam: 0, Iter: 30501, Reward pred: 1, Reward: 1, BF Gain pred: 108.20, BF Gain: 108.20
# Beam: 1, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 243.78, BF Gain: 243.78
# Beam: 2, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 212.26, BF Gain: 212.26
# Beam: 3, Iter: 30501, Reward pred: -1, Reward: -1, BF Gain pred: 157.38, BF Gain: 157.38
# Training for 500 iteration for each Beam uses 147.63696360588074 seconds.
# Beam: 0, Iter: 31001, Reward pred: 1, Reward: 1, BF Gain pred: 108.62, BF Gain: 108.62
# Beam: 1, Iter: 31001, Reward pred: 1, Reward: 1, BF Gain pred: 240.30, BF Gain: 240.30
# Beam: 2, Iter: 31001, Reward pred: -1, Reward: -1, BF Gain pred: 207.05, BF Gain: 207.05
# Beam: 3, Iter: 31001, Reward pred: 1, Reward: 1, BF Gain pred: 157.20, BF Gain: 157.20
# Training for 500 iteration for each Beam uses 142.6539764404297 seconds.
# Beam: 0, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 109.13, BF Gain: 109.13
# Beam: 1, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 238.96, BF Gain: 238.96
# Beam: 2, Iter: 31501, Reward pred: -1, Reward: -1, BF Gain pred: 203.87, BF Gain: 203.87
# Beam: 3, Iter: 31501, Reward pred: 1, Reward: 1, BF Gain pred: 159.13, BF Gain: 159.13
# Training for 500 iteration for each Beam uses 142.2197937965393 seconds.
# Beam: 0, Iter: 32001, Reward pred: 1, Reward: 1, BF Gain pred: 109.08, BF Gain: 109.08
# Beam: 1, Iter: 32001, Reward pred: -1, Reward: -1, BF Gain pred: 241.89, BF Gain: 241.89
# Beam: 2, Iter: 32001, Reward pred: 1, Reward: 1, BF Gain pred: 209.66, BF Gain: 209.66
# Beam: 3, Iter: 32001, Reward pred: 1, Reward: 1, BF Gain pred: 156.99, BF Gain: 156.99
# Training for 500 iteration for each Beam uses 142.3449580669403 seconds.
# Beam: 0, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 109.97, BF Gain: 109.97
# Beam: 1, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 234.27, BF Gain: 234.27
# Beam: 2, Iter: 32501, Reward pred: -1, Reward: -1, BF Gain pred: 208.52, BF Gain: 208.52
# Beam: 3, Iter: 32501, Reward pred: 1, Reward: 1, BF Gain pred: 158.86, BF Gain: 158.86
# Training for 500 iteration for each Beam uses 142.1397340297699 seconds.
# Beam: 0, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 109.95, BF Gain: 109.95
# Beam: 1, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 243.80, BF Gain: 243.80
# Beam: 2, Iter: 33001, Reward pred: 1, Reward: 1, BF Gain pred: 201.78, BF Gain: 201.78
# Beam: 3, Iter: 33001, Reward pred: -1, Reward: -1, BF Gain pred: 156.17, BF Gain: 156.17
# Training for 500 iteration for each Beam uses 142.04099369049072 seconds.
# Beam: 0, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 107.12, BF Gain: 107.12
# Beam: 1, Iter: 33501, Reward pred: 1, Reward: 1, BF Gain pred: 236.34, BF Gain: 236.34
# Beam: 2, Iter: 33501, Reward pred: -1, Reward: -1, BF Gain pred: 208.65, BF Gain: 208.65
# Beam: 3, Iter: 33501, Reward pred: 1, Reward: 1, BF Gain pred: 156.47, BF Gain: 156.47
# Training for 500 iteration for each Beam uses 141.7194414138794 seconds.
# Beam: 0, Iter: 34001, Reward pred: 1, Reward: 1, BF Gain pred: 108.31, BF Gain: 108.31
# Beam: 1, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 239.67, BF Gain: 239.67
# Beam: 2, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 198.55, BF Gain: 198.55
# Beam: 3, Iter: 34001, Reward pred: -1, Reward: -1, BF Gain pred: 158.79, BF Gain: 158.79
# Training for 500 iteration for each Beam uses 142.02781438827515 seconds.
# Beam: 0, Iter: 34501, Reward pred: 1, Reward: 1, BF Gain pred: 111.54, BF Gain: 111.54
# Beam: 1, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 239.69, BF Gain: 239.69
# Beam: 2, Iter: 34501, Reward pred: -1, Reward: -1, BF Gain pred: 208.19, BF Gain: 208.19
# Beam: 3, Iter: 34501, Reward pred: 1, Reward: 1, BF Gain pred: 156.47, BF Gain: 156.47
# Training for 500 iteration for each Beam uses 141.99360942840576 seconds.
# Beam: 0, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 108.18, BF Gain: 108.18
# Beam: 1, Iter: 35001, Reward pred: 1, Reward: 1, BF Gain pred: 239.56, BF Gain: 239.56
# Beam: 2, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 212.56, BF Gain: 212.56
# Beam: 3, Iter: 35001, Reward pred: -1, Reward: -1, BF Gain pred: 158.72, BF Gain: 158.72
# Training for 500 iteration for each Beam uses 141.95365977287292 seconds.
# Beam: 0, Iter: 35501, Reward pred: 1, Reward: 1, BF Gain pred: 109.66, BF Gain: 109.66
# Beam: 1, Iter: 35501, Reward pred: 1, Reward: 1, BF Gain pred: 240.27, BF Gain: 240.27
# Beam: 2, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 216.19, BF Gain: 216.19
# Beam: 3, Iter: 35501, Reward pred: -1, Reward: -1, BF Gain pred: 154.82, BF Gain: 154.82
# Training for 500 iteration for each Beam uses 142.49844670295715 seconds.
# Beam: 0, Iter: 36001, Reward pred: 1, Reward: 1, BF Gain pred: 110.25, BF Gain: 110.25
# Beam: 1, Iter: 36001, Reward pred: 1, Reward: 1, BF Gain pred: 239.91, BF Gain: 239.91
# Beam: 2, Iter: 36001, Reward pred: 1, Reward: 1, BF Gain pred: 213.82, BF Gain: 213.82
# Beam: 3, Iter: 36001, Reward pred: -1, Reward: -1, BF Gain pred: 156.40, BF Gain: 156.40
# Training for 500 iteration for each Beam uses 142.51158356666565 seconds.
# Beam: 0, Iter: 36501, Reward pred: 1, Reward: 1, BF Gain pred: 111.13, BF Gain: 111.13
# Beam: 1, Iter: 36501, Reward pred: -1, Reward: -1, BF Gain pred: 244.89, BF Gain: 244.89
# Beam: 2, Iter: 36501, Reward pred: -1, Reward: -1, BF Gain pred: 208.51, BF Gain: 208.51
# Beam: 3, Iter: 36501, Reward pred: 1, Reward: 1, BF Gain pred: 155.15, BF Gain: 155.15
# Training for 500 iteration for each Beam uses 142.23900318145752 seconds.
# Beam: 0, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 108.51, BF Gain: 108.51
# Beam: 1, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 235.01, BF Gain: 235.01
# Beam: 2, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 214.06, BF Gain: 214.06
# Beam: 3, Iter: 37001, Reward pred: 1, Reward: 1, BF Gain pred: 159.91, BF Gain: 159.91
# Training for 500 iteration for each Beam uses 142.3389298915863 seconds.
# Beam: 0, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 108.06, BF Gain: 108.06
# Beam: 1, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 240.38, BF Gain: 240.38
# Beam: 2, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 208.27, BF Gain: 208.27
# Beam: 3, Iter: 37501, Reward pred: -1, Reward: -1, BF Gain pred: 157.82, BF Gain: 157.82
# Training for 500 iteration for each Beam uses 141.8139672279358 seconds.
# Beam: 0, Iter: 38001, Reward pred: 1, Reward: 1, BF Gain pred: 105.82, BF Gain: 105.82
# Beam: 1, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 240.70, BF Gain: 240.70
# Beam: 2, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 206.28, BF Gain: 206.28
# Beam: 3, Iter: 38001, Reward pred: -1, Reward: -1, BF Gain pred: 157.26, BF Gain: 157.26
# Training for 500 iteration for each Beam uses 142.5337529182434 seconds.
# Beam: 0, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 107.34, BF Gain: 107.34
# Beam: 1, Iter: 38501, Reward pred: 1, Reward: 1, BF Gain pred: 238.71, BF Gain: 238.71
# Beam: 2, Iter: 38501, Reward pred: -1, Reward: -1, BF Gain pred: 202.05, BF Gain: 202.05
# Beam: 3, Iter: 38501, Reward pred: 1, Reward: 1, BF Gain pred: 159.33, BF Gain: 159.33
# Training for 500 iteration for each Beam uses 141.9666051864624 seconds.
# Beam: 0, Iter: 39001, Reward pred: 1, Reward: 1, BF Gain pred: 111.12, BF Gain: 111.12
# Beam: 1, Iter: 39001, Reward pred: 1, Reward: 1, BF Gain pred: 238.48, BF Gain: 238.48
# Beam: 2, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 204.80, BF Gain: 204.80
# Beam: 3, Iter: 39001, Reward pred: -1, Reward: -1, BF Gain pred: 156.28, BF Gain: 156.28
# Training for 500 iteration for each Beam uses 142.26616668701172 seconds.
# Beam: 0, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 107.47, BF Gain: 107.47
# Beam: 1, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 239.15, BF Gain: 239.15
# Beam: 2, Iter: 39501, Reward pred: 1, Reward: 1, BF Gain pred: 214.41, BF Gain: 214.41
# Beam: 3, Iter: 39501, Reward pred: -1, Reward: -1, BF Gain pred: 157.70, BF Gain: 157.70
# Training for 500 iteration for each Beam uses 142.39297723770142 seconds.
# Beam: 0, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 106.50, BF Gain: 106.50
# Beam: 1, Iter: 40001, Reward pred: 1, Reward: 1, BF Gain pred: 239.79, BF Gain: 239.79
# Beam: 2, Iter: 40001, Reward pred: -1, Reward: -1, BF Gain pred: 205.47, BF Gain: 205.47
# Beam: 3, Iter: 40001, Reward pred: 1, Reward: 1, BF Gain pred: 156.81, BF Gain: 156.81
# Training for 500 iteration for each Beam uses 142.26428532600403 seconds.

# %%
import numpy as np
import scipy.io as scio

num_ant = 32
num_beam = 4
results = np.empty((num_beam, 2*num_ant))

path = './beams/'

for beam_id in range(num_beam):
    fname = 'beams_' + str(beam_id) + '_max.txt'
    with open(path + fname, 'r') as f:
        lines = f.readlines()
        last_line = lines[-1]
        results[beam_id, :] = np.fromstring(last_line.replace("\n", ""), sep=',').reshape(1, -1)

results = (1 / np.sqrt(num_ant)) * (results[:, ::2] + 1j * results[:, 1::2])

scio.savemat('beam_codebook.mat', {'beams': results})

# %%
from matplotlib import pyplot as plt
plt.title(f'Best beamforming gain')
plt.xlabel('Beam_framing_gain')   
for beam_id in range(options['num_NNs']):
    gain_record=np.concatenate(env_list[beam_id].gain_record[1:]).flatten()
    plt.plot(gain_record, label=f'Beam_{beam_id}')
    plt.plot([])
plt.plot([231.17094]*50,linestyle='dashed',color='black')
plt.legend(loc="upper left")  
plt.show()
